# %%
import os
import pandas as pd
import shutil

# Define folder paths
folder_A = "/Users/jatinkumarparmar/Desktop/DSP/Project/Folder_A"
bad_data_folder = "Folder_B"
good_data_folder = "Folder_C"

os.makedirs(good_data_folder, exist_ok=True)
os.makedirs(bad_data_folder, exist_ok=True)

def check_errors(df, file):
    """
    Check if the dataset contains any introduced errors.
    Returns True if errors are found, otherwise False.
    """
    error_found = False

    # Check for blank price values in SpiceJet
    if df[(df['airline'] == 'SpiceJet') & (df['price'].isna())].shape[0] > 0:
        error_found = True
        print(f"[ERROR] {file}: Blank price values in SpiceJet.")
    
    # Check for negative days_left values
    if df[df['days_left'] < 0].shape[0] > 0:
        error_found = True
        print(f"[ERROR] {file}: Negative 'days_left' values.")
    
    # Check for same source and destination cities
    if df[df['source_city'] == df['destination_city']].shape[0] > 0:
        error_found = True
        print(f"[ERROR] {file}: Same source and destination cities.")
    
    # Check for Yes/No in duration
    if df[df['duration'].astype(str).isin(['Yes', 'No'])].shape[0] > 0:
        error_found = True
        print(f"[ERROR] {file}: Invalid 'duration' values (Yes/No).")
    
    # Check for Premium travel_class
    if df[df['travel_class'] == 'Premium'].shape[0] > 0:
        error_found = True
        print(f"[ERROR] {file}: Premium travel_class found.")
    
    # Check for Air India flights with Vistara flight numbers
    # Ensure 'flight' column is treated as a string to prevent errors
    df['flight'] = df['flight'].astype(str)
    if df[(df['airline'] == 'Air_India') & (df['flight'].str.startswith('UK-'))].shape[0] > 0:
        error_found = True
        print(f"[ERROR] {file}: Air India flights with Vistara flight numbers.")
    
    # Check for zero stops with duration > 20 hours
    temp_duration = pd.to_numeric(df['duration'], errors='coerce')  # Convert to numeric
    if df[(df['stops'] == 'zero') & (temp_duration > 20)].shape[0] > 0:
        error_found = True
        print(f"[ERROR] {file}: Zero stops with duration > 20 hours.")

    return error_found

# Get the list of visible .csv files in Folder_A, excluding hidden files
files = [f for f in os.listdir(folder_A) if f.endswith(".csv") and not f.startswith(".")]

# Process each file and track the results
bad_data_count = 0
good_data_count = 0
skipped_files = []

# Start processing each file
for file in files:
    file_path = os.path.join(folder_A, file)
    
    try:
        # Attempt to read the CSV file
        df = pd.read_csv(file_path)

        # Check for errors in the data
        if check_errors(df, file):
            # Copy the file to bad_data folder
            shutil.copy(file_path, os.path.join(bad_data_folder, file))
            bad_data_count += 1
            print(f"{file} is copied to bad_data.")
        else:
            # Copy the file to good_data folder
            shutil.copy(file_path, os.path.join(good_data_folder, file))
            good_data_count += 1
            print(f"{file} is copied to good_data.")

    except Exception as e:
        # Log the error and skip the file
        skipped_files.append(file)
        print(f"[ERROR] Could not process {file}: {e}")

# Final summary
print(f"\nTotal files processed: {len(files)}")
print(f"Files copied to bad_data: {bad_data_count}")
print(f"Files copied to good_data: {good_data_count}")
print(f"Files skipped due to errors: {len(skipped_files)}")
# Out:
# split_8289.csv is copied to good_data.
# [ERROR] split_9197.csv: Zero stops with duration > 20 hours.
# split_9197.csv is copied to bad_data.
# split_5975.csv is copied to good_data.
# split_7804.csv is copied to good_data.
# split_185.csv is copied to good_data.
# [ERROR] split_9829.csv: Negative 'days_left' values.
# split_9829.csv is copied to bad_data.
# split_191.csv is copied to good_data.
# split_7810.csv is copied to good_data.
# split_2968.csv is copied to good_data.
# [ERROR] split_5961.csv: Zero stops with duration > 20 hours.
# split_5961.csv is copied to bad_data.
# [ERROR] split_9183.csv: Zero stops with duration > 20 hours.
# split_9183.csv is copied to bad_data.
# [ERROR] split_5791.csv: Same source and destination cities.
# [ERROR] split_5791.csv: Air India flights with Vistara flight numbers.
# split_5791.csv is copied to bad_data.
# split_5949.csv is copied to good_data.
# [ERROR] split_7186.csv: Invalid 'duration' values (Yes/No).
# split_7186.csv is copied to bad_data.
# split_807.csv is copied to good_data.
# split_6298.csv is copied to good_data.
# split_1291.csv is copied to good_data.
# split_7838.csv is copied to good_data.
# split_9815.csv is copied to good_data.
# [ERROR] split_2940.csv: Air India flights with Vistara flight numbers.
# split_2940.csv is copied to bad_data.
# [ERROR] split_3486.csv: Negative 'days_left' values.
# split_3486.csv is copied to bad_data.
# split_2798.csv is copied to good_data.
# split_2954.csv is copied to good_data.
# [ERROR] split_3492.csv: Invalid 'duration' values (Yes/No).
# split_3492.csv is copied to bad_data.
# split_1285.csv is copied to good_data.
# split_9801.csv is copied to good_data.
# [ERROR] split_813.csv: Negative 'days_left' values.
# split_813.csv is copied to bad_data.
# [ERROR] split_7192.csv: Invalid 'duration' values (Yes/No).
# split_7192.csv is copied to bad_data.
# split_5785.csv is copied to good_data.
# split_4470.csv is copied to good_data.
# [ERROR] split_2001.csv: Invalid 'duration' values (Yes/No).
# split_2001.csv is copied to bad_data.
# [ERROR] split_620.csv: Blank price values in SpiceJet.
# split_620.csv is copied to bad_data.
# [ERROR] split_1508.csv: Zero stops with duration > 20 hours.
# split_1508.csv is copied to bad_data.
# split_6267.csv is copied to good_data.
# split_9154.csv is copied to good_data.
# [ERROR] split_7179.csv: Zero stops with duration > 20 hours.
# split_7179.csv is copied to bad_data.
# split_6501.csv is copied to good_data.
# split_9632.csv is copied to good_data.
# [ERROR] split_146.csv: Air India flights with Vistara flight numbers.
# split_146.csv is copied to bad_data.
# split_2767.csv is copied to good_data.
# split_5008.csv is copied to good_data.
# split_4316.csv is copied to good_data.
# split_3479.csv is copied to good_data.
# split_2773.csv is copied to good_data.
# split_4302.csv is copied to good_data.
# split_8538.csv is copied to good_data.
# split_6515.csv is copied to good_data.
# split_9626.csv is copied to good_data.
# split_152.csv is copied to good_data.
# split_634.csv is copied to good_data.
# split_6273.csv is copied to good_data.
# split_9140.csv is copied to good_data.
# [ERROR] split_4464.csv: Blank price values in SpiceJet.
# split_4464.csv is copied to bad_data.
# split_2015.csv is copied to good_data.
# split_1534.csv is copied to good_data.
# [ERROR] split_9168.csv: Invalid 'duration' values (Yes/No).
# split_9168.csv is copied to bad_data.
# split_8276.csv is copied to good_data.
# split_7145.csv is copied to good_data.
# [ERROR] split_3323.csv: Same source and destination cities.
# split_3323.csv is copied to bad_data.
# split_5752.csv is copied to good_data.
# [ERROR] split_5034.csv: Negative 'days_left' values.
# split_5034.csv is copied to bad_data.
# [ERROR] split_2983.csv: Blank price values in SpiceJet.
# [ERROR] split_2983.csv: Premium travel_class found.
# [ERROR] split_2983.csv: Zero stops with duration > 20 hours.
# split_2983.csv is copied to bad_data.
# split_3445.csv is copied to good_data.
# split_8510.csv is copied to good_data.
# split_7623.csv is copied to good_data.
# [ERROR] split_1252.csv: Premium travel_class found.
# split_1252.csv is copied to bad_data.
# split_8504.csv is copied to good_data.
# split_7637.csv is copied to good_data.
# [ERROR] split_6529.csv: Zero stops with duration > 20 hours.
# split_6529.csv is copied to bad_data.
# split_1246.csv is copied to good_data.
# [ERROR] split_5020.csv: Negative 'days_left' values.
# split_5020.csv is copied to bad_data.
# [ERROR] split_2997.csv: Zero stops with duration > 20 hours.
# split_2997.csv is copied to bad_data.
# [ERROR] split_3451.csv: Blank price values in SpiceJet.
# split_3451.csv is copied to bad_data.
# [ERROR] split_3337.csv: Invalid 'duration' values (Yes/No).
# split_3337.csv is copied to bad_data.
# split_4458.csv is copied to good_data.
# split_5746.csv is copied to good_data.
# split_2029.csv is copied to good_data.
# split_1520.csv is copied to good_data.
# split_608.csv is copied to good_data.
# split_8262.csv is copied to good_data.
# split_7151.csv is copied to good_data.
# [ERROR] split_6918.csv: Premium travel_class found.
# [ERROR] split_6918.csv: Zero stops with duration > 20 hours.
# split_6918.csv is copied to bad_data.
# split_8935.csv is copied to good_data.
# split_387.csv is copied to good_data.
# [ERROR] split_3860.csv: Invalid 'duration' values (Yes/No).
# split_3860.csv is copied to bad_data.
# [ERROR] split_4869.csv: Invalid 'duration' values (Yes/No).
# split_4869.csv is copied to bad_data.
# split_9395.csv is copied to good_data.
# [ERROR] split_1911.csv: Same source and destination cities.
# split_1911.csv is copied to bad_data.
# split_9381.csv is copied to good_data.
# split_1905.csv is copied to good_data.
# split_3874.csv is copied to good_data.
# split_8921.csv is copied to good_data.
# split_393.csv is copied to good_data.
# split_3684.csv is copied to good_data.
# [ERROR] split_6924.csv: Same source and destination cities.
# [ERROR] split_6924.csv: Invalid 'duration' values (Yes/No).
# split_6924.csv is copied to bad_data.
# split_8909.csv is copied to good_data.
# split_1093.csv is copied to good_data.
# split_7384.csv is copied to good_data.
# split_4855.csv is copied to good_data.
# split_5593.csv is copied to good_data.
# split_4699.csv is copied to good_data.
# split_4841.csv is copied to good_data.
# [ERROR] split_5587.csv: Negative 'days_left' values.
# split_5587.csv is copied to bad_data.
# [ERROR] split_7390.csv: Invalid 'duration' values (Yes/No).
# split_7390.csv is copied to bad_data.
# split_1939.csv is copied to good_data.
# [ERROR] split_6930.csv: Premium travel_class found.
# [ERROR] split_6930.csv: Zero stops with duration > 20 hours.
# split_6930.csv is copied to bad_data.
# [ERROR] split_1087.csv: Air India flights with Vistara flight numbers.
# split_1087.csv is copied to bad_data.
# split_3848.csv is copied to good_data.
# [ERROR] split_3690.csv: Negative 'days_left' values.
# split_3690.csv is copied to bad_data.
# split_4114.csv is copied to good_data.
# [ERROR] split_2565.csv: Premium travel_class found.
# split_2565.csv is copied to bad_data.
# split_344.csv is copied to good_data.
# split_9430.csv is copied to good_data.
# split_6703.csv is copied to good_data.
# split_8048.csv is copied to good_data.
# split_9356.csv is copied to good_data.
# split_6065.csv is copied to good_data.
# [ERROR] split_422.csv: Blank price values in SpiceJet.
# split_422.csv is copied to bad_data.
# split_2203.csv is copied to good_data.
# split_4672.csv is copied to good_data.
# split_2217.csv is copied to good_data.
# split_5578.csv is copied to good_data.
# [ERROR] split_4666.csv: Zero stops with duration > 20 hours.
# split_4666.csv is copied to bad_data.
# split_3109.csv is copied to good_data.
# split_9342.csv is copied to good_data.
# split_6071.csv is copied to good_data.
# split_436.csv is copied to good_data.
# [ERROR] split_1078.csv: Zero stops with duration > 20 hours.
# split_1078.csv is copied to bad_data.
# split_350.csv is copied to good_data.
# split_9424.csv is copied to good_data.
# split_6717.csv is copied to good_data.
# [ERROR] split_7409.csv: Same source and destination cities.
# split_7409.csv is copied to bad_data.
# [ERROR] split_4100.csv: Zero stops with duration > 20 hours.
# split_4100.csv is copied to bad_data.
# split_2571.csv is copied to good_data.
# split_378.csv is copied to good_data.
# split_1050.csv is copied to good_data.
# split_7421.csv is copied to good_data.
# [ERROR] split_8712.csv: Same source and destination cities.
# split_8712.csv is copied to bad_data.
# split_3647.csv is copied to good_data.
# split_4128.csv is copied to good_data.
# split_5236.csv is copied to good_data.
# [ERROR] split_2559.csv: Air India flights with Vistara flight numbers.
# split_2559.csv is copied to bad_data.
# split_4896.csv is copied to good_data.
# split_5550.csv is copied to good_data.
# split_3121.csv is copied to good_data.
# split_7347.csv is copied to good_data.
# split_8074.csv is copied to good_data.
# split_6059.csv is copied to good_data.
# split_1736.csv is copied to good_data.
# [ERROR] split_7353.csv: Air India flights with Vistara flight numbers.
# split_7353.csv is copied to bad_data.
# [ERROR] split_8060.csv: Negative 'days_left' values.
# split_8060.csv is copied to bad_data.
# split_1722.csv is copied to good_data.
# [ERROR] split_4882.csv: Negative 'days_left' values.
# split_4882.csv is copied to bad_data.
# split_5544.csv is copied to good_data.
# split_3135.csv is copied to good_data.
# split_3653.csv is copied to good_data.
# split_5222.csv is copied to good_data.
# split_1044.csv is copied to good_data.
# split_9418.csv is copied to good_data.
# split_7435.csv is copied to good_data.
# [ERROR] split_8706.csv: Same source and destination cities.
# split_8706.csv is copied to bad_data.
# split_9587.csv is copied to good_data.
# [ERROR] split_8841.csv: Premium travel_class found.
# split_8841.csv is copied to bad_data.
# [ERROR] split_8699.csv: Invalid 'duration' values (Yes/No).
# split_8699.csv is copied to bad_data.
# split_3914.csv is copied to good_data.
# [ERROR] split_1865.csv: Negative 'days_left' values.
# split_1865.csv is copied to bad_data.
# split_595.csv is copied to good_data.
# split_1871.csv is copied to good_data.
# split_581.csv is copied to good_data.
# [ERROR] split_4909.csv: Invalid 'duration' values (Yes/No).
# split_4909.csv is copied to bad_data.
# split_3900.csv is copied to good_data.
# split_9593.csv is copied to good_data.
# split_8855.csv is copied to good_data.
# split_6878.csv is copied to good_data.
# split_3928.csv is copied to good_data.
# [ERROR] split_5381.csv: Same source and destination cities.
# split_5381.csv is copied to bad_data.
# [ERROR] split_6688.csv: Same source and destination cities.
# [ERROR] split_6688.csv: Air India flights with Vistara flight numbers.
# split_6688.csv is copied to bad_data.
# split_6850.csv is copied to good_data.
# split_7596.csv is copied to good_data.
# [ERROR] split_1859.csv: Premium travel_class found.
# split_1859.csv is copied to bad_data.
# [ERROR] split_1681.csv: Negative 'days_left' values.
# split_1681.csv is copied to bad_data.
# split_2388.csv is copied to good_data.
# split_4921.csv is copied to good_data.
# split_3096.csv is copied to good_data.
# [ERROR] split_4935.csv: Air India flights with Vistara flight numbers.
# split_4935.csv is copied to bad_data.
# split_3082.csv is copied to good_data.
# [ERROR] split_1695.csv: Blank price values in SpiceJet.
# split_1695.csv is copied to bad_data.
# split_8869.csv is copied to good_data.
# split_6844.csv is copied to good_data.
# split_7582.csv is copied to good_data.
# split_5395.csv is copied to good_data.
# [ERROR] split_2411.csv: Same source and destination cities.
# split_2411.csv is copied to bad_data.
# split_4060.csv is copied to good_data.
# split_7569.csv is copied to good_data.
# split_9544.csv is copied to good_data.
# split_6677.csv is copied to good_data.
# [ERROR] split_8882.csv: Same source and destination cities.
# split_8882.csv is copied to bad_data.
# split_1118.csv is copied to good_data.
# [ERROR] split_230.csv: Zero stops with duration > 20 hours.
# split_230.csv is copied to bad_data.
# split_556.csv is copied to good_data.
# split_9222.csv is copied to good_data.
# split_6111.csv is copied to good_data.
# [ERROR] split_3069.csv: Zero stops with duration > 20 hours.
# split_3069.csv is copied to bad_data.
# split_4706.csv is copied to good_data.
# split_5418.csv is copied to good_data.
# split_2377.csv is copied to good_data.
# split_4712.csv is copied to good_data.
# [ERROR] split_2363.csv: Air India flights with Vistara flight numbers.
# split_2363.csv is copied to bad_data.
# [ERROR] split_542.csv: Same source and destination cities.
# split_542.csv is copied to bad_data.
# split_9236.csv is copied to good_data.
# split_6105.csv is copied to good_data.
# split_8128.csv is copied to good_data.
# [ERROR] split_9550.csv: Invalid 'duration' values (Yes/No).
# split_9550.csv is copied to bad_data.
# split_6663.csv is copied to good_data.
# split_8896.csv is copied to good_data.
# split_224.csv is copied to good_data.
# split_2405.csv is copied to good_data.
# [ERROR] split_4074.csv: Air India flights with Vistara flight numbers.
# split_4074.csv is copied to bad_data.
# [ERROR] split_6893.csv: Negative 'days_left' values.
# split_6893.csv is copied to bad_data.
# split_7555.csv is copied to good_data.
# [ERROR] split_8666.csv: Premium travel_class found.
# split_8666.csv is copied to bad_data.
# split_9578.csv is copied to good_data.
# split_1124.csv is copied to good_data.
# split_5342.csv is copied to good_data.
# split_3733.csv is copied to good_data.
# split_3055.csv is copied to good_data.
# split_5424.csv is copied to good_data.
# split_1642.csv is copied to good_data.
# split_7233.csv is copied to good_data.
# [ERROR] split_8100.csv: Same source and destination cities.
# split_8100.csv is copied to bad_data.
# split_1656.csv is copied to good_data.
# [ERROR] split_6139.csv: Blank price values in SpiceJet.
# split_6139.csv is copied to bad_data.
# split_7227.csv is copied to good_data.
# split_8114.csv is copied to good_data.
# split_3041.csv is copied to good_data.
# split_5430.csv is copied to good_data.
# [ERROR] split_2439.csv: Zero stops with duration > 20 hours.
# split_2439.csv is copied to bad_data.
# [ERROR] split_5356.csv: Negative 'days_left' values.
# split_5356.csv is copied to bad_data.
# [ERROR] split_4048.csv: Same source and destination cities.
# split_4048.csv is copied to bad_data.
# split_3727.csv is copied to good_data.
# split_6887.csv is copied to good_data.
# split_7541.csv is copied to good_data.
# split_8672.csv is copied to good_data.
# [ERROR] split_218.csv: Premium travel_class found.
# split_218.csv is copied to bad_data.
# split_1130.csv is copied to good_data.
# split_797.csv is copied to good_data.
# [ERROR] split_5801.csv: Blank price values in SpiceJet.
# split_5801.csv is copied to bad_data.
# [ERROR] split_2808.csv: Blank price values in SpiceJet.
# split_2808.csv is copied to bad_data.
# split_7970.csv is copied to good_data.
# split_53.csv is copied to good_data.
# [ERROR] split_9785.csv: Same source and destination cities.
# split_9785.csv is copied to bad_data.
# split_9949.csv is copied to good_data.
# split_7964.csv is copied to good_data.
# split_47.csv is copied to good_data.
# split_9791.csv is copied to good_data.
# split_5815.csv is copied to good_data.
# split_783.csv is copied to good_data.
# split_3294.csv is copied to good_data.
# split_1483.csv is copied to good_data.
# [ERROR] split_973.csv: Air India flights with Vistara flight numbers.
# split_973.csv is copied to bad_data.
# split_7794.csv is copied to good_data.
# [ERROR] split_9961.csv: Air India flights with Vistara flight numbers.
# split_9961.csv is copied to bad_data.
# split_5183.csv is copied to good_data.
# [ERROR] split_2834.csv: Zero stops with duration > 20 hours.
# split_2834.csv is copied to bad_data.
# split_5197.csv is copied to good_data.
# split_4289.csv is copied to good_data.
# [ERROR] split_2820.csv: Blank price values in SpiceJet.
# split_2820.csv is copied to bad_data.
# split_7780.csv is copied to good_data.
# split_9975.csv is copied to good_data.
# split_7958.csv is copied to good_data.
# split_1497.csv is copied to good_data.
# [ERROR] split_967.csv: Negative 'days_left' values.
# [ERROR] split_967.csv: Invalid 'duration' values (Yes/No).
# split_967.csv is copied to bad_data.
# split_5829.csv is copied to good_data.
# split_3280.csv is copied to good_data.
# split_2175.csv is copied to good_data.
# split_4504.csv is copied to good_data.
# split_6313.csv is copied to good_data.
# split_9020.csv is copied to good_data.
# [ERROR] split_754.csv: Premium travel_class found.
# split_754.csv is copied to bad_data.
# [ERROR] split_90.csv: Negative 'days_left' values.
# split_90.csv is copied to bad_data.
# [ERROR] split_6475.csv: Blank price values in SpiceJet.
# split_6475.csv is copied to bad_data.
# [ERROR] split_9746.csv: Invalid 'duration' values (Yes/No).
# split_9746.csv is copied to bad_data.
# [ERROR] split_8458.csv: Invalid 'duration' values (Yes/No).
# split_8458.csv is copied to bad_data.
# split_4262.csv is copied to good_data.
# split_2613.csv is copied to good_data.
# split_3519.csv is copied to good_data.
# split_4276.csv is copied to good_data.
# split_5168.csv is copied to good_data.
# split_2607.csv is copied to good_data.
# [ERROR] split_84.csv: Zero stops with duration > 20 hours.
# split_84.csv is copied to bad_data.
# split_6461.csv is copied to good_data.
# [ERROR] split_9752.csv: Zero stops with duration > 20 hours.
# split_9752.csv is copied to bad_data.
# [ERROR] split_998.csv: Invalid 'duration' values (Yes/No).
# split_998.csv is copied to bad_data.
# split_7019.csv is copied to good_data.
# split_6307.csv is copied to good_data.
# [ERROR] split_9034.csv: Premium travel_class found.
# split_9034.csv is copied to bad_data.
# [ERROR] split_740.csv: Blank price values in SpiceJet.
# [ERROR] split_740.csv: Zero stops with duration > 20 hours.
# split_740.csv is copied to bad_data.
# split_1468.csv is copied to good_data.
# split_2161.csv is copied to good_data.
# split_4510.csv is copied to good_data.
# split_8302.csv is copied to good_data.
# split_7031.csv is copied to good_data.
# [ERROR] split_1440.csv: Invalid 'duration' values (Yes/No).
# [ERROR] split_1440.csv: Air India flights with Vistara flight numbers.
# split_1440.csv is copied to bad_data.
# split_768.csv is copied to good_data.
# split_2149.csv is copied to good_data.
# split_5626.csv is copied to good_data.
# [ERROR] split_4538.csv: Invalid 'duration' values (Yes/No).
# split_4538.csv is copied to bad_data.
# split_3257.csv is copied to good_data.
# split_3531.csv is copied to good_data.
# split_5140.csv is copied to good_data.
# split_1326.csv is copied to good_data.
# split_6449.csv is copied to good_data.
# [ERROR] split_8464.csv: Air India flights with Vistara flight numbers.
# split_8464.csv is copied to bad_data.
# split_7757.csv is copied to good_data.
# split_1332.csv is copied to good_data.
# split_8470.csv is copied to good_data.
# split_7743.csv is copied to good_data.
# [ERROR] split_3525.csv: Same source and destination cities.
# split_3525.csv is copied to bad_data.
# split_5154.csv is copied to good_data.
# split_5632.csv is copied to good_data.
# split_3243.csv is copied to good_data.
# split_8316.csv is copied to good_data.
# split_7025.csv is copied to good_data.
# split_9008.csv is copied to good_data.
# [ERROR] split_1454.csv: Zero stops with duration > 20 hours.
# split_1454.csv is copied to bad_data.
# [ERROR] split_5155.csv: Air India flights with Vistara flight numbers.
# split_5155.csv is copied to bad_data.
# split_3524.csv is copied to good_data.
# split_7742.csv is copied to good_data.
# [ERROR] split_8471.csv: Air India flights with Vistara flight numbers.
# split_8471.csv is copied to bad_data.
# split_1333.csv is copied to good_data.
# split_1455.csv is copied to good_data.
# [ERROR] split_9009.csv: Negative 'days_left' values.
# [ERROR] split_9009.csv: Invalid 'duration' values (Yes/No).
# split_9009.csv is copied to bad_data.
# split_7024.csv is copied to good_data.
# split_8317.csv is copied to good_data.
# [ERROR] split_3242.csv: Invalid 'duration' values (Yes/No).
# split_3242.csv is copied to bad_data.
# split_5633.csv is copied to good_data.
# [ERROR] split_3256.csv: Same source and destination cities.
# split_3256.csv is copied to bad_data.
# split_4539.csv is copied to good_data.
# split_5627.csv is copied to good_data.
# split_2148.csv is copied to good_data.
# split_769.csv is copied to good_data.
# split_1441.csv is copied to good_data.
# split_7030.csv is copied to good_data.
# split_8303.csv is copied to good_data.
# split_7756.csv is copied to good_data.
# split_8465.csv is copied to good_data.
# [ERROR] split_6448.csv: Blank price values in SpiceJet.
# [ERROR] split_6448.csv: Zero stops with duration > 20 hours.
# split_6448.csv is copied to bad_data.
# split_1327.csv is copied to good_data.
# split_5141.csv is copied to good_data.
# split_3530.csv is copied to good_data.
# split_9753.csv is copied to good_data.
# split_6460.csv is copied to good_data.
# [ERROR] split_85.csv: Blank price values in SpiceJet.
# split_85.csv is copied to bad_data.
# split_2606.csv is copied to good_data.
# [ERROR] split_5169.csv: Invalid 'duration' values (Yes/No).
# split_5169.csv is copied to bad_data.
# split_4277.csv is copied to good_data.
# split_3518.csv is copied to good_data.
# split_4511.csv is copied to good_data.
# split_2160.csv is copied to good_data.
# split_1469.csv is copied to good_data.
# [ERROR] split_741.csv: Premium travel_class found.
# split_741.csv is copied to bad_data.
# split_9035.csv is copied to good_data.
# split_6306.csv is copied to good_data.
# [ERROR] split_999.csv: Invalid 'duration' values (Yes/No).
# [ERROR] split_999.csv: Zero stops with duration > 20 hours.
# split_999.csv is copied to bad_data.
# split_7018.csv is copied to good_data.
# [ERROR] split_755.csv: Same source and destination cities.
# split_755.csv is copied to bad_data.
# split_9021.csv is copied to good_data.
# split_6312.csv is copied to good_data.
# split_4505.csv is copied to good_data.
# [ERROR] split_2174.csv: Same source and destination cities.
# split_2174.csv is copied to bad_data.
# [ERROR] split_2612.csv: Premium travel_class found.
# split_2612.csv is copied to bad_data.
# split_4263.csv is copied to good_data.
# split_8459.csv is copied to good_data.
# split_9747.csv is copied to good_data.
# split_6474.csv is copied to good_data.
# [ERROR] split_91.csv: Same source and destination cities.
# split_91.csv is copied to bad_data.
# split_7959.csv is copied to good_data.
# split_9974.csv is copied to good_data.
# split_7781.csv is copied to good_data.
# split_2821.csv is copied to good_data.
# [ERROR] split_4288.csv: Zero stops with duration > 20 hours.
# split_4288.csv is copied to bad_data.
# split_5196.csv is copied to good_data.
# split_3281.csv is copied to good_data.
# split_5828.csv is copied to good_data.
# split_966.csv is copied to good_data.
# split_1496.csv is copied to good_data.
# split_972.csv is copied to good_data.
# [ERROR] split_1482.csv: Blank price values in SpiceJet.
# split_1482.csv is copied to bad_data.
# split_3295.csv is copied to good_data.
# split_2835.csv is copied to good_data.
# [ERROR] split_5182.csv: Same source and destination cities.
# [ERROR] split_5182.csv: Air India flights with Vistara flight numbers.
# split_5182.csv is copied to bad_data.
# split_9960.csv is copied to good_data.
# split_7795.csv is copied to good_data.
# split_9790.csv is copied to good_data.
# [ERROR] split_46.csv: Premium travel_class found.
# split_46.csv is copied to bad_data.
# split_7965.csv is copied to good_data.
# split_9948.csv is copied to good_data.
# split_782.csv is copied to good_data.
# [ERROR] split_5814.csv: Same source and destination cities.
# split_5814.csv is copied to bad_data.
# split_5800.csv is copied to good_data.
# split_796.csv is copied to good_data.
# split_9784.csv is copied to good_data.
# [ERROR] split_52.csv: Air India flights with Vistara flight numbers.
# split_52.csv is copied to bad_data.
# split_7971.csv is copied to good_data.
# [ERROR] split_2809.csv: Same source and destination cities.
# split_2809.csv is copied to bad_data.
# [ERROR] split_5431.csv: Negative 'days_left' values.
# split_5431.csv is copied to bad_data.
# split_3040.csv is copied to good_data.
# split_8115.csv is copied to good_data.
# split_7226.csv is copied to good_data.
# [ERROR] split_6138.csv: Zero stops with duration > 20 hours.
# split_6138.csv is copied to bad_data.
# [ERROR] split_1657.csv: Same source and destination cities.
# split_1657.csv is copied to bad_data.
# split_1131.csv is copied to good_data.
# split_219.csv is copied to good_data.
# split_8673.csv is copied to good_data.
# split_7540.csv is copied to good_data.
# split_6886.csv is copied to good_data.
# [ERROR] split_3726.csv: Same source and destination cities.
# [ERROR] split_3726.csv: Premium travel_class found.
# split_3726.csv is copied to bad_data.
# [ERROR] split_4049.csv: Blank price values in SpiceJet.
# [ERROR] split_4049.csv: Zero stops with duration > 20 hours.
# split_4049.csv is copied to bad_data.
# [ERROR] split_5357.csv: Invalid 'duration' values (Yes/No).
# [ERROR] split_5357.csv: Zero stops with duration > 20 hours.
# split_5357.csv is copied to bad_data.
# [ERROR] split_2438.csv: Air India flights with Vistara flight numbers.
# split_2438.csv is copied to bad_data.
# split_3732.csv is copied to good_data.
# split_5343.csv is copied to good_data.
# split_1125.csv is copied to good_data.
# split_9579.csv is copied to good_data.
# split_8667.csv is copied to good_data.
# split_7554.csv is copied to good_data.
# [ERROR] split_6892.csv: Negative 'days_left' values.
# split_6892.csv is copied to bad_data.
# split_8101.csv is copied to good_data.
# split_7232.csv is copied to good_data.
# split_1643.csv is copied to good_data.
# [ERROR] split_5425.csv: Invalid 'duration' values (Yes/No).
# [ERROR] split_5425.csv: Zero stops with duration > 20 hours.
# split_5425.csv is copied to bad_data.
# split_3054.csv is copied to good_data.
# split_8129.csv is copied to good_data.
# split_6104.csv is copied to good_data.
# [ERROR] split_9237.csv: Invalid 'duration' values (Yes/No).
# split_9237.csv is copied to bad_data.
# split_543.csv is copied to good_data.
# split_2362.csv is copied to good_data.
# split_4713.csv is copied to good_data.
# split_4075.csv is copied to good_data.
# [ERROR] split_2404.csv: Zero stops with duration > 20 hours.
# split_2404.csv is copied to bad_data.
# [ERROR] split_225.csv: Blank price values in SpiceJet.
# split_225.csv is copied to bad_data.
# split_8897.csv is copied to good_data.
# split_6662.csv is copied to good_data.
# split_9551.csv is copied to good_data.
# split_231.csv is copied to good_data.
# [ERROR] split_8883.csv: Same source and destination cities.
# [ERROR] split_8883.csv: Invalid 'duration' values (Yes/No).
# split_8883.csv is copied to bad_data.
# [ERROR] split_1119.csv: Premium travel_class found.
# split_1119.csv is copied to bad_data.
# split_6676.csv is copied to good_data.
# split_9545.csv is copied to good_data.
# [ERROR] split_7568.csv: Air India flights with Vistara flight numbers.
# split_7568.csv is copied to bad_data.
# split_4061.csv is copied to good_data.
# split_2410.csv is copied to good_data.
# split_2376.csv is copied to good_data.
# split_5419.csv is copied to good_data.
# split_4707.csv is copied to good_data.
# split_3068.csv is copied to good_data.
# [ERROR] split_6110.csv: Same source and destination cities.
# split_6110.csv is copied to bad_data.
# split_9223.csv is copied to good_data.
# [ERROR] split_557.csv: Premium travel_class found.
# split_557.csv is copied to bad_data.
# [ERROR] split_1694.csv: Blank price values in SpiceJet.
# [ERROR] split_1694.csv: Zero stops with duration > 20 hours.
# split_1694.csv is copied to bad_data.
# [ERROR] split_3083.csv: Same source and destination cities.
# [ERROR] split_3083.csv: Invalid 'duration' values (Yes/No).
# split_3083.csv is copied to bad_data.
# split_4934.csv is copied to good_data.
# split_5394.csv is copied to good_data.
# split_7583.csv is copied to good_data.
# split_6845.csv is copied to good_data.
# split_8868.csv is copied to good_data.
# [ERROR] split_7597.csv: Zero stops with duration > 20 hours.
# split_7597.csv is copied to bad_data.
# [ERROR] split_6851.csv: Invalid 'duration' values (Yes/No).
# split_6851.csv is copied to bad_data.
# split_6689.csv is copied to good_data.
# split_5380.csv is copied to good_data.
# [ERROR] split_3929.csv: Same source and destination cities.
# [ERROR] split_3929.csv: Invalid 'duration' values (Yes/No).
# split_3929.csv is copied to bad_data.
# split_3097.csv is copied to good_data.
# split_4920.csv is copied to good_data.
# split_2389.csv is copied to good_data.
# split_1680.csv is copied to good_data.
# split_1858.csv is copied to good_data.
# split_4908.csv is copied to good_data.
# split_580.csv is copied to good_data.
# [ERROR] split_1870.csv: Negative 'days_left' values.
# split_1870.csv is copied to bad_data.
# [ERROR] split_6879.csv: Zero stops with duration > 20 hours.
# split_6879.csv is copied to bad_data.
# split_8854.csv is copied to good_data.
# [ERROR] split_9592.csv: Invalid 'duration' values (Yes/No).
# split_9592.csv is copied to bad_data.
# split_3901.csv is copied to good_data.
# [ERROR] split_3915.csv: Air India flights with Vistara flight numbers.
# split_3915.csv is copied to bad_data.
# split_8698.csv is copied to good_data.
# split_8840.csv is copied to good_data.
# split_9586.csv is copied to good_data.
# split_594.csv is copied to good_data.
# [ERROR] split_1864.csv: Premium travel_class found.
# split_1864.csv is copied to bad_data.
# split_3134.csv is copied to good_data.
# [ERROR] split_5545.csv: Negative 'days_left' values.
# split_5545.csv is copied to bad_data.
# split_4883.csv is copied to good_data.
# split_1723.csv is copied to good_data.
# [ERROR] split_8061.csv: Air India flights with Vistara flight numbers.
# split_8061.csv is copied to bad_data.
# split_7352.csv is copied to good_data.
# split_8707.csv is copied to good_data.
# split_7434.csv is copied to good_data.
# split_9419.csv is copied to good_data.
# split_1045.csv is copied to good_data.
# [ERROR] split_5223.csv: Invalid 'duration' values (Yes/No).
# [ERROR] split_5223.csv: Premium travel_class found.
# split_5223.csv is copied to bad_data.
# split_3652.csv is copied to good_data.
# [ERROR] split_2558.csv: Air India flights with Vistara flight numbers.
# split_2558.csv is copied to bad_data.
# [ERROR] split_5237.csv: Air India flights with Vistara flight numbers.
# split_5237.csv is copied to bad_data.
# [ERROR] split_4129.csv: Blank price values in SpiceJet.
# split_4129.csv is copied to bad_data.
# split_3646.csv is copied to good_data.
# [ERROR] split_8713.csv: Negative 'days_left' values.
# [ERROR] split_8713.csv: Air India flights with Vistara flight numbers.
# split_8713.csv is copied to bad_data.
# split_7420.csv is copied to good_data.
# split_1051.csv is copied to good_data.
# split_379.csv is copied to good_data.
# [ERROR] split_1737.csv: Premium travel_class found.
# [ERROR] split_1737.csv: Zero stops with duration > 20 hours.
# split_1737.csv is copied to bad_data.
# [ERROR] split_6058.csv: Air India flights with Vistara flight numbers.
# split_6058.csv is copied to bad_data.
# split_8075.csv is copied to good_data.
# split_7346.csv is copied to good_data.
# [ERROR] split_3120.csv: Negative 'days_left' values.
# split_3120.csv is copied to bad_data.
# split_5551.csv is copied to good_data.
# split_4897.csv is copied to good_data.
# split_437.csv is copied to good_data.
# [ERROR] split_6070.csv: Zero stops with duration > 20 hours.
# split_6070.csv is copied to bad_data.
# split_9343.csv is copied to good_data.
# split_3108.csv is copied to good_data.
# split_4667.csv is copied to good_data.
# [ERROR] split_5579.csv: Negative 'days_left' values.
# split_5579.csv is copied to bad_data.
# [ERROR] split_2216.csv: Negative 'days_left' values.
# split_2216.csv is copied to bad_data.
# split_2570.csv is copied to good_data.
# [ERROR] split_4101.csv: Invalid 'duration' values (Yes/No).
# split_4101.csv is copied to bad_data.
# [ERROR] split_7408.csv: Negative 'days_left' values.
# [ERROR] split_7408.csv: Air India flights with Vistara flight numbers.
# split_7408.csv is copied to bad_data.
# split_6716.csv is copied to good_data.
# split_9425.csv is copied to good_data.
# [ERROR] split_351.csv: Premium travel_class found.
# [ERROR] split_351.csv: Air India flights with Vistara flight numbers.
# split_351.csv is copied to bad_data.
# [ERROR] split_1079.csv: Same source and destination cities.
# split_1079.csv is copied to bad_data.
# split_6702.csv is copied to good_data.
# [ERROR] split_9431.csv: Premium travel_class found.
# split_9431.csv is copied to bad_data.
# split_345.csv is copied to good_data.
# split_2564.csv is copied to good_data.
# [ERROR] split_4115.csv: Blank price values in SpiceJet.
# split_4115.csv is copied to bad_data.
# [ERROR] split_4673.csv: Invalid 'duration' values (Yes/No).
# split_4673.csv is copied to bad_data.
# [ERROR] split_2202.csv: Zero stops with duration > 20 hours.
# split_2202.csv is copied to bad_data.
# [ERROR] split_423.csv: Air India flights with Vistara flight numbers.
# split_423.csv is copied to bad_data.
# [ERROR] split_6064.csv: Blank price values in SpiceJet.
# split_6064.csv is copied to bad_data.
# split_9357.csv is copied to good_data.
# split_8049.csv is copied to good_data.
# [ERROR] split_1938.csv: Premium travel_class found.
# split_1938.csv is copied to bad_data.
# [ERROR] split_7391.csv: Zero stops with duration > 20 hours.
# split_7391.csv is copied to bad_data.
# split_5586.csv is copied to good_data.
# split_4840.csv is copied to good_data.
# split_4698.csv is copied to good_data.
# split_3691.csv is copied to good_data.
# split_3849.csv is copied to good_data.
# split_1086.csv is copied to good_data.
# split_6931.csv is copied to good_data.
# split_8908.csv is copied to good_data.
# split_1092.csv is copied to good_data.
# split_6925.csv is copied to good_data.
# [ERROR] split_3685.csv: Premium travel_class found.
# [ERROR] split_3685.csv: Air India flights with Vistara flight numbers.
# split_3685.csv is copied to bad_data.
# split_5592.csv is copied to good_data.
# split_4854.csv is copied to good_data.
# split_7385.csv is copied to good_data.
# [ERROR] split_1904.csv: Invalid 'duration' values (Yes/No).
# split_1904.csv is copied to bad_data.
# [ERROR] split_9380.csv: Invalid 'duration' values (Yes/No).
# split_9380.csv is copied to bad_data.
# split_392.csv is copied to good_data.
# split_8920.csv is copied to good_data.
# [ERROR] split_3875.csv: Premium travel_class found.
# split_3875.csv is copied to bad_data.
# split_3861.csv is copied to good_data.
# [ERROR] split_386.csv: Same source and destination cities.
# split_386.csv is copied to bad_data.
# split_8934.csv is copied to good_data.
# [ERROR] split_6919.csv: Zero stops with duration > 20 hours.
# split_6919.csv is copied to bad_data.
# [ERROR] split_1910.csv: Premium travel_class found.
# split_1910.csv is copied to bad_data.
# split_9394.csv is copied to good_data.
# split_4868.csv is copied to good_data.
# split_3450.csv is copied to good_data.
# split_2996.csv is copied to good_data.
# [ERROR] split_5021.csv: Same source and destination cities.
# split_5021.csv is copied to bad_data.
# split_1247.csv is copied to good_data.
# split_6528.csv is copied to good_data.
# [ERROR] split_7636.csv: Air India flights with Vistara flight numbers.
# split_7636.csv is copied to bad_data.
# split_8505.csv is copied to good_data.
# split_7150.csv is copied to good_data.
# [ERROR] split_8263.csv: Zero stops with duration > 20 hours.
# split_8263.csv is copied to bad_data.
# [ERROR] split_609.csv: Invalid 'duration' values (Yes/No).
# split_609.csv is copied to bad_data.
# [ERROR] split_1521.csv: Same source and destination cities.
# split_1521.csv is copied to bad_data.
# split_2028.csv is copied to good_data.
# split_5747.csv is copied to good_data.
# [ERROR] split_4459.csv: Blank price values in SpiceJet.
# split_4459.csv is copied to bad_data.
# [ERROR] split_3336.csv: Invalid 'duration' values (Yes/No).
# split_3336.csv is copied to bad_data.
# split_5753.csv is copied to good_data.
# [ERROR] split_3322.csv: Zero stops with duration > 20 hours.
# split_3322.csv is copied to bad_data.
# [ERROR] split_7144.csv: Negative 'days_left' values.
# split_7144.csv is copied to bad_data.
# split_8277.csv is copied to good_data.
# split_9169.csv is copied to good_data.
# split_1535.csv is copied to good_data.
# split_1253.csv is copied to good_data.
# split_7622.csv is copied to good_data.
# split_8511.csv is copied to good_data.
# split_3444.csv is copied to good_data.
# [ERROR] split_2982.csv: Premium travel_class found.
# split_2982.csv is copied to bad_data.
# split_5035.csv is copied to good_data.
# split_153.csv is copied to good_data.
# split_9627.csv is copied to good_data.
# split_6514.csv is copied to good_data.
# [ERROR] split_8539.csv: Same source and destination cities.
# [ERROR] split_8539.csv: Invalid 'duration' values (Yes/No).
# split_8539.csv is copied to bad_data.
# split_4303.csv is copied to good_data.
# split_2772.csv is copied to good_data.
# split_2014.csv is copied to good_data.
# split_4465.csv is copied to good_data.
# split_9141.csv is copied to good_data.
# split_6272.csv is copied to good_data.
# split_635.csv is copied to good_data.
# [ERROR] split_7178.csv: Same source and destination cities.
# split_7178.csv is copied to bad_data.
# split_9155.csv is copied to good_data.
# [ERROR] split_6266.csv: Zero stops with duration > 20 hours.
# split_6266.csv is copied to bad_data.
# split_1509.csv is copied to good_data.
# split_621.csv is copied to good_data.
# [ERROR] split_2000.csv: Same source and destination cities.
# split_2000.csv is copied to bad_data.
# split_4471.csv is copied to good_data.
# split_3478.csv is copied to good_data.
# split_4317.csv is copied to good_data.
# split_5009.csv is copied to good_data.
# [ERROR] split_2766.csv: Negative 'days_left' values.
# split_2766.csv is copied to bad_data.
# split_147.csv is copied to good_data.
# split_9633.csv is copied to good_data.
# split_6500.csv is copied to good_data.
# split_9800.csv is copied to good_data.
# split_1284.csv is copied to good_data.
# [ERROR] split_3493.csv: Negative 'days_left' values.
# [ERROR] split_3493.csv: Zero stops with duration > 20 hours.
# split_3493.csv is copied to bad_data.
# [ERROR] split_2955.csv: Premium travel_class found.
# [ERROR] split_2955.csv: Air India flights with Vistara flight numbers.
# [ERROR] split_2955.csv: Zero stops with duration > 20 hours.
# split_2955.csv is copied to bad_data.
# split_5784.csv is copied to good_data.
# split_812.csv is copied to good_data.
# split_7193.csv is copied to good_data.
# split_6299.csv is copied to good_data.
# split_7187.csv is copied to good_data.
# [ERROR] split_806.csv: Same source and destination cities.
# split_806.csv is copied to bad_data.
# split_5948.csv is copied to good_data.
# split_5790.csv is copied to good_data.
# split_2799.csv is copied to good_data.
# split_3487.csv is copied to good_data.
# [ERROR] split_2941.csv: Negative 'days_left' values.
# [ERROR] split_2941.csv: Zero stops with duration > 20 hours.
# split_2941.csv is copied to bad_data.
# split_9814.csv is copied to good_data.
# split_7839.csv is copied to good_data.
# [ERROR] split_1290.csv: Blank price values in SpiceJet.
# split_1290.csv is copied to bad_data.
# split_2969.csv is copied to good_data.
# [ERROR] split_190.csv: Negative 'days_left' values.
# split_190.csv is copied to bad_data.
# split_7811.csv is copied to good_data.
# split_9182.csv is copied to good_data.
# split_5960.csv is copied to good_data.
# split_5974.csv is copied to good_data.
# split_9196.csv is copied to good_data.
# split_8288.csv is copied to good_data.
# split_9828.csv is copied to good_data.
# split_7805.csv is copied to good_data.
# split_184.csv is copied to good_data.
# split_5962.csv is copied to good_data.
# [ERROR] split_9180.csv: Invalid 'duration' values (Yes/No).
# split_9180.csv is copied to bad_data.
# [ERROR] split_7813.csv: Same source and destination cities.
# split_7813.csv is copied to bad_data.
# split_192.csv is copied to good_data.
# [ERROR] split_186.csv: Zero stops with duration > 20 hours.
# split_186.csv is copied to bad_data.
# [ERROR] split_7807.csv: Same source and destination cities.
# split_7807.csv is copied to bad_data.
# [ERROR] split_838.csv: Zero stops with duration > 20 hours.
# split_838.csv is copied to bad_data.
# [ERROR] split_9194.csv: Air India flights with Vistara flight numbers.
# split_9194.csv is copied to bad_data.
# split_5976.csv is copied to good_data.
# [ERROR] split_7191.csv: Negative 'days_left' values.
# split_7191.csv is copied to bad_data.
# split_810.csv is copied to good_data.
# [ERROR] split_5786.csv: Same source and destination cities.
# [ERROR] split_5786.csv: Zero stops with duration > 20 hours.
# split_5786.csv is copied to bad_data.
# [ERROR] split_4498.csv: Invalid 'duration' values (Yes/No).
# split_4498.csv is copied to bad_data.
# [ERROR] split_2957.csv: Negative 'days_left' values.
# split_2957.csv is copied to bad_data.
# [ERROR] split_3491.csv: Premium travel_class found.
# split_3491.csv is copied to bad_data.
# split_1286.csv is copied to good_data.
# split_9802.csv is copied to good_data.
# split_1292.csv is copied to good_data.
# split_9816.csv is copied to good_data.
# split_2943.csv is copied to good_data.
# [ERROR] split_3485.csv: Same source and destination cities.
# split_3485.csv is copied to bad_data.
# split_5792.csv is copied to good_data.
# [ERROR] split_804.csv: Air India flights with Vistara flight numbers.
# [ERROR] split_804.csv: Zero stops with duration > 20 hours.
# split_804.csv is copied to bad_data.
# split_7185.csv is copied to good_data.
# split_637.csv is copied to good_data.
# [ERROR] split_9143.csv: Same source and destination cities.
# split_9143.csv is copied to bad_data.
# [ERROR] split_6270.csv: Premium travel_class found.
# split_6270.csv is copied to bad_data.
# split_3308.csv is copied to good_data.
# split_4467.csv is copied to good_data.
# split_5779.csv is copied to good_data.
# split_2016.csv is copied to good_data.
# split_2770.csv is copied to good_data.
# split_4301.csv is copied to good_data.
# split_7608.csv is copied to good_data.
# split_9625.csv is copied to good_data.
# [ERROR] split_6516.csv: Premium travel_class found.
# split_6516.csv is copied to bad_data.
# split_1279.csv is copied to good_data.
# split_151.csv is copied to good_data.
# split_9631.csv is copied to good_data.
# split_6502.csv is copied to good_data.
# split_145.csv is copied to good_data.
# split_2764.csv is copied to good_data.
# [ERROR] split_4315.csv: Blank price values in SpiceJet.
# split_4315.csv is copied to bad_data.
# split_4473.csv is copied to good_data.
# [ERROR] split_2002.csv: Negative 'days_left' values.
# split_2002.csv is copied to bad_data.
# [ERROR] split_623.csv: Blank price values in SpiceJet.
# [ERROR] split_623.csv: Same source and destination cities.
# split_623.csv is copied to bad_data.
# split_9157.csv is copied to good_data.
# split_6264.csv is copied to good_data.
# split_8249.csv is copied to good_data.
# split_3334.csv is copied to good_data.
# split_5745.csv is copied to good_data.
# split_1523.csv is copied to good_data.
# [ERROR] split_7152.csv: Invalid 'duration' values (Yes/No).
# [ERROR] split_7152.csv: Premium travel_class found.
# [ERROR] split_7152.csv: Air India flights with Vistara flight numbers.
# split_7152.csv is copied to bad_data.
# split_8261.csv is copied to good_data.
# split_7634.csv is copied to good_data.
# split_8507.csv is copied to good_data.
# [ERROR] split_9619.csv: Invalid 'duration' values (Yes/No).
# split_9619.csv is copied to bad_data.
# [ERROR] split_1245.csv: Premium travel_class found.
# split_1245.csv is copied to bad_data.
# split_5023.csv is copied to good_data.
# split_2994.csv is copied to good_data.
# split_3452.csv is copied to good_data.
# split_2758.csv is copied to good_data.
# split_5037.csv is copied to good_data.
# split_2980.csv is copied to good_data.
# split_4329.csv is copied to good_data.
# split_3446.csv is copied to good_data.
# split_7620.csv is copied to good_data.
# [ERROR] split_8513.csv: Negative 'days_left' values.
# split_8513.csv is copied to bad_data.
# split_179.csv is copied to good_data.
# split_1251.csv is copied to good_data.
# split_1537.csv is copied to good_data.
# split_6258.csv is copied to good_data.
# split_7146.csv is copied to good_data.
# split_8275.csv is copied to good_data.
# [ERROR] split_3320.csv: Negative 'days_left' values.
# split_3320.csv is copied to bad_data.
# split_5989.csv is copied to good_data.
# split_5751.csv is copied to good_data.
# split_3877.csv is copied to good_data.
# split_390.csv is copied to good_data.
# split_8922.csv is copied to good_data.
# split_9382.csv is copied to good_data.
# split_1906.csv is copied to good_data.
# split_9396.csv is copied to good_data.
# split_1912.csv is copied to good_data.
# [ERROR] split_8088.csv: Negative 'days_left' values.
# split_8088.csv is copied to bad_data.
# [ERROR] split_384.csv: Same source and destination cities.
# [ERROR] split_384.csv: Zero stops with duration > 20 hours.
# split_384.csv is copied to bad_data.
# split_8936.csv is copied to good_data.
# [ERROR] split_3863.csv: Blank price values in SpiceJet.
# [ERROR] split_3863.csv: Invalid 'duration' values (Yes/No).
# split_3863.csv is copied to bad_data.
# split_6933.csv is copied to good_data.
# split_1084.csv is copied to good_data.
# split_3693.csv is copied to good_data.
# split_4842.csv is copied to good_data.
# split_5584.csv is copied to good_data.
# [ERROR] split_7393.csv: Invalid 'duration' values (Yes/No).
# split_7393.csv is copied to bad_data.
# split_6099.csv is copied to good_data.
# split_7387.csv is copied to good_data.
# split_4856.csv is copied to good_data.
# split_5590.csv is copied to good_data.
# [ERROR] split_2599.csv: Air India flights with Vistara flight numbers.
# split_2599.csv is copied to bad_data.
# split_3687.csv is copied to good_data.
# split_6927.csv is copied to good_data.
# split_1090.csv is copied to good_data.
# split_353.csv is copied to good_data.
# split_6714.csv is copied to good_data.
# split_9427.csv is copied to good_data.
# split_8739.csv is copied to good_data.
# [ERROR] split_4103.csv: Invalid 'duration' values (Yes/No).
# split_4103.csv is copied to bad_data.
# split_2572.csv is copied to good_data.
# split_2214.csv is copied to good_data.
# split_4665.csv is copied to good_data.
# split_6072.csv is copied to good_data.
# split_9341.csv is copied to good_data.
# split_435.csv is copied to good_data.
# split_7378.csv is copied to good_data.
# [ERROR] split_6066.csv: Blank price values in SpiceJet.
# [ERROR] split_6066.csv: Invalid 'duration' values (Yes/No).
# split_6066.csv is copied to bad_data.
# split_9355.csv is copied to good_data.
# [ERROR] split_421.csv: Zero stops with duration > 20 hours.
# split_421.csv is copied to bad_data.
# split_1709.csv is copied to good_data.
# split_2200.csv is copied to good_data.
# split_4671.csv is copied to good_data.
# split_3678.csv is copied to good_data.
# [ERROR] split_4117.csv: Blank price values in SpiceJet.
# split_4117.csv is copied to bad_data.
# split_5209.csv is copied to good_data.
# [ERROR] split_2566.csv: Invalid 'duration' values (Yes/No).
# split_2566.csv is copied to bad_data.
# split_347.csv is copied to good_data.
# split_6700.csv is copied to good_data.
# [ERROR] split_9433.csv: Premium travel_class found.
# split_9433.csv is copied to bad_data.
# split_3650.csv is copied to good_data.
# [ERROR] split_5221.csv: Air India flights with Vistara flight numbers.
# split_5221.csv is copied to bad_data.
# split_3888.csv is copied to good_data.
# split_1047.csv is copied to good_data.
# [ERROR] split_6728.csv: Same source and destination cities.
# [ERROR] split_6728.csv: Zero stops with duration > 20 hours.
# split_6728.csv is copied to bad_data.
# split_8705.csv is copied to good_data.
# split_7436.csv is copied to good_data.
# split_8063.csv is copied to good_data.
# split_7350.csv is copied to good_data.
# [ERROR] split_1721.csv: Premium travel_class found.
# split_1721.csv is copied to bad_data.
# [ERROR] split_409.csv: Invalid 'duration' values (Yes/No).
# split_409.csv is copied to bad_data.
# split_4881.csv is copied to good_data.
# [ERROR] split_2228.csv: Air India flights with Vistara flight numbers.
# split_2228.csv is copied to bad_data.
# split_5547.csv is copied to good_data.
# split_4659.csv is copied to good_data.
# split_3136.csv is copied to good_data.
# split_4895.csv is copied to good_data.
# split_5553.csv is copied to good_data.
# split_3122.csv is copied to good_data.
# [ERROR] split_8077.csv: Premium travel_class found.
# split_8077.csv is copied to bad_data.
# split_7344.csv is copied to good_data.
# [ERROR] split_9369.csv: Invalid 'duration' values (Yes/No).
# split_9369.csv is copied to bad_data.
# split_1735.csv is copied to good_data.
# split_1053.csv is copied to good_data.
# [ERROR] split_8711.csv: Invalid 'duration' values (Yes/No).
# split_8711.csv is copied to bad_data.
# split_7422.csv is copied to good_data.
# [ERROR] split_3644.csv: Blank price values in SpiceJet.
# split_3644.csv is copied to bad_data.
# split_5235.csv is copied to good_data.
# split_3903.csv is copied to good_data.
# split_9590.csv is copied to good_data.
# ...
# split_5171.csv is copied to bad_data.
# split_3500.csv is copied to good_data.
# split_5165.csv is copied to good_data.
# split_3514.csv is copied to good_data.
# split_7772.csv is copied to good_data.
# split_8441.csv is copied to good_data.
# split_9987.csv is copied to good_data.
# [ERROR] split_1303.csv: Blank price values in SpiceJet.
# [ERROR] split_1303.csv: Negative 'days_left' values.
# split_1303.csv is copied to bad_data.
# split_89.csv is copied to good_data.
# split_9039.csv is copied to good_data.
# split_1465.csv is copied to good_data.
# split_7014.csv is copied to good_data.
# split_995.csv is copied to good_data.
# split_8327.csv is copied to good_data.
# [ERROR] split_3272.csv: Zero stops with duration > 20 hours.
# split_3272.csv is copied to bad_data.
# split_5603.csv is copied to good_data.
# [ERROR] split_2187.csv: Blank price values in SpiceJet.
# [ERROR] split_2187.csv: Air India flights with Vistara flight numbers.
# split_2187.csv is copied to bad_data.
# split_5830.csv is copied to good_data.
# split_3299.csv is copied to good_data.
# [ERROR] split_62.csv: Zero stops with duration > 20 hours.
# split_62.csv is copied to bad_data.
# split_7941.csv is copied to good_data.
# split_6487.csv is copied to good_data.
# split_7799.csv is copied to good_data.
# split_4290.csv is copied to good_data.
# [ERROR] split_2839.csv: Blank price values in SpiceJet.
# [ERROR] split_2839.csv: Zero stops with duration > 20 hours.
# split_2839.csv is copied to bad_data.
# split_4284.csv is copied to good_data.
# split_76.csv is copied to good_data.
# [ERROR] split_7955.csv: Air India flights with Vistara flight numbers.
# split_7955.csv is copied to bad_data.
# [ERROR] split_6493.csv: Invalid 'duration' values (Yes/No).
# split_6493.csv is copied to bad_data.
# split_9978.csv is copied to good_data.
# split_2193.csv is copied to good_data.
# split_5824.csv is copied to good_data.
# [ERROR] split_942.csv: Zero stops with duration > 20 hours.
# split_942.csv is copied to bad_data.
# split_2805.csv is copied to good_data.
# [ERROR] split_9788.csv: Premium travel_class found.
# split_9788.csv is copied to bad_data.
# split_8496.csv is copied to good_data.
# split_9950.csv is copied to good_data.
# [ERROR] split_7969.csv: Negative 'days_left' values.
# split_7969.csv is copied to bad_data.
# split_8482.csv is copied to good_data.
# [ERROR] split_9944.csv: Same source and destination cities.
# split_9944.csv is copied to bad_data.
# split_2811.csv is copied to good_data.
# split_5818.csv is copied to good_data.
# split_956.csv is copied to good_data.
# split_6646.csv is copied to good_data.
# [ERROR] split_9575.csv: Negative 'days_left' values.
# split_9575.csv is copied to bad_data.
# [ERROR] split_201.csv: Blank price values in SpiceJet.
# split_201.csv is copied to bad_data.
# [ERROR] split_1129.csv: Invalid 'duration' values (Yes/No).
# split_1129.csv is copied to bad_data.
# split_7558.csv is copied to good_data.
# split_4051.csv is copied to good_data.
# [ERROR] split_2420.csv: Air India flights with Vistara flight numbers.
# split_2420.csv is copied to bad_data.
# split_5429.csv is copied to good_data.
# split_2346.csv is copied to good_data.
# split_3058.csv is copied to good_data.
# split_4737.csv is copied to good_data.
# split_1897.csv is copied to good_data.
# split_567.csv is copied to good_data.
# [ERROR] split_6120.csv: Blank price values in SpiceJet.
# split_6120.csv is copied to bad_data.
# [ERROR] split_9213.csv: Same source and destination cities.
# split_9213.csv is copied to bad_data.
# split_8119.csv is copied to good_data.
# split_1883.csv is copied to good_data.
# split_573.csv is copied to good_data.
# split_6134.csv is copied to good_data.
# split_9207.csv is copied to good_data.
# [ERROR] split_2352.csv: Invalid 'duration' values (Yes/No).
# split_2352.csv is copied to bad_data.
# split_4723.csv is copied to good_data.
# split_4045.csv is copied to good_data.
# split_2434.csv is copied to good_data.
# [ERROR] split_6652.csv: Same source and destination cities.
# split_6652.csv is copied to bad_data.
# split_9561.csv is copied to good_data.
# split_215.csv is copied to good_data.
# split_3702.csv is copied to good_data.
# split_5373.csv is copied to good_data.
# split_9549.csv is copied to good_data.
# split_1115.csv is copied to good_data.
# split_8657.csv is copied to good_data.
# split_7564.csv is copied to good_data.
# split_8131.csv is copied to good_data.
# split_7202.csv is copied to good_data.
# split_1673.csv is copied to good_data.
# split_5415.csv is copied to good_data.
# split_3064.csv is copied to good_data.
# split_5401.csv is copied to good_data.
# [ERROR] split_3070.csv: Zero stops with duration > 20 hours.
# split_3070.csv is copied to bad_data.
# [ERROR] split_8125.csv: Same source and destination cities.
# split_8125.csv is copied to bad_data.
# split_7216.csv is copied to good_data.
# split_1667.csv is copied to good_data.
# split_6108.csv is copied to good_data.
# split_1101.csv is copied to good_data.
# split_229.csv is copied to good_data.
# split_8643.csv is copied to good_data.
# split_7570.csv is copied to good_data.
# split_4079.csv is copied to good_data.
# split_3716.csv is copied to good_data.
# split_2408.csv is copied to good_data.
# split_5367.csv is copied to good_data.
# split_3925.csv is copied to good_data.
# split_4092.csv is copied to good_data.
# split_6685.csv is copied to good_data.
# split_8870.csv is copied to good_data.
# split_1854.csv is copied to good_data.
# split_2385.csv is copied to good_data.
# split_2391.csv is copied to good_data.
# split_4938.csv is copied to good_data.
# split_1698.csv is copied to good_data.
# split_1840.csv is copied to good_data.
# split_6849.csv is copied to good_data.
# split_6691.csv is copied to good_data.
# split_8864.csv is copied to good_data.
# [ERROR] split_3931.csv: Same source and destination cities.
# [ERROR] split_3931.csv: Zero stops with duration > 20 hours.
# split_3931.csv is copied to bad_data.
# split_5398.csv is copied to good_data.
# split_4086.csv is copied to good_data.
# split_6861.csv is copied to good_data.
# split_8694.csv is copied to good_data.
# split_3919.csv is copied to good_data.
# split_4910.csv is copied to good_data.
# split_598.csv is copied to good_data.
# split_1868.csv is copied to good_data.
# split_4904.csv is copied to good_data.
# split_6875.csv is copied to good_data.
# split_8680.csv is copied to good_data.
# split_8858.csv is copied to good_data.
# split_375.csv is copied to good_data.
# split_6732.csv is copied to good_data.
# split_9401.csv is copied to good_data.
# split_3892.csv is copied to good_data.
# [ERROR] split_2554.csv: Premium travel_class found.
# split_2554.csv is copied to bad_data.
# [ERROR] split_4125.csv: Negative 'days_left' values.
# [ERROR] split_4125.csv: Same source and destination cities.
# split_4125.csv is copied to bad_data.
# [ERROR] split_4643.csv: Negative 'days_left' values.
# split_4643.csv is copied to bad_data.
# split_2232.csv is copied to good_data.
# [ERROR] split_6054.csv: Negative 'days_left' values.
# split_6054.csv is copied to bad_data.
# split_9367.csv is copied to good_data.
# split_413.csv is copied to good_data.
# split_8079.csv is copied to good_data.
# split_6040.csv is copied to good_data.
# split_9373.csv is copied to good_data.
# split_407.csv is copied to good_data.
# [ERROR] split_4657.csv: Negative 'days_left' values.
# split_4657.csv is copied to bad_data.
# split_3138.csv is copied to good_data.
# split_2226.csv is copied to good_data.
# split_5549.csv is copied to good_data.
# split_3886.csv is copied to good_data.
# [ERROR] split_2540.csv: Zero stops with duration > 20 hours.
# split_2540.csv is copied to bad_data.
# [ERROR] split_4131.csv: Invalid 'duration' values (Yes/No).
# split_4131.csv is copied to bad_data.
# split_7438.csv is copied to good_data.
# split_361.csv is copied to good_data.
# [ERROR] split_1049.csv: Negative 'days_left' values.
# [ERROR] split_1049.csv: Zero stops with duration > 20 hours.
# split_1049.csv is copied to bad_data.
# split_6726.csv is copied to good_data.
# split_9415.csv is copied to good_data.
# split_5207.csv is copied to good_data.
# split_2568.csv is copied to good_data.
# split_3676.csv is copied to good_data.
# split_4119.csv is copied to good_data.
# [ERROR] split_8723.csv: Air India flights with Vistara flight numbers.
# split_8723.csv is copied to bad_data.
# [ERROR] split_7410.csv: Premium travel_class found.
# split_7410.csv is copied to bad_data.
# split_1061.csv is copied to good_data.
# split_349.csv is copied to good_data.
# split_6068.csv is copied to good_data.
# split_1707.csv is copied to good_data.
# split_8045.csv is copied to good_data.
# split_7376.csv is copied to good_data.
# split_3110.csv is copied to good_data.
# split_5561.csv is copied to good_data.
# split_3104.csv is copied to good_data.
# [ERROR] split_5575.csv: Premium travel_class found.
# split_5575.csv is copied to bad_data.
# [ERROR] split_1713.csv: Premium travel_class found.
# split_1713.csv is copied to bad_data.
# [ERROR] split_8051.csv: Air India flights with Vistara flight numbers.
# split_8051.csv is copied to bad_data.
# split_7362.csv is copied to good_data.
# split_8737.csv is copied to good_data.
# [ERROR] split_7404.csv: Premium travel_class found.
# split_7404.csv is copied to bad_data.
# split_1075.csv is copied to good_data.
# [ERROR] split_9429.csv: Invalid 'duration' values (Yes/No).
# split_9429.csv is copied to bad_data.
# split_5213.csv is copied to good_data.
# [ERROR] split_3662.csv: Air India flights with Vistara flight numbers.
# split_3662.csv is copied to bad_data.
# split_3689.csv is copied to good_data.
# [ERROR] split_3851.csv: Air India flights with Vistara flight numbers.
# split_3851.csv is copied to bad_data.
# [ERROR] split_2597.csv: Premium travel_class found.
# split_2597.csv is copied to bad_data.
# split_8904.csv is copied to good_data.
# split_6929.csv is copied to good_data.
# [ERROR] split_7389.csv: Same source and destination cities.
# split_7389.csv is copied to bad_data.
# split_1920.csv is copied to good_data.
# split_6097.csv is copied to good_data.
# split_4858.csv is copied to good_data.
# split_4680.csv is copied to good_data.
# [ERROR] split_4694.csv: Invalid 'duration' values (Yes/No).
# split_4694.csv is copied to bad_data.
# split_1934.csv is copied to good_data.
# split_6083.csv is copied to good_data.
# split_8910.csv is copied to good_data.
# [ERROR] split_3845.csv: Invalid 'duration' values (Yes/No).
# split_3845.csv is copied to bad_data.
# [ERROR] split_2583.csv: Invalid 'duration' values (Yes/No).
# split_2583.csv is copied to bad_data.
# split_8938.csv is copied to good_data.
# split_6915.csv is copied to good_data.
# split_4864.csv is copied to good_data.
# [ERROR] split_8086.csv: Negative 'days_left' values.
# split_8086.csv is copied to bad_data.
# split_9398.csv is copied to good_data.
# split_8092.csv is copied to good_data.
# split_1908.csv is copied to good_data.
# split_4870.csv is copied to good_data.
# split_3879.csv is copied to good_data.
# split_6901.csv is copied to good_data.
# split_7148.csv is copied to good_data.
# split_1539.csv is copied to good_data.
# split_611.csv is copied to good_data.
# split_9165.csv is copied to good_data.
# split_6256.csv is copied to good_data.
# [ERROR] split_2030.csv: Zero stops with duration > 20 hours.
# split_2030.csv is copied to bad_data.
# split_5987.csv is copied to good_data.
# split_4441.csv is copied to good_data.
# [ERROR] split_4327.csv: Premium travel_class found.
# split_4327.csv is copied to bad_data.
# [ERROR] split_3448.csv: Same source and destination cities.
# split_3448.csv is copied to bad_data.
# split_2756.csv is copied to good_data.
# [ERROR] split_5039.csv: Premium travel_class found.
# [ERROR] split_5039.csv: Air India flights with Vistara flight numbers.
# split_5039.csv is copied to bad_data.
# split_9603.csv is copied to good_data.
# split_6530.csv is copied to good_data.
# split_177.csv is copied to good_data.
# split_9617.csv is copied to good_data.
# split_6524.csv is copied to good_data.
# split_163.csv is copied to good_data.
# split_8509.csv is copied to good_data.
# [ERROR] split_4333.csv: Blank price values in SpiceJet.
# split_4333.csv is copied to bad_data.
# [ERROR] split_2742.csv: Premium travel_class found.
# split_2742.csv is copied to bad_data.
# split_2024.csv is copied to good_data.
# [ERROR] split_5993.csv: Premium travel_class found.
# split_5993.csv is copied to bad_data.
# [ERROR] split_4455.csv: Air India flights with Vistara flight numbers.
# split_4455.csv is copied to bad_data.
# [ERROR] split_605.csv: Blank price values in SpiceJet.
# split_605.csv is copied to bad_data.
# [ERROR] split_9171.csv: Negative 'days_left' values.
# [ERROR] split_9171.csv: Air India flights with Vistara flight numbers.
# split_9171.csv is copied to bad_data.
# split_6242.csv is copied to good_data.
# split_5763.csv is copied to good_data.
# [ERROR] split_3312.csv: Invalid 'duration' values (Yes/No).
# split_3312.csv is copied to bad_data.
# [ERROR] split_7174.csv: Negative 'days_left' values.
# [ERROR] split_7174.csv: Invalid 'duration' values (Yes/No).
# [ERROR] split_7174.csv: Air India flights with Vistara flight numbers.
# split_7174.csv is copied to bad_data.
# [ERROR] split_8247.csv: Premium travel_class found.
# split_8247.csv is copied to bad_data.
# split_1505.csv is copied to good_data.
# split_9159.csv is copied to good_data.
# split_1263.csv is copied to good_data.
# [ERROR] split_7612.csv: Zero stops with duration > 20 hours.
# split_7612.csv is copied to bad_data.
# split_8521.csv is copied to good_data.
# split_3474.csv is copied to good_data.
# split_5005.csv is copied to good_data.
# [ERROR] split_3460.csv: Blank price values in SpiceJet.
# [ERROR] split_3460.csv: Invalid 'duration' values (Yes/No).
# split_3460.csv is copied to bad_data.
# [ERROR] split_5011.csv: Same source and destination cities.
# split_5011.csv is copied to bad_data.
# split_6518.csv is copied to good_data.
# [ERROR] split_1277.csv: Same source and destination cities.
# split_1277.csv is copied to bad_data.
# split_7606.csv is copied to good_data.
# split_8535.csv is copied to good_data.
# [ERROR] split_7160.csv: Same source and destination cities.
# [ERROR] split_7160.csv: Invalid 'duration' values (Yes/No).
# split_7160.csv is copied to bad_data.
# [ERROR] split_8253.csv: Negative 'days_left' values.
# split_8253.csv is copied to bad_data.
# split_639.csv is copied to good_data.
# split_1511.csv is copied to good_data.
# split_5777.csv is copied to good_data.
# split_2018.csv is copied to good_data.
# split_3306.csv is copied to good_data.
# [ERROR] split_4469.csv: Blank price values in SpiceJet.
# split_4469.csv is copied to bad_data.
# split_5944.csv is copied to good_data.
# split_4482.csv is copied to good_data.
# [ERROR] split_6295.csv: Blank price values in SpiceJet.
# [ERROR] split_6295.csv: Zero stops with duration > 20 hours.
# split_6295.csv is copied to bad_data.
# split_9818.csv is copied to good_data.
# split_7835.csv is copied to good_data.
# split_2795.csv is copied to good_data.
# split_2781.csv is copied to good_data.
# split_2959.csv is copied to good_data.
# [ERROR] split_1288.csv: Air India flights with Vistara flight numbers.
# split_1288.csv is copied to bad_data.
# split_7821.csv is copied to good_data.
# [ERROR] split_6281.csv: Blank price values in SpiceJet.
# split_6281.csv is copied to bad_data.
# split_5950.csv is copied to good_data.
# [ERROR] split_4496.csv: Blank price values in SpiceJet.
# split_4496.csv is copied to bad_data.
# [ERROR] split_5788.csv: Premium travel_class found.
# split_5788.csv is copied to bad_data.
# split_836.csv is copied to good_data.
# [ERROR] split_8284.csv: Negative 'days_left' values.
# split_8284.csv is copied to bad_data.
# [ERROR] split_5978.csv: Same source and destination cities.
# split_5978.csv is copied to bad_data.
# [ERROR] split_2971.csv: Blank price values in SpiceJet.
# [ERROR] split_2971.csv: Negative 'days_left' values.
# split_2971.csv is copied to bad_data.
# split_9824.csv is copied to good_data.
# [ERROR] split_188.csv: Negative 'days_left' values.
# split_188.csv is copied to bad_data.
# split_7809.csv is copied to good_data.
# split_9830.csv is copied to good_data.
# split_2965.csv is copied to good_data.
# split_822.csv is copied to good_data.
# split_8290.csv is copied to good_data.
#
# Total files processed: 10000
# Files copied to bad_data: 2909
# Files copied to good_data: 7091
# Files skipped due to errors: 0
