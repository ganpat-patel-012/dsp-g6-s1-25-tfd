# %%
import os
import pandas as pd
import shutil

# Define folder paths
folder_A = "Folder_A"
bad_data_folder = "Folder_B"
good_data_folder = "Folder_C"

# Create directories
os.makedirs(good_data_folder, exist_ok=True)
os.makedirs(bad_data_folder, exist_ok=True)

def check_errors(df, file):
    """
    Check if the dataset contains any introduced errors.
    Returns True if errors are found, otherwise False.
    """
    error_found = False

    # Check for blank price values in SpiceJet
    if df[(df['airline'] == 'SpiceJet') & (df['price'].isna())].shape[0] > 0:
        error_found = True
        print(f"[ERROR] {file}: Blank price values in SpiceJet.")
    
    # Check for negative days_left values
    if df[df['days_left'] < 0].shape[0] > 0:
        error_found = True
        print(f"[ERROR] {file}: Negative 'days_left' values.")
    
    # Check for same source and destination cities
    if df[df['source_city'] == df['destination_city']].shape[0] > 0:
        error_found = True
        print(f"[ERROR] {file}: Same source and destination cities.")
    
    # Check for Yes/No in duration
    if df[df['duration'].astype(str).isin(['Yes', 'No'])].shape[0] > 0:
        error_found = True
        print(f"[ERROR] {file}: Invalid 'duration' values (Yes/No).")
    
    # Check for Premium class
    if df[df['class'] == 'Premium'].shape[0] > 0:
        error_found = True
        print(f"[ERROR] {file}: Premium class found.")
    
    # Check for Air India flights with Vistara flight numbers
    # Ensure 'flight' column is treated as a string to prevent errors
    df['flight'] = df['flight'].astype(str)
    if df[(df['airline'] == 'Air_India') & (df['flight'].str.startswith('UK-'))].shape[0] > 0:
        error_found = True
        print(f"[ERROR] {file}: Air India flights with Vistara flight numbers.")
    
    # Check for zero stops with duration > 20 hours
    temp_duration = pd.to_numeric(df['duration'], errors='coerce')  # Convert to numeric
    if df[(df['stops'] == 'zero') & (temp_duration > 20)].shape[0] > 0:
        error_found = True
        print(f"[ERROR] {file}: Zero stops with duration > 20 hours.")

    return error_found

# Get the list of visible .csv files in Folder_A, excluding hidden files
files = [f for f in os.listdir(folder_A) if f.endswith(".csv") and not f.startswith(".")]

# Process each file and track the results
bad_data_count = 0
good_data_count = 0
skipped_files = []

# Start processing each file
for file in files:
    file_path = os.path.join(folder_A, file)
    
    try:
        # Attempt to read the CSV file
        df = pd.read_csv(file_path)

        # Check for errors in the data
        if check_errors(df, file):
            # Copy the file to bad_data folder
            shutil.copy(file_path, os.path.join(bad_data_folder, file))
            bad_data_count += 1
            print(f"{file} is copied to bad_data.")
        else:
            # Copy the file to good_data folder
            shutil.copy(file_path, os.path.join(good_data_folder, file))
            good_data_count += 1
            print(f"{file} is copied to good_data.")

    except Exception as e:
        # Log the error and skip the file
        skipped_files.append(file)
        print(f"[ERROR] Could not process {file}: {e}")

# Final summary
print(f"\nTotal files processed: {len(files)}")
print(f"Files copied to bad_data: {bad_data_count}")
print(f"Files copied to good_data: {good_data_count}")
print(f"Files skipped due to errors: {len(skipped_files)}")
# Out:
# [ERROR] split_28768.csv: Invalid 'duration' values (Yes/No).
# split_28768.csv is copied to bad_data.
# split_8289.csv is copied to good_data.
# split_20334.csv is copied to good_data.
# split_17598.csv is copied to good_data.
# split_16686.csv is copied to good_data.
# split_29476.csv is copied to good_data.
# split_26745.csv is copied to good_data.
# split_18873.csv is copied to good_data.
# split_9197.csv is copied to good_data.
# split_13926.csv is copied to good_data.
# split_22523.csv is copied to good_data.
# split_14091.csv is copied to good_data.
# split_5975.csv is copied to good_data.
# [ERROR] split_24152.csv: Premium class found.
# split_24152.csv is copied to bad_data.
# split_24634.csv is copied to good_data.
# split_13098.csv is copied to good_data.
# split_22245.csv is copied to good_data.
# split_12386.csv is copied to good_data.
# split_29310.csv is copied to good_data.
# [ERROR] split_26023.csv: Negative 'days_left' values.
# split_26023.csv is copied to bad_data.
# split_7804.csv is copied to good_data.
# [ERROR] split_185.csv: Invalid 'duration' values (Yes/No).
# split_185.csv is copied to bad_data.
# [ERROR] split_20452.csv: Negative 'days_left' values.
# split_20452.csv is copied to bad_data.
# split_9829.csv is copied to good_data.
# split_11857.csv is copied to good_data.
# split_21994.csv is copied to good_data.
# split_10591.csv is copied to good_data.
# split_29304.csv is copied to good_data.
# split_26037.csv is copied to good_data.
# split_21758.csv is copied to good_data.
# split_191.csv is copied to good_data.
# split_7810.csv is copied to good_data.
# split_20446.csv is copied to good_data.
# split_11843.csv is copied to good_data.
# split_21980.csv is copied to good_data.
# split_27329.csv is copied to good_data.
# split_10585.csv is copied to good_data.
# split_2968.csv is copied to good_data.
# split_24620.csv is copied to good_data.
# split_22251.csv is copied to good_data.
# split_12392.csv is copied to good_data.
# split_25258.csv is copied to good_data.
# split_13932.csv is copied to good_data.
# split_22537.csv is copied to good_data.
# split_23629.csv is copied to good_data.
# split_14085.csv is copied to good_data.
# [ERROR] split_5961.csv: Premium class found.
# split_5961.csv is copied to bad_data.
# split_24146.csv is copied to good_data.
# split_20320.csv is copied to good_data.
# split_26989.csv is copied to good_data.
# [ERROR] split_16692.csv: Same source and destination cities.
# split_16692.csv is copied to bad_data.
# split_29462.csv is copied to good_data.
# [ERROR] split_18867.csv: Premium class found.
# split_18867.csv is copied to bad_data.
# split_9183.csv is copied to good_data.
# [ERROR] split_26751.csv: Same source and destination cities.
# split_26751.csv is copied to bad_data.
# [ERROR] split_5791.csv: Premium class found.
# split_5791.csv is copied to bad_data.
# split_25270.csv is copied to good_data.
# split_5949.csv is copied to good_data.
# split_23601.csv is copied to good_data.
# [ERROR] split_27467.csv: Invalid 'duration' values (Yes/No).
# split_27467.csv is copied to bad_data.
# split_16862.csv is copied to good_data.
# split_7186.csv is copied to good_data.
# split_28754.csv is copied to good_data.
# [ERROR] split_807.csv: Same source and destination cities.
# split_807.csv is copied to bad_data.
# split_18697.csv is copied to good_data.
# [ERROR] split_20308.csv: Negative 'days_left' values.
# [ERROR] split_20308.csv: Same source and destination cities.
# split_20308.csv is copied to bad_data.
# split_19589.csv is copied to good_data.
# split_21016.csv is copied to good_data.
# split_26779.csv is copied to good_data.
# split_6298.csv is copied to good_data.
# [ERROR] split_1291.csv: Invalid 'duration' values (Yes/No).
# split_1291.csv is copied to bad_data.
# split_7838.csv is copied to good_data.
# split_21770.csv is copied to good_data.
# split_9815.csv is copied to good_data.
# split_27301.csv is copied to good_data.
# split_28032.csv is copied to good_data.
# split_24608.csv is copied to good_data.
# split_2940.csv is copied to good_data.
# split_23167.csv is copied to good_data.
# split_3486.csv is copied to good_data.
# split_22279.csv is copied to good_data.
# [ERROR] split_2798.csv: Zero stops with duration > 20 hours.
# split_2798.csv is copied to bad_data.
# split_14913.csv is copied to good_data.
# split_25516.csv is copied to good_data.
# split_2954.csv is copied to good_data.
# split_23173.csv is copied to good_data.
# [ERROR] split_3492.csv: Invalid 'duration' values (Yes/No).
# split_3492.csv is copied to bad_data.
# split_14907.csv is copied to good_data.
# split_25502.csv is copied to good_data.
# [ERROR] split_29338.csv: Invalid 'duration' values (Yes/No).
# split_29338.csv is copied to bad_data.
# split_1285.csv is copied to good_data.
# [ERROR] split_21764.csv: Air India flights with Vistara flight numbers.
# split_21764.csv is copied to bad_data.
# split_9801.csv is copied to good_data.
# split_27315.csv is copied to good_data.
# split_28026.csv is copied to good_data.
# split_27473.csv is copied to good_data.
# split_813.csv is copied to good_data.
# split_28740.csv is copied to good_data.
# split_16876.csv is copied to good_data.
# split_7192.csv is copied to good_data.
# split_18683.csv is copied to good_data.
# [ERROR] split_21002.csv: Air India flights with Vistara flight numbers.
# split_21002.csv is copied to bad_data.
# [ERROR] split_28998.csv: Invalid 'duration' values (Yes/No).
# split_28998.csv is copied to bad_data.
# split_5785.csv is copied to good_data.
# split_25264.csv is copied to good_data.
# split_23615.csv is copied to good_data.
# split_14052.csv is copied to good_data.
# split_24191.csv is copied to good_data.
# split_4470.csv is copied to good_data.
# split_12423.csv is copied to good_data.
# split_23826.csv is copied to good_data.
# split_2001.csv is copied to good_data.
# [ERROR] split_620.csv: Invalid 'duration' values (Yes/No).
# split_620.csv is copied to bad_data.
# split_28973.csv is copied to good_data.
# split_16645.csv is copied to good_data.
# split_19576.csv is copied to good_data.
# split_1508.csv is copied to good_data.
# [ERROR] split_6267.csv: Blank price values in SpiceJet.
# split_6267.csv is copied to bad_data.
# split_26786.csv is copied to good_data.
# split_9154.csv is copied to good_data.
# split_7179.csv is copied to good_data.
# split_27498.csv is copied to good_data.
# split_10234.csv is copied to good_data.
# split_18668.csv is copied to good_data.
# split_20491.csv is copied to good_data.
# split_11894.csv is copied to good_data.
# split_21957.csv is copied to good_data.
# [ERROR] split_10552.csv: Invalid 'duration' values (Yes/No).
# split_10552.csv is copied to bad_data.
# split_6501.csv is copied to good_data.
# [ERROR] split_9632.csv: Blank price values in SpiceJet.
# split_9632.csv is copied to bad_data.
# split_146.csv is copied to good_data.
# [ERROR] split_16123.csv: Air India flights with Vistara flight numbers.
# split_16123.csv is copied to bad_data.
# split_19210.csv is copied to good_data.
# [ERROR] split_2767.csv: Same source and destination cities.
# split_2767.csv is copied to bad_data.
# split_22286.csv is copied to good_data.
# split_12345.csv is copied to good_data.
# [ERROR] split_5008.csv: Negative 'days_left' values.
# split_5008.csv is copied to bad_data.
# [ERROR] split_4316.csv: Zero stops with duration > 20 hours.
# split_4316.csv is copied to bad_data.
# split_3479.csv is copied to good_data.
# split_23198.csv is copied to good_data.
# split_14734.csv is copied to good_data.
# split_2773.csv is copied to good_data.
# split_22292.csv is copied to good_data.
# split_12351.csv is copied to good_data.
# split_4302.csv is copied to good_data.
# split_14720.csv is copied to good_data.
# split_20485.csv is copied to good_data.
# split_17229.csv is copied to good_data.
# split_11880.csv is copied to good_data.
# split_21943.csv is copied to good_data.
# split_10546.csv is copied to good_data.
# [ERROR] split_8538.csv: Zero stops with duration > 20 hours.
# split_8538.csv is copied to bad_data.
# split_6515.csv is copied to good_data.
# split_9626.csv is copied to good_data.
# split_11658.csv is copied to good_data.
# split_16137.csv is copied to good_data.
# [ERROR] split_152.csv: Zero stops with duration > 20 hours.
# split_152.csv is copied to bad_data.
# split_19204.csv is copied to good_data.
# split_16651.csv is copied to good_data.
# split_28967.csv is copied to good_data.
# split_634.csv is copied to good_data.
# split_19562.csv is copied to good_data.
# split_6273.csv is copied to good_data.
# split_9140.csv is copied to good_data.
# split_26792.csv is copied to good_data.
# split_16889.csv is copied to good_data.
# split_10220.csv is copied to good_data.
# [ERROR] split_14046.csv: Invalid 'duration' values (Yes/No).
# split_14046.csv is copied to bad_data.
# split_24185.csv is copied to good_data.
# [ERROR] split_13729.csv: Zero stops with duration > 20 hours.
# split_13729.csv is copied to bad_data.
# split_4464.csv is copied to good_data.
# split_12437.csv is copied to good_data.
# split_23832.csv is copied to good_data.
# [ERROR] split_2015.csv: Premium class found.
# split_2015.csv is copied to bad_data.
# split_15358.csv is copied to good_data.
# split_1534.csv is copied to good_data.
# split_16679.csv is copied to good_data.
# split_11116.csv is copied to good_data.
# split_9168.csv is copied to good_data.
# split_29489.csv is copied to good_data.
# split_8276.csv is copied to good_data.
# split_10208.csv is copied to good_data.
# split_7145.csv is copied to good_data.
# split_28797.csv is copied to good_data.
# [ERROR] split_18654.csv: Premium class found.
# split_18654.csv is copied to bad_data.
# [ERROR] split_26962.csv: Negative 'days_left' values.
# split_26962.csv is copied to bad_data.
# split_17567.csv is copied to good_data.
# split_3323.csv is copied to good_data.
# split_13701.csv is copied to good_data.
# split_5752.csv is copied to good_data.
# split_15370.csv is copied to good_data.
# split_15416.csv is copied to good_data.
# split_24813.csv is copied to good_data.
# split_5034.csv is copied to good_data.
# [ERROR] split_12379.csv: Zero stops with duration > 20 hours.
# split_12379.csv is copied to bad_data.
# split_13067.csv is copied to good_data.
# [ERROR] split_2983.csv: Negative 'days_left' values.
# split_2983.csv is copied to bad_data.
# split_14708.csv is copied to good_data.
# [ERROR] split_3445.csv: Invalid 'duration' values (Yes/No).
# split_3445.csv is copied to bad_data.
# [ERROR] split_18132.csv: Blank price values in SpiceJet.
# [ERROR] split_18132.csv: Same source and destination cities.
# split_18132.csv is copied to bad_data.
# split_17201.csv is copied to good_data.
# split_8510.csv is copied to good_data.
# split_7623.csv is copied to good_data.
# split_11670.csv is copied to good_data.
# split_1252.csv is copied to good_data.
# split_18126.csv is copied to good_data.
# split_17215.csv is copied to good_data.
# [ERROR] split_8504.csv: Blank price values in SpiceJet.
# split_8504.csv is copied to bad_data.
# split_7637.csv is copied to good_data.
# [ERROR] split_11664.csv: Negative 'days_left' values.
# split_11664.csv is copied to bad_data.
# split_6529.csv is copied to good_data.
# split_1246.csv is copied to good_data.
# split_19238.csv is copied to good_data.
# split_15402.csv is copied to good_data.
# split_24807.csv is copied to good_data.
# split_5020.csv is copied to good_data.
# split_13073.csv is copied to good_data.
# split_2997.csv is copied to good_data.
# split_3451.csv is copied to good_data.
# split_3337.csv is copied to good_data.
# [ERROR] split_4458.csv: Blank price values in SpiceJet.
# [ERROR] split_4458.csv: Premium class found.
# split_4458.csv is copied to bad_data.
# split_13715.csv is copied to good_data.
# split_5746.csv is copied to good_data.
# split_15364.csv is copied to good_data.
# [ERROR] split_2029.csv: Same source and destination cities.
# split_2029.csv is copied to bad_data.
# split_1520.csv is copied to good_data.
# split_608.csv is copied to good_data.
# split_18898.csv is copied to good_data.
# [ERROR] split_11102.csv: Negative 'days_left' values.
# split_11102.csv is copied to bad_data.
# split_8262.csv is copied to good_data.
# [ERROR] split_28783.csv: Air India flights with Vistara flight numbers.
# split_28783.csv is copied to bad_data.
# [ERROR] split_7151.csv: Invalid 'duration' values (Yes/No).
# split_7151.csv is copied to bad_data.
# split_26976.csv is copied to good_data.
# split_18640.csv is copied to good_data.
# split_17573.csv is copied to good_data.
# [ERROR] split_10793.csv: Invalid 'duration' values (Yes/No).
# split_10793.csv is copied to bad_data.
# [ERROR] split_6918.csv: Premium class found.
# split_6918.csv is copied to bad_data.
# split_20650.csv is copied to good_data.
# [ERROR] split_8935.csv: Negative 'days_left' values.
# split_8935.csv is copied to bad_data.
# split_387.csv is copied to good_data.
# split_26221.csv is copied to good_data.
# split_29112.csv is copied to good_data.
# split_20888.csv is copied to good_data.
# split_25728.csv is copied to good_data.
# [ERROR] split_12184.csv: Negative 'days_left' values.
# split_12184.csv is copied to bad_data.
# [ERROR] split_3860.csv: Same source and destination cities.
# split_3860.csv is copied to bad_data.
# split_22047.csv is copied to good_data.
# split_23359.csv is copied to good_data.
# split_15833.csv is copied to good_data.
# split_24436.csv is copied to good_data.
# [ERROR] split_24350.csv: Premium class found.
# split_24350.csv is copied to bad_data.
# split_14293.csv is copied to good_data.
# split_4869.csv is copied to good_data.
# split_22721.csv is copied to good_data.
# [ERROR] split_9395.csv: Negative 'days_left' values.
# split_9395.csv is copied to bad_data.
# split_26547.csv is copied to good_data.
# split_17942.csv is copied to good_data.
# split_29674.csv is copied to good_data.
# split_27881.csv is copied to good_data.
# split_21228.csv is copied to good_data.
# split_16484.csv is copied to good_data.
# split_20136.csv is copied to good_data.
# [ERROR] split_27659.csv: Same source and destination cities.
# [ERROR] split_27659.csv: Air India flights with Vistara flight numbers.
# split_27659.csv is copied to bad_data.
# split_1911.csv is copied to good_data.
# split_26553.csv is copied to good_data.
# [ERROR] split_9381.csv: Air India flights with Vistara flight numbers.
# split_9381.csv is copied to bad_data.
# split_29660.csv is copied to good_data.
# [ERROR] split_17956.csv: Zero stops with duration > 20 hours.
# split_17956.csv is copied to bad_data.
# split_27895.csv is copied to good_data.
# split_16490.csv is copied to good_data.
# split_20122.csv is copied to good_data.
# split_1905.csv is copied to good_data.
# [ERROR] split_24344.csv: Same source and destination cities.
# split_24344.csv is copied to bad_data.
# split_14287.csv is copied to good_data.
# split_22735.csv is copied to good_data.
# [ERROR] split_15199.csv: Invalid 'duration' values (Yes/No).
# split_15199.csv is copied to bad_data.
# split_12190.csv is copied to good_data.
# split_3874.csv is copied to good_data.
# split_22053.csv is copied to good_data.
# split_15827.csv is copied to good_data.
# split_24422.csv is copied to good_data.
# split_10787.csv is copied to good_data.
# split_28218.csv is copied to good_data.
# split_20644.csv is copied to good_data.
# [ERROR] split_8921.csv: Same source and destination cities.
# split_8921.csv is copied to bad_data.
# split_393.csv is copied to good_data.
# split_26235.csv is copied to good_data.
# split_11499.csv is copied to good_data.
# split_29106.csv is copied to good_data.
# split_25714.csv is copied to good_data.
# split_3684.csv is copied to good_data.
# split_23365.csv is copied to good_data.
# split_28230.csv is copied to good_data.
# split_27103.csv is copied to good_data.
# split_6924.csv is copied to good_data.
# split_21572.csv is copied to good_data.
# split_8909.csv is copied to good_data.
# split_10977.csv is copied to good_data.
# split_1093.csv is copied to good_data.
# split_29648.csv is copied to good_data.
# split_21214.csv is copied to good_data.
# split_29890.csv is copied to good_data.
# split_18495.csv is copied to good_data.
# split_28556.csv is copied to good_data.
# [ERROR] split_7384.csv: Invalid 'duration' values (Yes/No).
# split_7384.csv is copied to bad_data.
# split_27665.csv is copied to good_data.
# split_19953.csv is copied to good_data.
# split_12806.csv is copied to good_data.
# split_23403.csv is copied to good_data.
# split_4855.csv is copied to good_data.
# [ERROR] split_25072.csv: Same source and destination cities.
# split_25072.csv is copied to bad_data.
# [ERROR] split_5593.csv: Negative 'days_left' values.
# split_5593.csv is copied to bad_data.
# split_24378.csv is copied to good_data.
# split_4699.csv is copied to good_data.
# [ERROR] split_12812.csv: Premium class found.
# [ERROR] split_12812.csv: Air India flights with Vistara flight numbers.
# split_12812.csv is copied to bad_data.
# split_23417.csv is copied to good_data.
# split_22709.csv is copied to good_data.
# split_4841.csv is copied to good_data.
# split_25066.csv is copied to good_data.
# [ERROR] split_5587.csv: Same source and destination cities.
# split_5587.csv is copied to bad_data.
# split_21200.csv is copied to good_data.
# split_29884.csv is copied to good_data.
# split_18481.csv is copied to good_data.
# split_7390.csv is copied to good_data.
# split_28542.csv is copied to good_data.
# split_1939.csv is copied to good_data.
# split_19947.csv is copied to good_data.
# split_27671.csv is copied to good_data.
# split_28224.csv is copied to good_data.
# split_27117.csv is copied to good_data.
# split_20678.csv is copied to good_data.
# split_6930.csv is copied to good_data.
# split_21566.csv is copied to good_data.
# split_10963.csv is copied to good_data.
# split_1087.csv is copied to good_data.
# split_26209.csv is copied to good_data.
# split_3848.csv is copied to good_data.
# split_25700.csv is copied to good_data.
# split_3690.csv is copied to good_data.
# split_23371.csv is copied to good_data.
# split_14536.csv is copied to good_data.
# split_25933.csv is copied to good_data.
# split_4114.csv is copied to good_data.
# split_13259.csv is copied to good_data.
# [ERROR] split_12147.csv: Zero stops with duration > 20 hours.
# split_12147.csv is copied to bad_data.
# split_22084.csv is copied to good_data.
# split_15628.csv is copied to good_data.
# [ERROR] split_2565.csv: Blank price values in SpiceJet.
# split_2565.csv is copied to bad_data.
# split_10988.csv is copied to good_data.
# [ERROR] split_19012.csv: Zero stops with duration > 20 hours.
# split_19012.csv is copied to bad_data.
# split_16321.csv is copied to good_data.
# [ERROR] split_344.csv: Blank price values in SpiceJet.
# split_344.csv is copied to bad_data.
# split_9430.csv is copied to good_data.
# split_6703.csv is copied to good_data.
# split_10750.csv is copied to good_data.
# split_20693.csv is copied to good_data.
# [ERROR] split_17759.csv: Invalid 'duration' values (Yes/No).
# split_17759.csv is copied to bad_data.
# split_10036.csv is copied to good_data.
# split_8048.csv is copied to good_data.
# split_9356.csv is copied to good_data.
# split_26584.csv is copied to good_data.
# split_11328.csv is copied to good_data.
# split_17981.csv is copied to good_data.
# [ERROR] split_6065.csv: Premium class found.
# split_6065.csv is copied to bad_data.
# split_19774.csv is copied to good_data.
# split_27842.csv is copied to good_data.
# [ERROR] split_16447.csv: Same source and destination cities.
# split_16447.csv is copied to bad_data.
# [ERROR] split_422.csv: Premium class found.
# split_422.csv is copied to bad_data.
# [ERROR] split_2203.csv: Same source and destination cities.
# [ERROR] split_2203.csv: Premium class found.
# split_2203.csv is copied to bad_data.
# split_12621.csv is copied to good_data.
# [ERROR] split_4672.csv: Invalid 'duration' values (Yes/No).
# [ERROR] split_4672.csv: Premium class found.
# split_4672.csv is copied to bad_data.
# split_24393.csv is copied to good_data.
# split_14250.csv is copied to good_data.
# split_2217.csv is copied to good_data.
# split_5578.csv is copied to good_data.
# split_25099.csv is copied to good_data.
# split_12635.csv is copied to good_data.
# split_4666.csv is copied to good_data.
# split_24387.csv is copied to good_data.
# split_14244.csv is copied to good_data.
# split_3109.csv is copied to good_data.
# split_10022.csv is copied to good_data.
# split_26590.csv is copied to good_data.
# [ERROR] split_9342.csv: Negative 'days_left' values.
# split_9342.csv is copied to bad_data.
# split_17995.csv is copied to good_data.
# split_6071.csv is copied to good_data.
# split_27856.csv is copied to good_data.
# split_19760.csv is copied to good_data.
# [ERROR] split_436.csv: Negative 'days_left' values.
# split_436.csv is copied to bad_data.
# split_16453.csv is copied to good_data.
# split_19006.csv is copied to good_data.
# split_1078.csv is copied to good_data.
# split_350.csv is copied to good_data.
# split_21599.csv is copied to good_data.
# split_16335.csv is copied to good_data.
# split_9424.csv is copied to good_data.
# split_6717.csv is copied to good_data.
# split_10744.csv is copied to good_data.
# split_7409.csv is copied to good_data.
# split_18318.csv is copied to good_data.
# split_20687.csv is copied to good_data.
# [ERROR] split_14522.csv: Blank price values in SpiceJet.
# split_14522.csv is copied to bad_data.
# split_25927.csv is copied to good_data.
# [ERROR] split_4100.csv: Blank price values in SpiceJet.
# split_4100.csv is copied to bad_data.
# split_12153.csv is copied to good_data.
# split_22090.csv is copied to good_data.
# [ERROR] split_2571.csv: Invalid 'duration' values (Yes/No).
# split_2571.csv is copied to bad_data.
# split_378.csv is copied to good_data.
# split_1050.csv is copied to good_data.
# split_20877.csv is copied to good_data.
# split_11472.csv is copied to good_data.
# [ERROR] split_7421.csv: Same source and destination cities.
# split_7421.csv is copied to bad_data.
# [ERROR] split_8712.csv: Zero stops with duration > 20 hours.
# split_8712.csv is copied to bad_data.
# [ERROR] split_17003.csv: Zero stops with duration > 20 hours.
# split_17003.csv is copied to bad_data.
# split_18330.csv is copied to good_data.
# split_3647.csv is copied to good_data.
# [ERROR] split_13265.csv: Blank price values in SpiceJet.
# split_13265.csv is copied to bad_data.
# [ERROR] split_4128.csv: Invalid 'duration' values (Yes/No).
# split_4128.csv is copied to bad_data.
# split_5236.csv is copied to good_data.
# split_2559.csv is copied to good_data.
# split_15614.csv is copied to good_data.
# [ERROR] split_15172.csv: Negative 'days_left' values.
# split_15172.csv is copied to bad_data.
# split_4896.csv is copied to good_data.
# split_5550.csv is copied to good_data.
# split_13503.csv is copied to good_data.
# [ERROR] split_22906.csv: Zero stops with duration > 20 hours.
# split_22906.csv is copied to bad_data.
# split_3121.csv is copied to good_data.
# split_29853.csv is copied to good_data.
# [ERROR] split_17765.csv: Premium class found.
# split_17765.csv is copied to bad_data.
# [ERROR] split_18456.csv: Blank price values in SpiceJet.
# split_18456.csv is copied to bad_data.
# split_28595.csv is copied to good_data.
# split_7347.csv is copied to good_data.
# [ERROR] split_19990.csv: Negative 'days_left' values.
# split_19990.csv is copied to bad_data.
# split_8074.csv is copied to good_data.
# split_6059.csv is copied to good_data.
# [ERROR] split_11314.csv: Same source and destination cities.
# split_11314.csv is copied to bad_data.
# [ERROR] split_1736.csv: Same source and destination cities.
# split_1736.csv is copied to bad_data.
# split_19748.csv is copied to good_data.
# split_17771.csv is copied to good_data.
# split_29847.csv is copied to good_data.
# split_18442.csv is copied to good_data.
# split_7353.csv is copied to good_data.
# split_28581.csv is copied to good_data.
# split_19984.csv is copied to good_data.
# [ERROR] split_8060.csv: Premium class found.
# split_8060.csv is copied to bad_data.
# split_11300.csv is copied to good_data.
# split_1722.csv is copied to good_data.
# split_15166.csv is copied to good_data.
# split_4882.csv is copied to good_data.
# split_12609.csv is copied to good_data.
# split_5544.csv is copied to good_data.
# split_13517.csv is copied to good_data.
# split_22912.csv is copied to good_data.
# split_3135.csv is copied to good_data.
# split_14278.csv is copied to good_data.
# split_3653.csv is copied to good_data.
# split_13271.csv is copied to good_data.
# [ERROR] split_5222.csv: Negative 'days_left' values.
# split_5222.csv is copied to bad_data.
# split_15600.csv is copied to good_data.
# split_16309.csv is copied to good_data.
# split_1044.csv is copied to good_data.
# split_20863.csv is copied to good_data.
# split_11466.csv is copied to good_data.
# split_9418.csv is copied to good_data.
# split_7435.csv is copied to good_data.
# [ERROR] split_8706.csv: Invalid 'duration' values (Yes/No).
# split_8706.csv is copied to bad_data.
# split_10778.csv is copied to good_data.
# split_17017.csv is copied to good_data.
# split_18324.csv is copied to good_data.
# split_9587.csv is copied to good_data.
# [ERROR] split_26355.csv: Same source and destination cities.
# split_26355.csv is copied to bad_data.
# split_29066.csv is copied to good_data.
# [ERROR] split_8841.csv: Zero stops with duration > 20 hours.
# split_8841.csv is copied to bad_data.
# split_16296.csv is copied to good_data.
# split_20724.csv is copied to good_data.
# split_17188.csv is copied to good_data.
# [ERROR] split_8699.csv: Blank price values in SpiceJet.
# split_8699.csv is copied to bad_data.
# split_28378.csv is copied to good_data.
# split_15947.csv is copied to good_data.
# split_24542.csv is copied to good_data.
# split_14481.csv is copied to good_data.
# split_25884.csv is copied to good_data.
# [ERROR] split_22133.csv: Premium class found.
# split_22133.csv is copied to bad_data.
# split_3914.csv is copied to good_data.
# split_12796.csv is copied to good_data.
# split_22655.csv is copied to good_data.
# split_24224.csv is copied to good_data.
# split_13488.csv is copied to good_data.
# split_1865.csv is copied to good_data.
# split_10181.csv is copied to good_data.
# split_20042.csv is copied to good_data.
# [ERROR] split_595.csv: Negative 'days_left' values.
# split_595.csv is copied to bad_data.
# split_26433.csv is copied to good_data.
# split_29700.csv is copied to good_data.
# split_17836.csv is copied to good_data.
# split_27739.csv is copied to good_data.
# [ERROR] split_1871.csv: Negative 'days_left' values.
# split_1871.csv is copied to bad_data.
# split_10195.csv is copied to good_data.
# split_20056.csv is copied to good_data.
# [ERROR] split_581.csv: Zero stops with duration > 20 hours.
# split_581.csv is copied to bad_data.
# split_21348.csv is copied to good_data.
# [ERROR] split_26427.csv: Invalid 'duration' values (Yes/No).
# split_26427.csv is copied to bad_data.
# split_17822.csv is copied to good_data.
# split_29714.csv is copied to good_data.
# split_12782.csv is copied to good_data.
# split_4909.csv is copied to good_data.
# [ERROR] split_22641.csv: Premium class found.
# split_22641.csv is copied to bad_data.
# split_22899.csv is copied to good_data.
# split_24230.csv is copied to good_data.
# split_15953.csv is copied to good_data.
# split_24556.csv is copied to good_data.
# split_23239.csv is copied to good_data.
# split_14495.csv is copied to good_data.
# [ERROR] split_25890.csv: Premium class found.
# split_25890.csv is copied to bad_data.
# [ERROR] split_22127.csv: Invalid 'duration' values (Yes/No).
# split_22127.csv is copied to bad_data.
# split_25648.csv is copied to good_data.
# split_3900.csv is copied to good_data.
# split_26341.csv is copied to good_data.
# [ERROR] split_9593.csv: Zero stops with duration > 20 hours.
# split_9593.csv is copied to bad_data.
# [ERROR] split_29072.csv: Invalid 'duration' values (Yes/No).
# split_29072.csv is copied to bad_data.
# split_8855.csv is copied to good_data.
# split_16282.csv is copied to good_data.
# split_6878.csv is copied to good_data.
# split_20730.csv is copied to good_data.
# [ERROR] split_23211.csv: Air India flights with Vistara flight numbers.
# split_23211.csv is copied to bad_data.
# split_3928.csv is copied to good_data.
# split_25660.csv is copied to good_data.
# split_5381.csv is copied to good_data.
# split_6688.csv is copied to good_data.
# split_26369.csv is copied to good_data.
# split_21406.csv is copied to good_data.
# [ERROR] split_10803.csv: Invalid 'duration' values (Yes/No).
# split_10803.csv is copied to bad_data.
# [ERROR] split_19199.csv: Air India flights with Vistara flight numbers.
# split_19199.csv is copied to bad_data.
# split_20718.csv is copied to good_data.
# split_6850.csv is copied to good_data.
# split_18287.csv is copied to good_data.
# split_28344.csv is copied to good_data.
# [ERROR] split_7596.csv: Negative 'days_left' values.
# split_7596.csv is copied to bad_data.
# split_27077.csv is copied to good_data.
# [ERROR] split_28422.csv: Negative 'days_left' values.
# [ERROR] split_28422.csv: Same source and destination cities.
# split_28422.csv is copied to bad_data.
# [ERROR] split_1859.csv: Blank price values in SpiceJet.
# split_1859.csv is copied to bad_data.
# split_19827.csv is copied to good_data.
# split_27711.csv is copied to good_data.
# split_21360.csv is copied to good_data.
# split_1681.csv is copied to good_data.
# split_25106.csv is copied to good_data.
# split_2388.csv is copied to good_data.
# [ERROR] split_22669.csv: Invalid 'duration' values (Yes/No).
# split_22669.csv is copied to bad_data.
# [ERROR] split_4921.csv: Negative 'days_left' values.
# split_4921.csv is copied to bad_data.
# split_3096.csv is copied to good_data.
# split_12972.csv is copied to good_data.
# split_23577.csv is copied to good_data.
# split_24218.csv is copied to good_data.
# split_25112.csv is copied to good_data.
# split_4935.csv is copied to good_data.
# split_3082.csv is copied to good_data.
# split_12966.csv is copied to good_data.
# split_23563.csv is copied to good_data.
# split_28436.csv is copied to good_data.
# split_27705.csv is copied to good_data.
# split_19833.csv is copied to good_data.
# split_21374.csv is copied to good_data.
# split_1695.csv is copied to good_data.
# [ERROR] split_29728.csv: Invalid 'duration' values (Yes/No).
# split_29728.csv is copied to bad_data.
# split_21412.csv is copied to good_data.
# split_8869.csv is copied to good_data.
# split_10817.csv is copied to good_data.
# split_6844.csv is copied to good_data.
# split_18293.csv is copied to good_data.
# split_7582.csv is copied to good_data.
# split_28350.csv is copied to good_data.
# split_27063.csv is copied to good_data.
# split_23205.csv is copied to good_data.
# split_25674.csv is copied to good_data.
# split_5395.csv is copied to good_data.
# split_2411.csv is copied to good_data.
# [ERROR] split_12033.csv: Air India flights with Vistara flight numbers.
# split_12033.csv is copied to bad_data.
# split_4060.csv is copied to good_data.
# split_15984.csv is copied to good_data.
# [ERROR] split_24581.csv: Same source and destination cities.
# split_24581.csv is copied to bad_data.
# split_14442.csv is copied to good_data.
# split_25847.csv is copied to good_data.
# split_18278.csv is copied to good_data.
# split_27088.csv is copied to good_data.
# split_10624.csv is copied to good_data.
# split_7569.csv is copied to good_data.
# split_9544.csv is copied to good_data.
# split_26396.csv is copied to good_data.
# split_6677.csv is copied to good_data.
# split_8882.csv is copied to good_data.
# split_19166.csv is copied to good_data.
# split_1118.csv is copied to good_data.
# [ERROR] split_230.csv: Blank price values in SpiceJet.
# split_230.csv is copied to bad_data.
# split_16255.csv is copied to good_data.
# split_27936.csv is copied to good_data.
# split_19600.csv is copied to good_data.
# split_556.csv is copied to good_data.
# split_16533.csv is copied to good_data.
# split_9222.csv is copied to good_data.
# split_6111.csv is copied to good_data.
# split_10142.csv is copied to good_data.
# split_20081.csv is copied to good_data.
# split_23588.csv is copied to good_data.
# [ERROR] split_14324.csv: Blank price values in SpiceJet.
# split_14324.csv is copied to bad_data.
# split_3069.csv is copied to good_data.
# split_4706.csv is copied to good_data.
# [ERROR] split_5418.csv: Zero stops with duration > 20 hours.
# split_5418.csv is copied to bad_data.
# split_12755.csv is copied to good_data.
# split_22696.csv is copied to good_data.
# split_2377.csv is copied to good_data.
# split_14330.csv is copied to good_data.
# split_12999.csv is copied to good_data.
# split_4712.csv is copied to good_data.
# [ERROR] split_12741.csv: Negative 'days_left' values.
# split_12741.csv is copied to bad_data.
# split_22682.csv is copied to good_data.
# split_2363.csv is copied to good_data.
# split_19614.csv is copied to good_data.
# split_27922.csv is copied to good_data.
# split_16527.csv is copied to good_data.
# split_542.csv is copied to good_data.
# split_9236.csv is copied to good_data.
# [ERROR] split_11248.csv: Same source and destination cities.
# split_11248.csv is copied to bad_data.
# split_6105.csv is copied to good_data.
# split_10156.csv is copied to good_data.
# split_8128.csv is copied to good_data.
# split_20095.csv is copied to good_data.
# [ERROR] split_17639.csv: Premium class found.
# split_17639.csv is copied to bad_data.
# [ERROR] split_10630.csv: Negative 'days_left' values.
# split_10630.csv is copied to bad_data.
# [ERROR] split_26382.csv: Premium class found.
# split_26382.csv is copied to bad_data.
# split_9550.csv is copied to good_data.
# [ERROR] split_6663.csv: Premium class found.
# split_6663.csv is copied to bad_data.
# split_8896.csv is copied to good_data.
# [ERROR] split_19172.csv: Premium class found.
# split_19172.csv is copied to bad_data.
# split_16241.csv is copied to good_data.
# [ERROR] split_224.csv: Invalid 'duration' values (Yes/No).
# split_224.csv is copied to bad_data.
# split_15748.csv is copied to good_data.
# split_2405.csv is copied to good_data.
# split_12027.csv is copied to good_data.
# [ERROR] split_4074.csv: Negative 'days_left' values.
# split_4074.csv is copied to bad_data.
# split_15990.csv is copied to good_data.
# split_24595.csv is copied to good_data.
# [ERROR] split_13339.csv: Blank price values in SpiceJet.
# split_13339.csv is copied to bad_data.
# split_14456.csv is copied to good_data.
# split_25853.csv is copied to good_data.
# split_6893.csv is copied to good_data.
# split_17177.csv is copied to good_data.
# [ERROR] split_18244.csv: Negative 'days_left' values.
# split_18244.csv is copied to bad_data.
# [ERROR] split_28387.csv: Premium class found.
# split_28387.csv is copied to bad_data.
# split_7555.csv is copied to good_data.
# split_8666.csv is copied to good_data.
# [ERROR] split_10618.csv: Blank price values in SpiceJet.
# [ERROR] split_10618.csv: Air India flights with Vistara flight numbers.
# split_10618.csv is copied to bad_data.
# split_29099.csv is copied to good_data.
# [ERROR] split_20903.csv: Air India flights with Vistara flight numbers.
# split_20903.csv is copied to bad_data.
# split_11506.csv is copied to good_data.
# [ERROR] split_9578.csv: Invalid 'duration' values (Yes/No).
# split_9578.csv is copied to bad_data.
# split_16269.csv is copied to good_data.
# [ERROR] split_1124.csv: Invalid 'duration' values (Yes/No).
# split_1124.csv is copied to bad_data.
# split_15760.csv is copied to good_data.
# split_5342.csv is copied to good_data.
# split_13311.csv is copied to good_data.
# split_3733.csv is copied to good_data.
# split_3055.csv is copied to good_data.
# split_14318.csv is copied to good_data.
# [ERROR] split_13477.csv: Invalid 'duration' values (Yes/No).
# split_13477.csv is copied to bad_data.
# split_22872.csv is copied to good_data.
# [ERROR] split_12769.csv: Blank price values in SpiceJet.
# split_12769.csv is copied to bad_data.
# split_5424.csv is copied to good_data.
# split_15006.csv is copied to good_data.
# [ERROR] split_1642.csv: Same source and destination cities.
# split_1642.csv is copied to bad_data.
# [ERROR] split_11260.csv: Negative 'days_left' values.
# split_11260.csv is copied to bad_data.
# split_7233.csv is copied to good_data.
# split_8100.csv is copied to good_data.
# split_17611.csv is copied to good_data.
# [ERROR] split_29927.csv: Negative 'days_left' values.
# split_29927.csv is copied to bad_data.
# [ERROR] split_18522.csv: Premium class found.
# split_18522.csv is copied to bad_data.
# split_1656.csv is copied to good_data.
# split_19628.csv is copied to good_data.
# [ERROR] split_6139.csv: Zero stops with duration > 20 hours.
# split_6139.csv is copied to bad_data.
# split_11274.csv is copied to good_data.
# split_7227.csv is copied to good_data.
# [ERROR] split_8114.csv: Same source and destination cities.
# [ERROR] split_8114.csv: Invalid 'duration' values (Yes/No).
# split_8114.csv is copied to bad_data.
# [ERROR] split_29933.csv: Negative 'days_left' values.
# [ERROR] split_29933.csv: Invalid 'duration' values (Yes/No).
# split_29933.csv is copied to bad_data.
# split_17605.csv is copied to good_data.
# split_18536.csv is copied to good_data.
# split_3041.csv is copied to good_data.
# split_13463.csv is copied to good_data.
# split_22866.csv is copied to good_data.
# split_5430.csv is copied to good_data.
# split_15012.csv is copied to good_data.
# split_2439.csv is copied to good_data.
# split_15774.csv is copied to good_data.
# split_5356.csv is copied to good_data.
# split_13305.csv is copied to good_data.
# split_4048.csv is copied to good_data.
# split_3727.csv is copied to good_data.
# split_6887.csv is copied to good_data.
# split_17163.csv is copied to good_data.
# split_18250.csv is copied to good_data.
# split_7541.csv is copied to good_data.
# split_28393.csv is copied to good_data.
# split_8672.csv is copied to good_data.
# split_20917.csv is copied to good_data.
# [ERROR] split_11512.csv: Invalid 'duration' values (Yes/No).
# split_11512.csv is copied to bad_data.
# split_218.csv is copied to good_data.
# split_1130.csv is copied to good_data.
# split_29502.csv is copied to good_data.
# [ERROR] split_18907.csv: Same source and destination cities.
# split_18907.csv is copied to bad_data.
# split_26631.csv is copied to good_data.
# [ERROR] split_797.csv: Zero stops with duration > 20 hours.
# split_797.csv is copied to bad_data.
# split_20240.csv is copied to good_data.
# [ERROR] split_10383.csv: Negative 'days_left' values.
# split_10383.csv is copied to bad_data.
# split_24026.csv is copied to good_data.
# [ERROR] split_23749.csv: Premium class found.
# split_23749.csv is copied to bad_data.
# split_5801.csv is copied to good_data.
# split_13852.csv is copied to good_data.
# split_22457.csv is copied to good_data.
# split_25338.csv is copied to good_data.
# split_12594.csv is copied to good_data.
# split_23991.csv is copied to good_data.
# split_24998.csv is copied to good_data.
# split_22331.csv is copied to good_data.
# split_14683.csv is copied to good_data.
# [ERROR] split_2808.csv: Same source and destination cities.
# split_2808.csv is copied to bad_data.
# [ERROR] split_24740.csv: Premium class found.
# split_24740.csv is copied to bad_data.
# [ERROR] split_27249.csv: Negative 'days_left' values.
# split_27249.csv is copied to bad_data.
# split_20526.csv is copied to good_data.
# split_11923.csv is copied to good_data.
# split_21638.csv is copied to good_data.
# [ERROR] split_7970.csv: Same source and destination cities.
# [ERROR] split_7970.csv: Invalid 'duration' values (Yes/No).
# split_7970.csv is copied to bad_data.
# split_16094.csv is copied to good_data.
# [ERROR] split_53.csv: Blank price values in SpiceJet.
# split_53.csv is copied to bad_data.
# split_29264.csv is copied to good_data.
# [ERROR] split_26157.csv: Invalid 'duration' values (Yes/No).
# split_26157.csv is copied to bad_data.
# split_9785.csv is copied to good_data.
# split_20532.csv is copied to good_data.
# [ERROR] split_9949.csv: Zero stops with duration > 20 hours.
# split_9949.csv is copied to bad_data.
# split_11937.csv is copied to good_data.
# split_7964.csv is copied to good_data.
# split_16080.csv is copied to good_data.
# split_47.csv is copied to good_data.
# split_29270.csv is copied to good_data.
# [ERROR] split_9791.csv: Invalid 'duration' values (Yes/No).
# split_9791.csv is copied to bad_data.
# split_26143.csv is copied to good_data.
# split_22325.csv is copied to good_data.
# split_15589.csv is copied to good_data.
# split_14697.csv is copied to good_data.
# split_24754.csv is copied to good_data.
# split_24032.csv is copied to good_data.
# split_5815.csv is copied to good_data.
# [ERROR] split_13846.csv: Zero stops with duration > 20 hours.
# split_13846.csv is copied to bad_data.
# split_22443.csv is copied to good_data.
# split_12580.csv is copied to good_data.
# split_23985.csv is copied to good_data.
# split_29516.csv is copied to good_data.
# split_26625.csv is copied to good_data.
# split_18913.csv is copied to good_data.
# [ERROR] split_11089.csv: Air India flights with Vistara flight numbers.
# split_11089.csv is copied to bad_data.
# split_783.csv is copied to good_data.
# split_20254.csv is copied to good_data.
# split_28608.csv is copied to good_data.
# split_10397.csv is copied to good_data.
# split_23775.csv is copied to good_data.
# split_3294.csv is copied to good_data.
# [ERROR] split_25304.csv: Invalid 'duration' values (Yes/No).
# split_25304.csv is copied to bad_data.
# split_1483.csv is copied to good_data.
# split_21162.csv is copied to good_data.
# split_27513.csv is copied to good_data.
# split_973.csv is copied to good_data.
# split_28620.csv is copied to good_data.
# split_16916.csv is copied to good_data.
# [ERROR] split_27275.csv: Premium class found.
# split_27275.csv is copied to bad_data.
# [ERROR] split_7794.csv: Premium class found.
# split_7794.csv is copied to bad_data.
# [ERROR] split_28146.csv: Air India flights with Vistara flight numbers.
# split_28146.csv is copied to bad_data.
# [ERROR] split_9961.csv: Negative 'days_left' values.
# split_9961.csv is copied to bad_data.
# split_18085.csv is copied to good_data.
# split_21604.csv is copied to good_data.
# split_29258.csv is copied to good_data.
# split_5183.csv is copied to good_data.
# split_14867.csv is copied to good_data.
# split_25462.csv is copied to good_data.
# split_23013.csv is copied to good_data.
# split_2834.csv is copied to good_data.
# split_5197.csv is copied to good_data.
# split_14873.csv is copied to good_data.
# [ERROR] split_25476.csv: Negative 'days_left' values.
# split_25476.csv is copied to bad_data.
# split_22319.csv is copied to good_data.
# split_23007.csv is copied to good_data.
# split_4289.csv is copied to good_data.
# split_24768.csv is copied to good_data.
# split_2820.csv is copied to good_data.
# split_27261.csv is copied to good_data.
# split_28152.csv is copied to good_data.
# split_7780.csv is copied to good_data.
# split_9975.csv is copied to good_data.
# split_18091.csv is copied to good_data.
# split_7958.csv is copied to good_data.
# split_21610.csv is copied to good_data.
# [ERROR] split_26619.csv: Same source and destination cities.
# split_26619.csv is copied to bad_data.
# split_1497.csv is copied to good_data.
# split_21176.csv is copied to good_data.
# [ERROR] split_20268.csv: Invalid 'duration' values (Yes/No).
# split_20268.csv is copied to bad_data.
# split_27507.csv is copied to good_data.
# split_16902.csv is copied to good_data.
# split_28634.csv is copied to good_data.
# split_967.csv is copied to good_data.
# split_5829.csv is copied to good_data.
# split_23761.csv is copied to good_data.
# split_3280.csv is copied to good_data.
# split_25310.csv is copied to good_data.
# split_2175.csv is copied to good_data.
# [ERROR] split_13891.csv: Negative 'days_left' values.
# split_13891.csv is copied to bad_data.
# split_22494.csv is copied to good_data.
# split_15238.csv is copied to good_data.
# split_12557.csv is copied to good_data.
# split_23952.csv is copied to good_data.
# split_13649.csv is copied to good_data.
# [ERROR] split_4504.csv: Air India flights with Vistara flight numbers.
# split_4504.csv is copied to bad_data.
# split_14126.csv is copied to good_data.
# split_20283.csv is copied to good_data.
# split_10340.csv is copied to good_data.
# split_6313.csv is copied to good_data.
# [ERROR] split_9020.csv: Blank price values in SpiceJet.
# split_9020.csv is copied to bad_data.
# [ERROR] split_16731.csv: Invalid 'duration' values (Yes/No).
# split_16731.csv is copied to bad_data.
# [ERROR] split_28807.csv: Zero stops with duration > 20 hours.
# split_28807.csv is copied to bad_data.
# split_754.csv is copied to good_data.
# split_19402.csv is copied to good_data.
# split_16057.csv is copied to good_data.
# split_90.csv is copied to good_data.
# split_19364.csv is copied to good_data.
# [ERROR] split_6475.csv: Blank price values in SpiceJet.
# split_6475.csv is copied to bad_data.
# split_26194.csv is copied to good_data.
# split_9746.csv is copied to good_data.
# split_11738.csv is copied to good_data.
# split_21823.csv is copied to good_data.
# split_10426.csv is copied to good_data.
# [ERROR] split_8458.csv: Blank price values in SpiceJet.
# split_8458.csv is copied to bad_data.
# [ERROR] split_17349.csv: Same source and destination cities.
# split_17349.csv is copied to bad_data.
# split_14640.csv is copied to good_data.
# split_24783.csv is copied to good_data.
# split_4262.csv is copied to good_data.
# split_12231.csv is copied to good_data.
# split_14898.csv is copied to good_data.
# split_2613.csv is copied to good_data.
# [ERROR] split_3519.csv: Invalid 'duration' values (Yes/No).
# split_3519.csv is copied to bad_data.
# [ERROR] split_14654.csv: Invalid 'duration' values (Yes/No).
# split_14654.csv is copied to bad_data.
# split_24797.csv is copied to good_data.
# split_4276.csv is copied to good_data.
# split_25489.csv is copied to good_data.
# split_12225.csv is copied to good_data.
# [ERROR] split_5168.csv: Air India flights with Vistara flight numbers.
# split_5168.csv is copied to bad_data.
# split_2607.csv is copied to good_data.
# split_16043.csv is copied to good_data.
# split_19370.csv is copied to good_data.
# split_84.csv is copied to good_data.
# split_6461.csv is copied to good_data.
# split_9752.csv is copied to good_data.
# [ERROR] split_26180.csv: Zero stops with duration > 20 hours.
# split_26180.csv is copied to bad_data.
# [ERROR] split_21837.csv: Zero stops with duration > 20 hours.
# split_21837.csv is copied to bad_data.
# split_10432.csv is copied to good_data.
# split_20297.csv is copied to good_data.
# split_18708.csv is copied to good_data.
# split_998.csv is copied to good_data.
# split_7019.csv is copied to good_data.
# [ERROR] split_10354.csv: Zero stops with duration > 20 hours.
# split_10354.csv is copied to bad_data.
# split_6307.csv is copied to good_data.
# [ERROR] split_9034.csv: Premium class found.
# split_9034.csv is copied to bad_data.
# split_21189.csv is copied to good_data.
# [ERROR] split_740.csv: Invalid 'duration' values (Yes/No).
# split_740.csv is copied to bad_data.
# split_28813.csv is copied to good_data.
# split_16725.csv is copied to good_data.
# split_19416.csv is copied to good_data.
# split_1468.csv is copied to good_data.
# split_2161.csv is copied to good_data.
# split_13885.csv is copied to good_data.
# split_22480.csv is copied to good_data.
# split_12543.csv is copied to good_data.
# split_23946.csv is copied to good_data.
# split_4510.csv is copied to good_data.
# split_14132.csv is copied to good_data.
# split_26816.csv is copied to good_data.
# [ERROR] split_18720.csv: Blank price values in SpiceJet.
# split_18720.csv is copied to bad_data.
# split_17413.csv is copied to good_data.
# split_8302.csv is copied to good_data.
# [ERROR] split_7031.csv: Blank price values in SpiceJet.
# split_7031.csv is copied to bad_data.
# split_11062.csv is copied to good_data.
# split_1440.csv is copied to good_data.
# split_768.csv is copied to good_data.
# split_15204.csv is copied to good_data.
# [ERROR] split_2149.csv: Same source and destination cities.
# split_2149.csv is copied to bad_data.
# split_5626.csv is copied to good_data.
# split_4538.csv is copied to good_data.
# split_13675.csv is copied to good_data.
# [ERROR] split_3257.csv: Negative 'days_left' values.
# split_3257.csv is copied to bad_data.
# [ERROR] split_3531.csv: Invalid 'duration' values (Yes/No).
# split_3531.csv is copied to bad_data.
# [ERROR] split_13113.csv: Invalid 'duration' values (Yes/No).
# split_13113.csv is copied to bad_data.
# [ERROR] split_5140.csv: Blank price values in SpiceJet.
# [ERROR] split_5140.csv: Zero stops with duration > 20 hours.
# split_5140.csv is copied to bad_data.
# split_15562.csv is copied to good_data.
# split_24967.csv is copied to good_data.
# [ERROR] split_1326.csv: Invalid 'duration' values (Yes/No).
# split_1326.csv is copied to bad_data.
# split_19358.csv is copied to good_data.
# split_11704.csv is copied to good_data.
# split_6449.csv is copied to good_data.
# split_8464.csv is copied to good_data.
# [ERROR] split_7757.csv: Negative 'days_left' values.
# split_7757.csv is copied to bad_data.
# [ERROR] split_28185.csv: Premium class found.
# split_28185.csv is copied to bad_data.
# split_18046.csv is copied to good_data.
# split_17375.csv is copied to good_data.
# split_1332.csv is copied to good_data.
# split_11710.csv is copied to good_data.
# [ERROR] split_8470.csv: Premium class found.
# split_8470.csv is copied to bad_data.
# split_28191.csv is copied to good_data.
# split_7743.csv is copied to good_data.
# split_18052.csv is copied to good_data.
# ...
# split_24375.csv is copied to good_data.
# split_4694.csv is copied to good_data.
# split_29889.csv is copied to good_data.
# split_20113.csv is copied to good_data.
# [ERROR] split_1934.csv: Same source and destination cities.
# split_1934.csv is copied to bad_data.
# split_29651.csv is copied to good_data.
# [ERROR] split_6083.csv: Negative 'days_left' values.
# [ERROR] split_6083.csv: Premium class found.
# split_6083.csv is copied to bad_data.
# [ERROR] split_17967.csv: Invalid 'duration' values (Yes/No).
# split_17967.csv is copied to bad_data.
# split_26562.csv is copied to good_data.
# [ERROR] split_19792.csv: Air India flights with Vistara flight numbers.
# split_19792.csv is copied to bad_data.
# split_8910.csv is copied to good_data.
# split_29137.csv is copied to good_data.
# split_26204.csv is copied to good_data.
# split_28229.csv is copied to good_data.
# split_20675.csv is copied to good_data.
# split_24413.csv is copied to good_data.
# split_15816.csv is copied to good_data.
# split_3845.csv is copied to good_data.
# split_2583.csv is copied to good_data.
# split_22062.csv is copied to good_data.
# split_10946.csv is copied to good_data.
# split_8938.csv is copied to good_data.
# split_21543.csv is copied to good_data.
# split_11480.csv is copied to good_data.
# split_20885.csv is copied to good_data.
# split_27132.csv is copied to good_data.
# split_28201.csv is copied to good_data.
# split_6915.csv is copied to good_data.
# [ERROR] split_23354.csv: Air India flights with Vistara flight numbers.
# split_23354.csv is copied to bad_data.
# [ERROR] split_13297.csv: Blank price values in SpiceJet.
# [ERROR] split_13297.csv: Same source and destination cities.
# split_13297.csv is copied to bad_data.
# split_12189.csv is copied to good_data.
# split_25725.csv is copied to good_data.
# split_4864.csv is copied to good_data.
# split_15180.csv is copied to good_data.
# split_25043.csv is copied to good_data.
# split_23432.csv is copied to good_data.
# split_12837.csv is copied to good_data.
# split_17797.csv is copied to good_data.
# split_27654.csv is copied to good_data.
# split_8086.csv is copied to good_data.
# split_19962.csv is copied to good_data.
# split_28567.csv is copied to good_data.
# [ERROR] split_9398.csv: Zero stops with duration > 20 hours.
# split_9398.csv is copied to bad_data.
# split_29679.csv is copied to good_data.
# split_16489.csv is copied to good_data.
# split_21225.csv is copied to good_data.
# split_17783.csv is copied to good_data.
# split_8092.csv is copied to good_data.
# split_19976.csv is copied to good_data.
# split_27640.csv is copied to good_data.
# split_1908.csv is copied to good_data.
# split_28573.csv is copied to good_data.
# split_27898.csv is copied to good_data.
# split_21231.csv is copied to good_data.
# split_4870.csv is copied to good_data.
# [ERROR] split_15194.csv: Premium class found.
# split_15194.csv is copied to bad_data.
# split_22738.csv is copied to good_data.
# [ERROR] split_25057.csv: Air India flights with Vistara flight numbers.
# split_25057.csv is copied to bad_data.
# split_24349.csv is copied to good_data.
# split_23426.csv is copied to good_data.
# [ERROR] split_12823.csv: Premium class found.
# split_12823.csv is copied to bad_data.
# split_23340.csv is copied to good_data.
# split_13283.csv is copied to good_data.
# [ERROR] split_25731.csv: Premium class found.
# split_25731.csv is copied to bad_data.
# split_3879.csv is copied to good_data.
# split_10952.csv is copied to good_data.
# split_21557.csv is copied to good_data.
# [ERROR] split_11494.csv: Zero stops with duration > 20 hours.
# split_11494.csv is copied to bad_data.
# split_26238.csv is copied to good_data.
# split_20891.csv is copied to good_data.
# split_27126.csv is copied to good_data.
# split_28215.csv is copied to good_data.
# split_6901.csv is copied to good_data.
# [ERROR] split_20649.csv: Negative 'days_left' values.
# [ERROR] split_20649.csv: Premium class found.
# [ERROR] split_20649.csv: Air India flights with Vistara flight numbers.
# split_20649.csv is copied to bad_data.
# split_10205.csv is copied to good_data.
# split_7148.csv is copied to good_data.
# [ERROR] split_18659.csv: Blank price values in SpiceJet.
# split_18659.csv is copied to bad_data.
# split_1539.csv is copied to good_data.
# split_19547.csv is copied to good_data.
# split_28942.csv is copied to good_data.
# split_16674.csv is copied to good_data.
# [ERROR] split_611.csv: Invalid 'duration' values (Yes/No).
# split_611.csv is copied to bad_data.
# split_9165.csv is copied to good_data.
# split_18881.csv is copied to good_data.
# split_29484.csv is copied to good_data.
# [ERROR] split_6256.csv: Invalid 'duration' values (Yes/No).
# split_6256.csv is copied to bad_data.
# split_23817.csv is copied to good_data.
# split_12412.csv is copied to good_data.
# [ERROR] split_2030.csv: Same source and destination cities.
# [ERROR] split_2030.csv: Premium class found.
# split_2030.csv is copied to bad_data.
# split_5987.csv is copied to good_data.
# split_14063.csv is copied to good_data.
# split_4441.csv is copied to good_data.
# split_4327.csv is copied to good_data.
# [ERROR] split_14705.csv: Same source and destination cities.
# split_14705.csv is copied to bad_data.
# [ERROR] split_3448.csv: Invalid 'duration' values (Yes/No).
# split_3448.csv is copied to bad_data.
# [ERROR] split_2756.csv: Blank price values in SpiceJet.
# split_2756.csv is copied to bad_data.
# split_5039.csv is copied to good_data.
# split_12374.csv is copied to good_data.
# split_9603.csv is copied to good_data.
# split_6530.csv is copied to good_data.
# split_19221.csv is copied to good_data.
# split_16112.csv is copied to good_data.
# split_177.csv is copied to good_data.
# split_10563.csv is copied to good_data.
# split_21966.csv is copied to good_data.
# split_11669.csv is copied to good_data.
# [ERROR] split_9617.csv: Blank price values in SpiceJet.
# split_9617.csv is copied to bad_data.
# split_6524.csv is copied to good_data.
# [ERROR] split_19235.csv: Zero stops with duration > 20 hours.
# split_19235.csv is copied to bad_data.
# split_163.csv is copied to good_data.
# split_16106.csv is copied to good_data.
# split_17218.csv is copied to good_data.
# split_8509.csv is copied to good_data.
# split_10577.csv is copied to good_data.
# split_21972.csv is copied to good_data.
# [ERROR] split_4333.csv: Same source and destination cities.
# split_4333.csv is copied to bad_data.
# split_14711.csv is copied to good_data.
# [ERROR] split_2742.csv: Premium class found.
# split_2742.csv is copied to bad_data.
# split_12360.csv is copied to good_data.
# split_23803.csv is copied to good_data.
# split_12406.csv is copied to good_data.
# split_15369.csv is copied to good_data.
# split_2024.csv is copied to good_data.
# split_5993.csv is copied to good_data.
# split_14077.csv is copied to good_data.
# split_4455.csv is copied to good_data.
# [ERROR] split_13718.csv: Negative 'days_left' values.
# split_13718.csv is copied to bad_data.
# split_10211.csv is copied to good_data.
# split_19553.csv is copied to good_data.
# split_605.csv is copied to good_data.
# split_16660.csv is copied to good_data.
# split_28956.csv is copied to good_data.
# split_9171.csv is copied to good_data.
# split_18895.csv is copied to good_data.
# split_6242.csv is copied to good_data.
# split_29490.csv is copied to good_data.
# split_25282.csv is copied to good_data.
# split_5763.csv is copied to good_data.
# [ERROR] split_15341.csv: Same source and destination cities.
# split_15341.csv is copied to bad_data.
# split_3312.csv is copied to good_data.
# split_13730.csv is copied to good_data.
# split_7174.csv is copied to good_data.
# split_16890.csv is copied to good_data.
# split_10239.csv is copied to good_data.
# split_8247.csv is copied to good_data.
# split_27495.csv is copied to good_data.
# split_17556.csv is copied to good_data.
# split_18665.csv is copied to good_data.
# split_26953.csv is copied to good_data.
# split_16648.csv is copied to good_data.
# split_1505.csv is copied to good_data.
# split_9159.csv is copied to good_data.
# split_11127.csv is copied to good_data.
# split_11641.csv is copied to good_data.
# split_21782.csv is copied to good_data.
# [ERROR] split_1263.csv: Premium class found.
# [ERROR] split_1263.csv: Zero stops with duration > 20 hours.
# split_1263.csv is copied to bad_data.
# split_17230.csv is copied to good_data.
# split_18103.csv is copied to good_data.
# split_11899.csv is copied to good_data.
# [ERROR] split_7612.csv: Same source and destination cities.
# split_7612.csv is copied to bad_data.
# split_8521.csv is copied to good_data.
# [ERROR] split_13056.csv: Invalid 'duration' values (Yes/No).
# split_13056.csv is copied to bad_data.
# split_3474.csv is copied to good_data.
# split_14739.csv is copied to good_data.
# split_23195.csv is copied to good_data.
# split_24822.csv is copied to good_data.
# split_15427.csv is copied to good_data.
# split_12348.csv is copied to good_data.
# [ERROR] split_5005.csv: Air India flights with Vistara flight numbers.
# split_5005.csv is copied to bad_data.
# [ERROR] split_13042.csv: Invalid 'duration' values (Yes/No).
# split_13042.csv is copied to bad_data.
# split_3460.csv is copied to good_data.
# [ERROR] split_23181.csv: Premium class found.
# split_23181.csv is copied to bad_data.
# split_24836.csv is copied to good_data.
# split_15433.csv is copied to good_data.
# split_5011.csv is copied to good_data.
# split_6518.csv is copied to good_data.
# split_11655.csv is copied to good_data.
# split_21796.csv is copied to good_data.
# split_19209.csv is copied to good_data.
# [ERROR] split_1277.csv: Premium class found.
# split_1277.csv is copied to bad_data.
# split_17224.csv is copied to good_data.
# split_20488.csv is copied to good_data.
# split_18117.csv is copied to good_data.
# split_7606.csv is copied to good_data.
# [ERROR] split_8535.csv: Blank price values in SpiceJet.
# [ERROR] split_8535.csv: Zero stops with duration > 20 hours.
# split_8535.csv is copied to bad_data.
# split_7160.csv is copied to good_data.
# split_16884.csv is copied to good_data.
# [ERROR] split_27481.csv: Invalid 'duration' values (Yes/No).
# split_27481.csv is copied to bad_data.
# split_8253.csv is copied to good_data.
# split_17542.csv is copied to good_data.
# split_26947.csv is copied to good_data.
# split_18671.csv is copied to good_data.
# split_639.csv is copied to good_data.
# split_1511.csv is copied to good_data.
# [ERROR] split_11133.csv: Invalid 'duration' values (Yes/No).
# split_11133.csv is copied to bad_data.
# split_25296.csv is copied to good_data.
# [ERROR] split_5777.csv: Negative 'days_left' values.
# split_5777.csv is copied to bad_data.
# [ERROR] split_2018.csv: Negative 'days_left' values.
# split_2018.csv is copied to bad_data.
# [ERROR] split_15355.csv: Blank price values in SpiceJet.
# split_15355.csv is copied to bad_data.
# split_3306.csv is copied to good_data.
# split_13724.csv is copied to good_data.
# split_24188.csv is copied to good_data.
# split_4469.csv is copied to good_data.
# [ERROR] split_5944.csv: Air India flights with Vistara flight numbers.
# split_5944.csv is copied to bad_data.
# split_4482.csv is copied to good_data.
# split_24163.csv is copied to good_data.
# split_22512.csv is copied to good_data.
# split_13917.csv is copied to good_data.
# split_19584.csv is copied to good_data.
# split_28981.csv is copied to good_data.
# split_26774.csv is copied to good_data.
# [ERROR] split_18842.csv: Same source and destination cities.
# split_18842.csv is copied to bad_data.
# split_29447.csv is copied to good_data.
# [ERROR] split_6295.csv: Same source and destination cities.
# split_6295.csv is copied to bad_data.
# split_28759.csv is copied to good_data.
# split_20305.csv is copied to good_data.
# split_11866.csv is copied to good_data.
# split_9818.csv is copied to good_data.
# [ERROR] split_20463.csv: Negative 'days_left' values.
# split_20463.csv is copied to bad_data.
# split_26012.csv is copied to good_data.
# split_29321.csv is copied to good_data.
# split_7835.csv is copied to good_data.
# [ERROR] split_22274.csv: Premium class found.
# split_22274.csv is copied to bad_data.
# [ERROR] split_2795.csv: Zero stops with duration > 20 hours.
# split_2795.csv is copied to bad_data.
# split_24605.csv is copied to good_data.
# split_22260.csv is copied to good_data.
# split_2781.csv is copied to good_data.
# split_24611.csv is copied to good_data.
# split_2959.csv is copied to good_data.
# [ERROR] split_11872.csv: Premium class found.
# split_11872.csv is copied to bad_data.
# split_20477.csv is copied to good_data.
# split_27318.csv is copied to good_data.
# split_26006.csv is copied to good_data.
# split_29335.csv is copied to good_data.
# split_1288.csv is copied to good_data.
# [ERROR] split_7821.csv: Invalid 'duration' values (Yes/No).
# split_7821.csv is copied to bad_data.
# split_21769.csv is copied to good_data.
# split_19590.csv is copied to good_data.
# split_28995.csv is copied to good_data.
# [ERROR] split_18856.csv: Negative 'days_left' values.
# split_18856.csv is copied to bad_data.
# split_26760.csv is copied to good_data.
# split_6281.csv is copied to good_data.
# [ERROR] split_29453.csv: Negative 'days_left' values.
# split_29453.csv is copied to bad_data.
# split_20311.csv is copied to good_data.
# split_5950.csv is copied to good_data.
# split_23618.csv is copied to good_data.
# [ERROR] split_4496.csv: Same source and destination cities.
# split_4496.csv is copied to bad_data.
# split_24177.csv is copied to good_data.
# [ERROR] split_5788.csv: Zero stops with duration > 20 hours.
# split_5788.csv is copied to bad_data.
# split_25269.csv is copied to good_data.
# [ERROR] split_22506.csv: Air India flights with Vistara flight numbers.
# split_22506.csv is copied to bad_data.
# split_13903.csv is copied to good_data.
# split_21027.csv is copied to good_data.
# split_26748.csv is copied to good_data.
# [ERROR] split_836.csv: Premium class found.
# split_836.csv is copied to bad_data.
# split_16853.csv is copied to good_data.
# split_28765.csv is copied to good_data.
# split_8284.csv is copied to good_data.
# split_27456.csv is copied to good_data.
# split_17595.csv is copied to good_data.
# split_20339.csv is copied to good_data.
# split_26990.csv is copied to good_data.
# split_23630.csv is copied to good_data.
# [ERROR] split_5978.csv: Premium class found.
# split_5978.csv is copied to bad_data.
# split_25241.csv is copied to good_data.
# [ERROR] split_15382.csv: Premium class found.
# split_15382.csv is copied to bad_data.
# split_22248.csv is copied to good_data.
# split_25527.csv is copied to good_data.
# split_14922.csv is copied to good_data.
# split_2971.csv is copied to good_data.
# split_13095.csv is copied to good_data.
# split_24639.csv is copied to good_data.
# split_23156.csv is copied to good_data.
# split_9824.csv is copied to good_data.
# split_21999.csv is copied to good_data.
# split_28003.csv is copied to good_data.
# split_27330.csv is copied to good_data.
# split_11682.csv is copied to good_data.
# split_188.csv is copied to good_data.
# [ERROR] split_21741.csv: Same source and destination cities.
# split_21741.csv is copied to bad_data.
# split_7809.csv is copied to good_data.
# split_9830.csv is copied to good_data.
# split_28017.csv is copied to good_data.
# split_10588.csv is copied to good_data.
# split_27324.csv is copied to good_data.
# split_29309.csv is copied to good_data.
# [ERROR] split_11696.csv: Same source and destination cities.
# split_11696.csv is copied to bad_data.
# split_21755.csv is copied to good_data.
# split_25533.csv is copied to good_data.
# split_14936.csv is copied to good_data.
# split_2965.csv is copied to good_data.
# split_13081.csv is copied to good_data.
# split_23142.csv is copied to good_data.
# split_14088.csv is copied to good_data.
# split_23624.csv is copied to good_data.
# [ERROR] split_25255.csv: Air India flights with Vistara flight numbers.
# split_25255.csv is copied to bad_data.
# [ERROR] split_15396.csv: Invalid 'duration' values (Yes/No).
# split_15396.csv is copied to bad_data.
# split_21033.csv is copied to good_data.
# split_28771.csv is copied to good_data.
# split_16847.csv is copied to good_data.
# split_822.csv is copied to good_data.
# [ERROR] split_27442.csv: Premium class found.
# split_27442.csv is copied to bad_data.
# split_8290.csv is copied to good_data.
# split_17581.csv is copied to good_data.
# split_26984.csv is copied to good_data.
#
# Total files processed: 30000
# Files copied to bad_data: 6116
# Files copied to good_data: 23884
# Files skipped due to errors: 0
