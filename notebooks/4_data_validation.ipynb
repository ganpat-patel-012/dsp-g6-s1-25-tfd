# %%
import os
import pandas as pd
import shutil

# Define folder paths
folder_A = "/Users/jatinkumarparmar/Documents/GitHub/dsp_project/dsp-g6-s1-25-tfd/input_data/raw_data"
bad_data_folder = "/Users/jatinkumarparmar/Documents/GitHub/dsp_project/dsp-g6-s1-25-tfd/data/Folder_B"
good_data_folder = "/Users/jatinkumarparmar/Documents/GitHub/dsp_project/dsp-g6-s1-25-tfd/data/Folder_C"

os.makedirs(good_data_folder, exist_ok=True)
os.makedirs(bad_data_folder, exist_ok=True)

def check_errors(df, file):
    """
    Check if the dataset contains any introduced errors.
    Returns True if errors are found, otherwise False.
    """
    error_found = False

    # Check for null values in the airline column
    if df['airline'].isna().any():
        error_found = True
        print(f"[ERROR] {file}: Null values found in 'airline' column.")

    
    # Check for negative duration values
    if df[df['duration'] < 0].shape[0] > 0:
        error_found = True
        print(f"[ERROR] {file}: Negative 'duration' values.")
    
    # Check for same source and destination cities
    if df[df['source_city'] == df['destination_city']].shape[0] > 0:
        error_found = True
        print(f"[ERROR] {file}: Same source and destination cities.")
    
    # Check for Yes/No in days_left
    if df[df['days_left'].astype(str).isin(['Yes', 'No'])].shape[0] > 0:
        error_found = True
        print(f"[ERROR] {file}: Invalid 'days_left' values (Yes/No).")
    
    # Check for Premium travel_class
    if df[df['travel_class'] == 'Premium'].shape[0] > 0:
        error_found = True
        print(f"[ERROR] {file}: Premium travel_class found.")
    
    # Check for Air India flights with Vistara flight numbers
    # Ensure 'flight' column is treated as a string to prevent errors
    df['flight'] = df['flight'].astype(str)
    if df[(df['airline'] == 'Air_India') & (df['flight'].str.startswith('UK-'))].shape[0] > 0:
        error_found = True
        print(f"[ERROR] {file}: Air India flights with Vistara flight numbers.")
    
    # Check for zero stops with duration > 20 hours
    temp_duration = pd.to_numeric(df['duration'], errors='coerce')  # Convert to numeric
    if df[(df['stops'] == 'zero') & (temp_duration > 20)].shape[0] > 0:
        error_found = True
        print(f"[ERROR] {file}: Zero stops with duration > 20 hours.")

    return error_found

# Get the list of visible .csv files in Folder_A, excluding hidden files
files = [f for f in os.listdir(folder_A) if f.endswith(".csv") and not f.startswith(".")]

# Process each file and track the results
bad_data_count = 0
good_data_count = 0
skipped_files = []

# Start processing each file
for file in files:
    file_path = os.path.join(folder_A, file)
    
    try:
        # Attempt to read the CSV file
        df = pd.read_csv(file_path)

        # Check for errors in the data
        if check_errors(df, file):
            # Copy the file to bad_data folder
            shutil.copy(file_path, os.path.join(bad_data_folder, file))
            bad_data_count += 1
            print(f"{file} is copied to bad_data.")
        else:
            # Copy the file to good_data folder
            shutil.copy(file_path, os.path.join(good_data_folder, file))
            good_data_count += 1
            print(f"{file} is copied to good_data.")

    except Exception as e:
        # Log the error and skip the file
        skipped_files.append(file)
        print(f"[ERROR] Could not process {file}: {e}")

# Final summary
print(f"\nTotal files processed: {len(files)}")
print(f"Files copied to bad_data: {bad_data_count}")
print(f"Files copied to good_data: {good_data_count}")
print(f"Files skipped due to errors: {len(skipped_files)}")
# Out:
# split_8289.csv is copied to good_data.
# [ERROR] split_9197.csv: Null values found in 'airline' column.
# split_9197.csv is copied to bad_data.
# split_5975.csv is copied to good_data.
# split_7804.csv is copied to good_data.
# [ERROR] split_185.csv: Negative 'duration' values.
# [ERROR] split_185.csv: Zero stops with duration > 20 hours.
# split_185.csv is copied to bad_data.
# [ERROR] split_9829.csv: Negative 'duration' values.
# split_9829.csv is copied to bad_data.
# split_191.csv is copied to good_data.
# split_7810.csv is copied to good_data.
# [ERROR] split_2968.csv: Premium travel_class found.
# [ERROR] split_2968.csv: Air India flights with Vistara flight numbers.
# [ERROR] split_2968.csv: Zero stops with duration > 20 hours.
# split_2968.csv is copied to bad_data.
# [ERROR] split_5961.csv: Premium travel_class found.
# [ERROR] split_5961.csv: Zero stops with duration > 20 hours.
# split_5961.csv is copied to bad_data.
# [ERROR] split_9183.csv: Air India flights with Vistara flight numbers.
# split_9183.csv is copied to bad_data.
# split_5791.csv is copied to good_data.
# split_5949.csv is copied to good_data.
# [ERROR] split_7186.csv: Same source and destination cities.
# split_7186.csv is copied to bad_data.
# split_807.csv is copied to good_data.
# [ERROR] split_6298.csv: Same source and destination cities.
# [ERROR] split_6298.csv: Premium travel_class found.
# split_6298.csv is copied to bad_data.
# [ERROR] split_1291.csv: Negative 'duration' values.
# split_1291.csv is copied to bad_data.
# split_7838.csv is copied to good_data.
# [ERROR] split_9815.csv: Invalid 'days_left' values (Yes/No).
# split_9815.csv is copied to bad_data.
# split_2940.csv is copied to good_data.
# [ERROR] split_3486.csv: Null values found in 'airline' column.
# [ERROR] split_3486.csv: Negative 'duration' values.
# split_3486.csv is copied to bad_data.
# split_2798.csv is copied to good_data.
# [ERROR] split_2954.csv: Zero stops with duration > 20 hours.
# split_2954.csv is copied to bad_data.
# [ERROR] split_3492.csv: Negative 'duration' values.
# split_3492.csv is copied to bad_data.
# split_1285.csv is copied to good_data.
# split_9801.csv is copied to good_data.
# [ERROR] split_813.csv: Negative 'duration' values.
# split_813.csv is copied to bad_data.
# [ERROR] split_7192.csv: Null values found in 'airline' column.
# split_7192.csv is copied to bad_data.
# [ERROR] split_5785.csv: Invalid 'days_left' values (Yes/No).
# split_5785.csv is copied to bad_data.
# split_4470.csv is copied to good_data.
# [ERROR] split_2001.csv: Premium travel_class found.
# split_2001.csv is copied to bad_data.
# split_620.csv is copied to good_data.
# [ERROR] split_1508.csv: Zero stops with duration > 20 hours.
# split_1508.csv is copied to bad_data.
# [ERROR] split_6267.csv: Air India flights with Vistara flight numbers.
# split_6267.csv is copied to bad_data.
# [ERROR] split_9154.csv: Air India flights with Vistara flight numbers.
# split_9154.csv is copied to bad_data.
# split_7179.csv is copied to good_data.
# [ERROR] split_6501.csv: Zero stops with duration > 20 hours.
# split_6501.csv is copied to bad_data.
# split_9632.csv is copied to good_data.
# split_146.csv is copied to good_data.
# split_2767.csv is copied to good_data.
# split_5008.csv is copied to good_data.
# split_4316.csv is copied to good_data.
# split_3479.csv is copied to good_data.
# [ERROR] split_2773.csv: Null values found in 'airline' column.
# split_2773.csv is copied to bad_data.
# [ERROR] split_4302.csv: Premium travel_class found.
# [ERROR] split_4302.csv: Air India flights with Vistara flight numbers.
# split_4302.csv is copied to bad_data.
# split_8538.csv is copied to good_data.
# [ERROR] split_6515.csv: Air India flights with Vistara flight numbers.
# [ERROR] split_6515.csv: Zero stops with duration > 20 hours.
# split_6515.csv is copied to bad_data.
# split_9626.csv is copied to good_data.
# [ERROR] split_152.csv: Invalid 'days_left' values (Yes/No).
# split_152.csv is copied to bad_data.
# split_634.csv is copied to good_data.
# [ERROR] split_6273.csv: Same source and destination cities.
# split_6273.csv is copied to bad_data.
# [ERROR] split_9140.csv: Negative 'duration' values.
# [ERROR] split_9140.csv: Same source and destination cities.
# split_9140.csv is copied to bad_data.
# split_4464.csv is copied to good_data.
# [ERROR] split_2015.csv: Negative 'duration' values.
# split_2015.csv is copied to bad_data.
# [ERROR] split_1534.csv: Air India flights with Vistara flight numbers.
# split_1534.csv is copied to bad_data.
# split_9168.csv is copied to good_data.
# split_8276.csv is copied to good_data.
# split_7145.csv is copied to good_data.
# [ERROR] split_3323.csv: Negative 'duration' values.
# [ERROR] split_3323.csv: Zero stops with duration > 20 hours.
# split_3323.csv is copied to bad_data.
# [ERROR] split_5752.csv: Negative 'duration' values.
# split_5752.csv is copied to bad_data.
# [ERROR] split_5034.csv: Invalid 'days_left' values (Yes/No).
# split_5034.csv is copied to bad_data.
# [ERROR] split_2983.csv: Zero stops with duration > 20 hours.
# split_2983.csv is copied to bad_data.
# [ERROR] split_3445.csv: Null values found in 'airline' column.
# split_3445.csv is copied to bad_data.
# split_8510.csv is copied to good_data.
# [ERROR] split_7623.csv: Premium travel_class found.
# split_7623.csv is copied to bad_data.
# split_1252.csv is copied to good_data.
# [ERROR] split_8504.csv: Negative 'duration' values.
# [ERROR] split_8504.csv: Same source and destination cities.
# [ERROR] split_8504.csv: Invalid 'days_left' values (Yes/No).
# split_8504.csv is copied to bad_data.
# [ERROR] split_7637.csv: Same source and destination cities.
# split_7637.csv is copied to bad_data.
# [ERROR] split_6529.csv: Zero stops with duration > 20 hours.
# split_6529.csv is copied to bad_data.
# split_1246.csv is copied to good_data.
# split_5020.csv is copied to good_data.
# split_2997.csv is copied to good_data.
# [ERROR] split_3451.csv: Null values found in 'airline' column.
# split_3451.csv is copied to bad_data.
# split_3337.csv is copied to good_data.
# [ERROR] split_4458.csv: Negative 'duration' values.
# [ERROR] split_4458.csv: Zero stops with duration > 20 hours.
# split_4458.csv is copied to bad_data.
# split_5746.csv is copied to good_data.
# [ERROR] split_2029.csv: Zero stops with duration > 20 hours.
# split_2029.csv is copied to bad_data.
# [ERROR] split_1520.csv: Invalid 'days_left' values (Yes/No).
# split_1520.csv is copied to bad_data.
# [ERROR] split_608.csv: Same source and destination cities.
# split_608.csv is copied to bad_data.
# [ERROR] split_8262.csv: Invalid 'days_left' values (Yes/No).
# split_8262.csv is copied to bad_data.
# [ERROR] split_7151.csv: Zero stops with duration > 20 hours.
# split_7151.csv is copied to bad_data.
# [ERROR] split_6918.csv: Air India flights with Vistara flight numbers.
# [ERROR] split_6918.csv: Zero stops with duration > 20 hours.
# split_6918.csv is copied to bad_data.
# split_8935.csv is copied to good_data.
# [ERROR] split_387.csv: Negative 'duration' values.
# [ERROR] split_387.csv: Premium travel_class found.
# split_387.csv is copied to bad_data.
# [ERROR] split_3860.csv: Zero stops with duration > 20 hours.
# split_3860.csv is copied to bad_data.
# [ERROR] split_4869.csv: Zero stops with duration > 20 hours.
# split_4869.csv is copied to bad_data.
# [ERROR] split_9395.csv: Same source and destination cities.
# split_9395.csv is copied to bad_data.
# split_1911.csv is copied to good_data.
# [ERROR] split_9381.csv: Same source and destination cities.
# split_9381.csv is copied to bad_data.
# [ERROR] split_1905.csv: Zero stops with duration > 20 hours.
# split_1905.csv is copied to bad_data.
# split_3874.csv is copied to good_data.
# split_8921.csv is copied to good_data.
# [ERROR] split_393.csv: Null values found in 'airline' column.
# [ERROR] split_393.csv: Invalid 'days_left' values (Yes/No).
# split_393.csv is copied to bad_data.
# [ERROR] split_3684.csv: Negative 'duration' values.
# split_3684.csv is copied to bad_data.
# [ERROR] split_6924.csv: Air India flights with Vistara flight numbers.
# split_6924.csv is copied to bad_data.
# split_8909.csv is copied to good_data.
# [ERROR] split_1093.csv: Negative 'duration' values.
# split_1093.csv is copied to bad_data.
# split_7384.csv is copied to good_data.
# [ERROR] split_4855.csv: Null values found in 'airline' column.
# [ERROR] split_4855.csv: Premium travel_class found.
# split_4855.csv is copied to bad_data.
# split_5593.csv is copied to good_data.
# split_4699.csv is copied to good_data.
# [ERROR] split_4841.csv: Negative 'duration' values.
# [ERROR] split_4841.csv: Zero stops with duration > 20 hours.
# split_4841.csv is copied to bad_data.
# [ERROR] split_5587.csv: Negative 'duration' values.
# [ERROR] split_5587.csv: Same source and destination cities.
# split_5587.csv is copied to bad_data.
# split_7390.csv is copied to good_data.
# split_1939.csv is copied to good_data.
# [ERROR] split_6930.csv: Negative 'duration' values.
# split_6930.csv is copied to bad_data.
# [ERROR] split_1087.csv: Air India flights with Vistara flight numbers.
# split_1087.csv is copied to bad_data.
# split_3848.csv is copied to good_data.
# split_3690.csv is copied to good_data.
# [ERROR] split_4114.csv: Null values found in 'airline' column.
# split_4114.csv is copied to bad_data.
# split_2565.csv is copied to good_data.
# split_344.csv is copied to good_data.
# [ERROR] split_9430.csv: Null values found in 'airline' column.
# split_9430.csv is copied to bad_data.
# [ERROR] split_6703.csv: Negative 'duration' values.
# [ERROR] split_6703.csv: Air India flights with Vistara flight numbers.
# split_6703.csv is copied to bad_data.
# [ERROR] split_8048.csv: Same source and destination cities.
# [ERROR] split_8048.csv: Premium travel_class found.
# split_8048.csv is copied to bad_data.
# [ERROR] split_9356.csv: Null values found in 'airline' column.
# split_9356.csv is copied to bad_data.
# split_6065.csv is copied to good_data.
# split_422.csv is copied to good_data.
# split_2203.csv is copied to good_data.
# [ERROR] split_4672.csv: Invalid 'days_left' values (Yes/No).
# split_4672.csv is copied to bad_data.
# split_2217.csv is copied to good_data.
# [ERROR] split_5578.csv: Same source and destination cities.
# [ERROR] split_5578.csv: Zero stops with duration > 20 hours.
# split_5578.csv is copied to bad_data.
# split_4666.csv is copied to good_data.
# split_3109.csv is copied to good_data.
# split_9342.csv is copied to good_data.
# [ERROR] split_6071.csv: Negative 'duration' values.
# split_6071.csv is copied to bad_data.
# split_436.csv is copied to good_data.
# [ERROR] split_1078.csv: Negative 'duration' values.
# [ERROR] split_1078.csv: Premium travel_class found.
# [ERROR] split_1078.csv: Zero stops with duration > 20 hours.
# split_1078.csv is copied to bad_data.
# [ERROR] split_350.csv: Same source and destination cities.
# split_350.csv is copied to bad_data.
# [ERROR] split_9424.csv: Invalid 'days_left' values (Yes/No).
# [ERROR] split_9424.csv: Premium travel_class found.
# split_9424.csv is copied to bad_data.
# split_6717.csv is copied to good_data.
# [ERROR] split_7409.csv: Null values found in 'airline' column.
# split_7409.csv is copied to bad_data.
# split_4100.csv is copied to good_data.
# split_2571.csv is copied to good_data.
# split_378.csv is copied to good_data.
# [ERROR] split_1050.csv: Air India flights with Vistara flight numbers.
# split_1050.csv is copied to bad_data.
# split_7421.csv is copied to good_data.
# split_8712.csv is copied to good_data.
# [ERROR] split_3647.csv: Null values found in 'airline' column.
# [ERROR] split_3647.csv: Same source and destination cities.
# split_3647.csv is copied to bad_data.
# split_4128.csv is copied to good_data.
# split_5236.csv is copied to good_data.
# split_2559.csv is copied to good_data.
# [ERROR] split_4896.csv: Negative 'duration' values.
# split_4896.csv is copied to bad_data.
# split_5550.csv is copied to good_data.
# split_3121.csv is copied to good_data.
# split_7347.csv is copied to good_data.
# [ERROR] split_8074.csv: Null values found in 'airline' column.
# [ERROR] split_8074.csv: Air India flights with Vistara flight numbers.
# split_8074.csv is copied to bad_data.
# [ERROR] split_6059.csv: Zero stops with duration > 20 hours.
# split_6059.csv is copied to bad_data.
# split_1736.csv is copied to good_data.
# split_7353.csv is copied to good_data.
# split_8060.csv is copied to good_data.
# [ERROR] split_1722.csv: Premium travel_class found.
# split_1722.csv is copied to bad_data.
# [ERROR] split_4882.csv: Null values found in 'airline' column.
# [ERROR] split_4882.csv: Premium travel_class found.
# split_4882.csv is copied to bad_data.
# split_5544.csv is copied to good_data.
# [ERROR] split_3135.csv: Negative 'duration' values.
# [ERROR] split_3135.csv: Air India flights with Vistara flight numbers.
# split_3135.csv is copied to bad_data.
# split_3653.csv is copied to good_data.
# split_5222.csv is copied to good_data.
# [ERROR] split_1044.csv: Zero stops with duration > 20 hours.
# split_1044.csv is copied to bad_data.
# split_9418.csv is copied to good_data.
# [ERROR] split_7435.csv: Air India flights with Vistara flight numbers.
# [ERROR] split_7435.csv: Zero stops with duration > 20 hours.
# split_7435.csv is copied to bad_data.
# [ERROR] split_8706.csv: Premium travel_class found.
# split_8706.csv is copied to bad_data.
# split_9587.csv is copied to good_data.
# [ERROR] split_8841.csv: Same source and destination cities.
# [ERROR] split_8841.csv: Invalid 'days_left' values (Yes/No).
# split_8841.csv is copied to bad_data.
# split_8699.csv is copied to good_data.
# [ERROR] split_3914.csv: Premium travel_class found.
# split_3914.csv is copied to bad_data.
# split_1865.csv is copied to good_data.
# split_595.csv is copied to good_data.
# split_1871.csv is copied to good_data.
# [ERROR] split_581.csv: Null values found in 'airline' column.
# split_581.csv is copied to bad_data.
# [ERROR] split_4909.csv: Null values found in 'airline' column.
# [ERROR] split_4909.csv: Invalid 'days_left' values (Yes/No).
# split_4909.csv is copied to bad_data.
# split_3900.csv is copied to good_data.
# split_9593.csv is copied to good_data.
# [ERROR] split_8855.csv: Null values found in 'airline' column.
# split_8855.csv is copied to bad_data.
# split_6878.csv is copied to good_data.
# [ERROR] split_3928.csv: Zero stops with duration > 20 hours.
# split_3928.csv is copied to bad_data.
# [ERROR] split_5381.csv: Invalid 'days_left' values (Yes/No).
# split_5381.csv is copied to bad_data.
# [ERROR] split_6688.csv: Same source and destination cities.
# split_6688.csv is copied to bad_data.
# split_6850.csv is copied to good_data.
# [ERROR] split_7596.csv: Premium travel_class found.
# split_7596.csv is copied to bad_data.
# split_1859.csv is copied to good_data.
# [ERROR] split_1681.csv: Air India flights with Vistara flight numbers.
# split_1681.csv is copied to bad_data.
# [ERROR] split_2388.csv: Air India flights with Vistara flight numbers.
# split_2388.csv is copied to bad_data.
# [ERROR] split_4921.csv: Negative 'duration' values.
# [ERROR] split_4921.csv: Premium travel_class found.
# split_4921.csv is copied to bad_data.
# [ERROR] split_3096.csv: Invalid 'days_left' values (Yes/No).
# split_3096.csv is copied to bad_data.
# split_4935.csv is copied to good_data.
# [ERROR] split_3082.csv: Negative 'duration' values.
# split_3082.csv is copied to bad_data.
# [ERROR] split_1695.csv: Same source and destination cities.
# split_1695.csv is copied to bad_data.
# [ERROR] split_8869.csv: Air India flights with Vistara flight numbers.
# split_8869.csv is copied to bad_data.
# split_6844.csv is copied to good_data.
# split_7582.csv is copied to good_data.
# [ERROR] split_5395.csv: Same source and destination cities.
# split_5395.csv is copied to bad_data.
# split_2411.csv is copied to good_data.
# [ERROR] split_4060.csv: Null values found in 'airline' column.
# split_4060.csv is copied to bad_data.
# split_7569.csv is copied to good_data.
# split_9544.csv is copied to good_data.
# [ERROR] split_6677.csv: Null values found in 'airline' column.
# split_6677.csv is copied to bad_data.
# split_8882.csv is copied to good_data.
# split_1118.csv is copied to good_data.
# split_230.csv is copied to good_data.
# split_556.csv is copied to good_data.
# split_9222.csv is copied to good_data.
# [ERROR] split_6111.csv: Null values found in 'airline' column.
# [ERROR] split_6111.csv: Premium travel_class found.
# [ERROR] split_6111.csv: Zero stops with duration > 20 hours.
# split_6111.csv is copied to bad_data.
# [ERROR] split_3069.csv: Zero stops with duration > 20 hours.
# split_3069.csv is copied to bad_data.
# [ERROR] split_4706.csv: Negative 'duration' values.
# split_4706.csv is copied to bad_data.
# split_5418.csv is copied to good_data.
# [ERROR] split_2377.csv: Premium travel_class found.
# split_2377.csv is copied to bad_data.
# split_4712.csv is copied to good_data.
# split_2363.csv is copied to good_data.
# [ERROR] split_542.csv: Null values found in 'airline' column.
# split_542.csv is copied to bad_data.
# [ERROR] split_9236.csv: Air India flights with Vistara flight numbers.
# split_9236.csv is copied to bad_data.
# [ERROR] split_6105.csv: Same source and destination cities.
# split_6105.csv is copied to bad_data.
# [ERROR] split_8128.csv: Negative 'duration' values.
# split_8128.csv is copied to bad_data.
# split_9550.csv is copied to good_data.
# split_6663.csv is copied to good_data.
# split_8896.csv is copied to good_data.
# split_224.csv is copied to good_data.
# split_2405.csv is copied to good_data.
# split_4074.csv is copied to good_data.
# split_6893.csv is copied to good_data.
# split_7555.csv is copied to good_data.
# [ERROR] split_8666.csv: Same source and destination cities.
# split_8666.csv is copied to bad_data.
# split_9578.csv is copied to good_data.
# [ERROR] split_1124.csv: Same source and destination cities.
# [ERROR] split_1124.csv: Air India flights with Vistara flight numbers.
# split_1124.csv is copied to bad_data.
# [ERROR] split_5342.csv: Null values found in 'airline' column.
# split_5342.csv is copied to bad_data.
# split_3733.csv is copied to good_data.
# [ERROR] split_3055.csv: Zero stops with duration > 20 hours.
# split_3055.csv is copied to bad_data.
# split_5424.csv is copied to good_data.
# [ERROR] split_1642.csv: Premium travel_class found.
# [ERROR] split_1642.csv: Zero stops with duration > 20 hours.
# split_1642.csv is copied to bad_data.
# split_7233.csv is copied to good_data.
# split_8100.csv is copied to good_data.
# [ERROR] split_1656.csv: Null values found in 'airline' column.
# split_1656.csv is copied to bad_data.
# split_6139.csv is copied to good_data.
# [ERROR] split_7227.csv: Same source and destination cities.
# split_7227.csv is copied to bad_data.
# [ERROR] split_8114.csv: Same source and destination cities.
# split_8114.csv is copied to bad_data.
# [ERROR] split_3041.csv: Zero stops with duration > 20 hours.
# split_3041.csv is copied to bad_data.
# split_5430.csv is copied to good_data.
# [ERROR] split_2439.csv: Same source and destination cities.
# [ERROR] split_2439.csv: Zero stops with duration > 20 hours.
# split_2439.csv is copied to bad_data.
# [ERROR] split_5356.csv: Invalid 'days_left' values (Yes/No).
# [ERROR] split_5356.csv: Premium travel_class found.
# split_5356.csv is copied to bad_data.
# [ERROR] split_4048.csv: Same source and destination cities.
# split_4048.csv is copied to bad_data.
# split_3727.csv is copied to good_data.
# [ERROR] split_6887.csv: Null values found in 'airline' column.
# split_6887.csv is copied to bad_data.
# [ERROR] split_7541.csv: Premium travel_class found.
# [ERROR] split_7541.csv: Zero stops with duration > 20 hours.
# split_7541.csv is copied to bad_data.
# [ERROR] split_8672.csv: Same source and destination cities.
# [ERROR] split_8672.csv: Invalid 'days_left' values (Yes/No).
# split_8672.csv is copied to bad_data.
# [ERROR] split_218.csv: Premium travel_class found.
# split_218.csv is copied to bad_data.
# [ERROR] split_1130.csv: Premium travel_class found.
# split_1130.csv is copied to bad_data.
# [ERROR] split_797.csv: Zero stops with duration > 20 hours.
# split_797.csv is copied to bad_data.
# [ERROR] split_5801.csv: Negative 'duration' values.
# split_5801.csv is copied to bad_data.
# [ERROR] split_2808.csv: Negative 'duration' values.
# split_2808.csv is copied to bad_data.
# split_7970.csv is copied to good_data.
# split_53.csv is copied to good_data.
# [ERROR] split_9785.csv: Premium travel_class found.
# split_9785.csv is copied to bad_data.
# split_9949.csv is copied to good_data.
# split_7964.csv is copied to good_data.
# split_47.csv is copied to good_data.
# split_9791.csv is copied to good_data.
# split_5815.csv is copied to good_data.
# split_783.csv is copied to good_data.
# [ERROR] split_3294.csv: Negative 'duration' values.
# [ERROR] split_3294.csv: Air India flights with Vistara flight numbers.
# split_3294.csv is copied to bad_data.
# [ERROR] split_1483.csv: Premium travel_class found.
# split_1483.csv is copied to bad_data.
# split_973.csv is copied to good_data.
# split_7794.csv is copied to good_data.
# split_9961.csv is copied to good_data.
# [ERROR] split_5183.csv: Negative 'duration' values.
# [ERROR] split_5183.csv: Air India flights with Vistara flight numbers.
# split_5183.csv is copied to bad_data.
# [ERROR] split_2834.csv: Premium travel_class found.
# split_2834.csv is copied to bad_data.
# split_5197.csv is copied to good_data.
# [ERROR] split_4289.csv: Invalid 'days_left' values (Yes/No).
# split_4289.csv is copied to bad_data.
# split_2820.csv is copied to good_data.
# [ERROR] split_7780.csv: Negative 'duration' values.
# split_7780.csv is copied to bad_data.
# [ERROR] split_9975.csv: Invalid 'days_left' values (Yes/No).
# split_9975.csv is copied to bad_data.
# split_7958.csv is copied to good_data.
# split_1497.csv is copied to good_data.
# [ERROR] split_967.csv: Air India flights with Vistara flight numbers.
# split_967.csv is copied to bad_data.
# split_5829.csv is copied to good_data.
# split_3280.csv is copied to good_data.
# split_2175.csv is copied to good_data.
# [ERROR] split_4504.csv: Same source and destination cities.
# split_4504.csv is copied to bad_data.
# split_6313.csv is copied to good_data.
# split_9020.csv is copied to good_data.
# split_754.csv is copied to good_data.
# split_90.csv is copied to good_data.
# [ERROR] split_6475.csv: Premium travel_class found.
# [ERROR] split_6475.csv: Air India flights with Vistara flight numbers.
# split_6475.csv is copied to bad_data.
# [ERROR] split_9746.csv: Negative 'duration' values.
# split_9746.csv is copied to bad_data.
# [ERROR] split_8458.csv: Null values found in 'airline' column.
# split_8458.csv is copied to bad_data.
# split_4262.csv is copied to good_data.
# [ERROR] split_2613.csv: Invalid 'days_left' values (Yes/No).
# [ERROR] split_2613.csv: Premium travel_class found.
# split_2613.csv is copied to bad_data.
# [ERROR] split_3519.csv: Zero stops with duration > 20 hours.
# split_3519.csv is copied to bad_data.
# [ERROR] split_4276.csv: Null values found in 'airline' column.
# split_4276.csv is copied to bad_data.
# [ERROR] split_5168.csv: Invalid 'days_left' values (Yes/No).
# split_5168.csv is copied to bad_data.
# split_2607.csv is copied to good_data.
# split_84.csv is copied to good_data.
# [ERROR] split_6461.csv: Air India flights with Vistara flight numbers.
# split_6461.csv is copied to bad_data.
# split_9752.csv is copied to good_data.
# [ERROR] split_998.csv: Negative 'duration' values.
# split_998.csv is copied to bad_data.
# [ERROR] split_7019.csv: Same source and destination cities.
# split_7019.csv is copied to bad_data.
# [ERROR] split_6307.csv: Invalid 'days_left' values (Yes/No).
# [ERROR] split_6307.csv: Premium travel_class found.
# split_6307.csv is copied to bad_data.
# [ERROR] split_9034.csv: Negative 'duration' values.
# [ERROR] split_9034.csv: Air India flights with Vistara flight numbers.
# split_9034.csv is copied to bad_data.
# split_740.csv is copied to good_data.
# split_1468.csv is copied to good_data.
# [ERROR] split_2161.csv: Premium travel_class found.
# split_2161.csv is copied to bad_data.
# [ERROR] split_4510.csv: Same source and destination cities.
# split_4510.csv is copied to bad_data.
# split_8302.csv is copied to good_data.
# split_7031.csv is copied to good_data.
# split_1440.csv is copied to good_data.
# [ERROR] split_768.csv: Premium travel_class found.
# split_768.csv is copied to bad_data.
# [ERROR] split_2149.csv: Null values found in 'airline' column.
# split_2149.csv is copied to bad_data.
# [ERROR] split_5626.csv: Air India flights with Vistara flight numbers.
# split_5626.csv is copied to bad_data.
# split_4538.csv is copied to good_data.
# [ERROR] split_3257.csv: Invalid 'days_left' values (Yes/No).
# split_3257.csv is copied to bad_data.
# split_3531.csv is copied to good_data.
# split_5140.csv is copied to good_data.
# [ERROR] split_1326.csv: Null values found in 'airline' column.
# split_1326.csv is copied to bad_data.
# [ERROR] split_6449.csv: Invalid 'days_left' values (Yes/No).
# split_6449.csv is copied to bad_data.
# [ERROR] split_8464.csv: Negative 'duration' values.
# split_8464.csv is copied to bad_data.
# [ERROR] split_7757.csv: Null values found in 'airline' column.
# split_7757.csv is copied to bad_data.
# split_1332.csv is copied to good_data.
# split_8470.csv is copied to good_data.
# split_7743.csv is copied to good_data.
# split_3525.csv is copied to good_data.
# [ERROR] split_5154.csv: Invalid 'days_left' values (Yes/No).
# split_5154.csv is copied to bad_data.
# [ERROR] split_5632.csv: Negative 'duration' values.
# [ERROR] split_5632.csv: Premium travel_class found.
# split_5632.csv is copied to bad_data.
# split_3243.csv is copied to good_data.
# split_8316.csv is copied to good_data.
# split_7025.csv is copied to good_data.
# split_9008.csv is copied to good_data.
# split_1454.csv is copied to good_data.
# [ERROR] split_5155.csv: Same source and destination cities.
# split_5155.csv is copied to bad_data.
# [ERROR] split_3524.csv: Air India flights with Vistara flight numbers.
# split_3524.csv is copied to bad_data.
# split_7742.csv is copied to good_data.
# split_8471.csv is copied to good_data.
# [ERROR] split_1333.csv: Negative 'duration' values.
# split_1333.csv is copied to bad_data.
# [ERROR] split_1455.csv: Same source and destination cities.
# split_1455.csv is copied to bad_data.
# [ERROR] split_9009.csv: Null values found in 'airline' column.
# split_9009.csv is copied to bad_data.
# split_7024.csv is copied to good_data.
# split_8317.csv is copied to good_data.
# split_3242.csv is copied to good_data.
# split_5633.csv is copied to good_data.
# [ERROR] split_3256.csv: Air India flights with Vistara flight numbers.
# split_3256.csv is copied to bad_data.
# [ERROR] split_4539.csv: Null values found in 'airline' column.
# [ERROR] split_4539.csv: Air India flights with Vistara flight numbers.
# split_4539.csv is copied to bad_data.
# split_5627.csv is copied to good_data.
# split_2148.csv is copied to good_data.
# [ERROR] split_769.csv: Null values found in 'airline' column.
# split_769.csv is copied to bad_data.
# split_1441.csv is copied to good_data.
# [ERROR] split_7030.csv: Zero stops with duration > 20 hours.
# split_7030.csv is copied to bad_data.
# split_8303.csv is copied to good_data.
# [ERROR] split_7756.csv: Premium travel_class found.
# split_7756.csv is copied to bad_data.
# [ERROR] split_8465.csv: Null values found in 'airline' column.
# [ERROR] split_8465.csv: Premium travel_class found.
# split_8465.csv is copied to bad_data.
# split_6448.csv is copied to good_data.
# [ERROR] split_1327.csv: Negative 'duration' values.
# split_1327.csv is copied to bad_data.
# split_5141.csv is copied to good_data.
# split_3530.csv is copied to good_data.
# [ERROR] split_9753.csv: Air India flights with Vistara flight numbers.
# split_9753.csv is copied to bad_data.
# [ERROR] split_6460.csv: Air India flights with Vistara flight numbers.
# split_6460.csv is copied to bad_data.
# [ERROR] split_85.csv: Invalid 'days_left' values (Yes/No).
# [ERROR] split_85.csv: Air India flights with Vistara flight numbers.
# [ERROR] split_85.csv: Zero stops with duration > 20 hours.
# split_85.csv is copied to bad_data.
# [ERROR] split_2606.csv: Premium travel_class found.
# split_2606.csv is copied to bad_data.
# [ERROR] split_5169.csv: Invalid 'days_left' values (Yes/No).
# split_5169.csv is copied to bad_data.
# [ERROR] split_4277.csv: Negative 'duration' values.
# [ERROR] split_4277.csv: Zero stops with duration > 20 hours.
# split_4277.csv is copied to bad_data.
# [ERROR] split_3518.csv: Premium travel_class found.
# split_3518.csv is copied to bad_data.
# [ERROR] split_4511.csv: Same source and destination cities.
# [ERROR] split_4511.csv: Zero stops with duration > 20 hours.
# split_4511.csv is copied to bad_data.
# [ERROR] split_2160.csv: Null values found in 'airline' column.
# [ERROR] split_2160.csv: Same source and destination cities.
# split_2160.csv is copied to bad_data.
# [ERROR] split_1469.csv: Negative 'duration' values.
# split_1469.csv is copied to bad_data.
# split_741.csv is copied to good_data.
# split_9035.csv is copied to good_data.
# [ERROR] split_6306.csv: Invalid 'days_left' values (Yes/No).
# split_6306.csv is copied to bad_data.
# [ERROR] split_999.csv: Zero stops with duration > 20 hours.
# split_999.csv is copied to bad_data.
# [ERROR] split_7018.csv: Negative 'duration' values.
# split_7018.csv is copied to bad_data.
# [ERROR] split_755.csv: Invalid 'days_left' values (Yes/No).
# split_755.csv is copied to bad_data.
# split_9021.csv is copied to good_data.
# [ERROR] split_6312.csv: Null values found in 'airline' column.
# split_6312.csv is copied to bad_data.
# split_4505.csv is copied to good_data.
# split_2174.csv is copied to good_data.
# split_2612.csv is copied to good_data.
# [ERROR] split_4263.csv: Zero stops with duration > 20 hours.
# split_4263.csv is copied to bad_data.
# [ERROR] split_8459.csv: Premium travel_class found.
# split_8459.csv is copied to bad_data.
# split_9747.csv is copied to good_data.
# [ERROR] split_6474.csv: Null values found in 'airline' column.
# [ERROR] split_6474.csv: Premium travel_class found.
# split_6474.csv is copied to bad_data.
# split_91.csv is copied to good_data.
# split_7959.csv is copied to good_data.
# split_9974.csv is copied to good_data.
# [ERROR] split_7781.csv: Negative 'duration' values.
# [ERROR] split_7781.csv: Air India flights with Vistara flight numbers.
# split_7781.csv is copied to bad_data.
# [ERROR] split_2821.csv: Negative 'duration' values.
# [ERROR] split_2821.csv: Zero stops with duration > 20 hours.
# split_2821.csv is copied to bad_data.
# [ERROR] split_4288.csv: Premium travel_class found.
# split_4288.csv is copied to bad_data.
# [ERROR] split_5196.csv: Null values found in 'airline' column.
# split_5196.csv is copied to bad_data.
# split_3281.csv is copied to good_data.
# split_5828.csv is copied to good_data.
# [ERROR] split_966.csv: Premium travel_class found.
# [ERROR] split_966.csv: Zero stops with duration > 20 hours.
# split_966.csv is copied to bad_data.
# [ERROR] split_1496.csv: Invalid 'days_left' values (Yes/No).
# [ERROR] split_1496.csv: Premium travel_class found.
# split_1496.csv is copied to bad_data.
# split_972.csv is copied to good_data.
# split_1482.csv is copied to good_data.
# [ERROR] split_3295.csv: Invalid 'days_left' values (Yes/No).
# split_3295.csv is copied to bad_data.
# [ERROR] split_2835.csv: Premium travel_class found.
# split_2835.csv is copied to bad_data.
# split_5182.csv is copied to good_data.
# split_9960.csv is copied to good_data.
# [ERROR] split_7795.csv: Invalid 'days_left' values (Yes/No).
# split_7795.csv is copied to bad_data.
# [ERROR] split_9790.csv: Air India flights with Vistara flight numbers.
# split_9790.csv is copied to bad_data.
# [ERROR] split_46.csv: Invalid 'days_left' values (Yes/No).
# split_46.csv is copied to bad_data.
# [ERROR] split_7965.csv: Invalid 'days_left' values (Yes/No).
# split_7965.csv is copied to bad_data.
# split_9948.csv is copied to good_data.
# split_782.csv is copied to good_data.
# split_5814.csv is copied to good_data.
# split_5800.csv is copied to good_data.
# split_796.csv is copied to good_data.
# [ERROR] split_9784.csv: Same source and destination cities.
# [ERROR] split_9784.csv: Premium travel_class found.
# split_9784.csv is copied to bad_data.
# [ERROR] split_52.csv: Negative 'duration' values.
# split_52.csv is copied to bad_data.
# split_7971.csv is copied to good_data.
# split_2809.csv is copied to good_data.
# [ERROR] split_5431.csv: Premium travel_class found.
# split_5431.csv is copied to bad_data.
# [ERROR] split_3040.csv: Same source and destination cities.
# [ERROR] split_3040.csv: Invalid 'days_left' values (Yes/No).
# split_3040.csv is copied to bad_data.
# split_8115.csv is copied to good_data.
# [ERROR] split_7226.csv: Air India flights with Vistara flight numbers.
# split_7226.csv is copied to bad_data.
# split_6138.csv is copied to good_data.
# [ERROR] split_1657.csv: Zero stops with duration > 20 hours.
# split_1657.csv is copied to bad_data.
# split_1131.csv is copied to good_data.
# split_219.csv is copied to good_data.
# split_8673.csv is copied to good_data.
# [ERROR] split_7540.csv: Negative 'duration' values.
# [ERROR] split_7540.csv: Same source and destination cities.
# split_7540.csv is copied to bad_data.
# split_6886.csv is copied to good_data.
# [ERROR] split_3726.csv: Zero stops with duration > 20 hours.
# split_3726.csv is copied to bad_data.
# [ERROR] split_4049.csv: Premium travel_class found.
# [ERROR] split_4049.csv: Zero stops with duration > 20 hours.
# split_4049.csv is copied to bad_data.
# split_5357.csv is copied to good_data.
# [ERROR] split_2438.csv: Zero stops with duration > 20 hours.
# split_2438.csv is copied to bad_data.
# split_3732.csv is copied to good_data.
# split_5343.csv is copied to good_data.
# split_1125.csv is copied to good_data.
# split_9579.csv is copied to good_data.
# split_8667.csv is copied to good_data.
# split_7554.csv is copied to good_data.
# [ERROR] split_6892.csv: Invalid 'days_left' values (Yes/No).
# [ERROR] split_6892.csv: Premium travel_class found.
# [ERROR] split_6892.csv: Zero stops with duration > 20 hours.
# split_6892.csv is copied to bad_data.
# split_8101.csv is copied to good_data.
# [ERROR] split_7232.csv: Negative 'duration' values.
# [ERROR] split_7232.csv: Premium travel_class found.
# split_7232.csv is copied to bad_data.
# [ERROR] split_1643.csv: Premium travel_class found.
# [ERROR] split_1643.csv: Zero stops with duration > 20 hours.
# split_1643.csv is copied to bad_data.
# [ERROR] split_5425.csv: Premium travel_class found.
# split_5425.csv is copied to bad_data.
# [ERROR] split_3054.csv: Premium travel_class found.
# [ERROR] split_3054.csv: Zero stops with duration > 20 hours.
# split_3054.csv is copied to bad_data.
# [ERROR] split_8129.csv: Premium travel_class found.
# split_8129.csv is copied to bad_data.
# [ERROR] split_6104.csv: Premium travel_class found.
# split_6104.csv is copied to bad_data.
# split_9237.csv is copied to good_data.
# [ERROR] split_543.csv: Null values found in 'airline' column.
# [ERROR] split_543.csv: Same source and destination cities.
# split_543.csv is copied to bad_data.
# [ERROR] split_2362.csv: Negative 'duration' values.
# split_2362.csv is copied to bad_data.
# split_4713.csv is copied to good_data.
# split_4075.csv is copied to good_data.
# split_2404.csv is copied to good_data.
# [ERROR] split_225.csv: Invalid 'days_left' values (Yes/No).
# split_225.csv is copied to bad_data.
# split_8897.csv is copied to good_data.
# [ERROR] split_6662.csv: Same source and destination cities.
# [ERROR] split_6662.csv: Invalid 'days_left' values (Yes/No).
# split_6662.csv is copied to bad_data.
# split_9551.csv is copied to good_data.
# [ERROR] split_231.csv: Same source and destination cities.
# [ERROR] split_231.csv: Air India flights with Vistara flight numbers.
# split_231.csv is copied to bad_data.
# [ERROR] split_8883.csv: Same source and destination cities.
# [ERROR] split_8883.csv: Premium travel_class found.
# split_8883.csv is copied to bad_data.
# split_1119.csv is copied to good_data.
# [ERROR] split_6676.csv: Same source and destination cities.
# split_6676.csv is copied to bad_data.
# [ERROR] split_9545.csv: Same source and destination cities.
# split_9545.csv is copied to bad_data.
# [ERROR] split_7568.csv: Zero stops with duration > 20 hours.
# split_7568.csv is copied to bad_data.
# [ERROR] split_4061.csv: Invalid 'days_left' values (Yes/No).
# split_4061.csv is copied to bad_data.
# [ERROR] split_2410.csv: Negative 'duration' values.
# [ERROR] split_2410.csv: Premium travel_class found.
# [ERROR] split_2410.csv: Air India flights with Vistara flight numbers.
# split_2410.csv is copied to bad_data.
# split_2376.csv is copied to good_data.
# split_5419.csv is copied to good_data.
# split_4707.csv is copied to good_data.
# [ERROR] split_3068.csv: Same source and destination cities.
# split_3068.csv is copied to bad_data.
# split_6110.csv is copied to good_data.
# split_9223.csv is copied to good_data.
# [ERROR] split_557.csv: Null values found in 'airline' column.
# split_557.csv is copied to bad_data.
# split_1694.csv is copied to good_data.
# split_3083.csv is copied to good_data.
# split_4934.csv is copied to good_data.
# split_5394.csv is copied to good_data.
# [ERROR] split_7583.csv: Zero stops with duration > 20 hours.
# split_7583.csv is copied to bad_data.
# [ERROR] split_6845.csv: Premium travel_class found.
# split_6845.csv is copied to bad_data.
# split_8868.csv is copied to good_data.
# split_7597.csv is copied to good_data.
# split_6851.csv is copied to good_data.
# [ERROR] split_6689.csv: Null values found in 'airline' column.
# [ERROR] split_6689.csv: Zero stops with duration > 20 hours.
# split_6689.csv is copied to bad_data.
# split_5380.csv is copied to good_data.
# split_3929.csv is copied to good_data.
# [ERROR] split_3097.csv: Premium travel_class found.
# split_3097.csv is copied to bad_data.
# split_4920.csv is copied to good_data.
# split_2389.csv is copied to good_data.
# [ERROR] split_1680.csv: Zero stops with duration > 20 hours.
# split_1680.csv is copied to bad_data.
# split_1858.csv is copied to good_data.
# split_4908.csv is copied to good_data.
# split_580.csv is copied to good_data.
# split_1870.csv is copied to good_data.
# [ERROR] split_6879.csv: Premium travel_class found.
# split_6879.csv is copied to bad_data.
# [ERROR] split_8854.csv: Air India flights with Vistara flight numbers.
# split_8854.csv is copied to bad_data.
# split_9592.csv is copied to good_data.
# [ERROR] split_3901.csv: Same source and destination cities.
# [ERROR] split_3901.csv: Premium travel_class found.
# split_3901.csv is copied to bad_data.
# split_3915.csv is copied to good_data.
# split_8698.csv is copied to good_data.
# split_8840.csv is copied to good_data.
# split_9586.csv is copied to good_data.
# [ERROR] split_594.csv: Premium travel_class found.
# split_594.csv is copied to bad_data.
# split_1864.csv is copied to good_data.
# split_3134.csv is copied to good_data.
# [ERROR] split_5545.csv: Same source and destination cities.
# [ERROR] split_5545.csv: Invalid 'days_left' values (Yes/No).
# split_5545.csv is copied to bad_data.
# split_4883.csv is copied to good_data.
# [ERROR] split_1723.csv: Same source and destination cities.
# [ERROR] split_1723.csv: Invalid 'days_left' values (Yes/No).
# split_1723.csv is copied to bad_data.
# [ERROR] split_8061.csv: Zero stops with duration > 20 hours.
# split_8061.csv is copied to bad_data.
# [ERROR] split_7352.csv: Null values found in 'airline' column.
# split_7352.csv is copied to bad_data.
# [ERROR] split_8707.csv: Negative 'duration' values.
# split_8707.csv is copied to bad_data.
# split_7434.csv is copied to good_data.
# [ERROR] split_9419.csv: Same source and destination cities.
# split_9419.csv is copied to bad_data.
# [ERROR] split_1045.csv: Air India flights with Vistara flight numbers.
# split_1045.csv is copied to bad_data.
# [ERROR] split_5223.csv: Invalid 'days_left' values (Yes/No).
# [ERROR] split_5223.csv: Premium travel_class found.
# split_5223.csv is copied to bad_data.
# [ERROR] split_3652.csv: Null values found in 'airline' column.
# split_3652.csv is copied to bad_data.
# split_2558.csv is copied to good_data.
# [ERROR] split_5237.csv: Negative 'duration' values.
# [ERROR] split_5237.csv: Same source and destination cities.
# split_5237.csv is copied to bad_data.
# [ERROR] split_4129.csv: Air India flights with Vistara flight numbers.
# split_4129.csv is copied to bad_data.
# [ERROR] split_3646.csv: Negative 'duration' values.
# split_3646.csv is copied to bad_data.
# [ERROR] split_8713.csv: Air India flights with Vistara flight numbers.
# [ERROR] split_8713.csv: Zero stops with duration > 20 hours.
# split_8713.csv is copied to bad_data.
# split_7420.csv is copied to good_data.
# split_1051.csv is copied to good_data.
# [ERROR] split_379.csv: Null values found in 'airline' column.
# split_379.csv is copied to bad_data.
# split_1737.csv is copied to good_data.
# [ERROR] split_6058.csv: Same source and destination cities.
# split_6058.csv is copied to bad_data.
# [ERROR] split_8075.csv: Negative 'duration' values.
# split_8075.csv is copied to bad_data.
# [ERROR] split_7346.csv: Premium travel_class found.
# split_7346.csv is copied to bad_data.
# [ERROR] split_3120.csv: Invalid 'days_left' values (Yes/No).
# split_3120.csv is copied to bad_data.
# split_5551.csv is copied to good_data.
# split_4897.csv is copied to good_data.
# split_437.csv is copied to good_data.
# split_6070.csv is copied to good_data.
# [ERROR] split_9343.csv: Air India flights with Vistara flight numbers.
# split_9343.csv is copied to bad_data.
# [ERROR] split_3108.csv: Premium travel_class found.
# split_3108.csv is copied to bad_data.
# [ERROR] split_4667.csv: Null values found in 'airline' column.
# [ERROR] split_4667.csv: Zero stops with duration > 20 hours.
# split_4667.csv is copied to bad_data.
# [ERROR] split_5579.csv: Invalid 'days_left' values (Yes/No).
# split_5579.csv is copied to bad_data.
# split_2216.csv is copied to good_data.
# split_2570.csv is copied to good_data.
# split_4101.csv is copied to good_data.
# [ERROR] split_7408.csv: Zero stops with duration > 20 hours.
# split_7408.csv is copied to bad_data.
# [ERROR] split_6716.csv: Null values found in 'airline' column.
# split_6716.csv is copied to bad_data.
# split_9425.csv is copied to good_data.
# [ERROR] split_351.csv: Air India flights with Vistara flight numbers.
# split_351.csv is copied to bad_data.
# split_1079.csv is copied to good_data.
# split_6702.csv is copied to good_data.
# [ERROR] split_9431.csv: Same source and destination cities.
# split_9431.csv is copied to bad_data.
# [ERROR] split_345.csv: Negative 'duration' values.
# split_345.csv is copied to bad_data.
# split_2564.csv is copied to good_data.
# [ERROR] split_4115.csv: Same source and destination cities.
# split_4115.csv is copied to bad_data.
# split_4673.csv is copied to good_data.
# [ERROR] split_2202.csv: Negative 'duration' values.
# [ERROR] split_2202.csv: Air India flights with Vistara flight numbers.
# split_2202.csv is copied to bad_data.
# split_423.csv is copied to good_data.
# [ERROR] split_6064.csv: Same source and destination cities.
# split_6064.csv is copied to bad_data.
# [ERROR] split_9357.csv: Invalid 'days_left' values (Yes/No).
# split_9357.csv is copied to bad_data.
# [ERROR] split_8049.csv: Invalid 'days_left' values (Yes/No).
# split_8049.csv is copied to bad_data.
# [ERROR] split_1938.csv: Premium travel_class found.
# split_1938.csv is copied to bad_data.
# [ERROR] split_7391.csv: Null values found in 'airline' column.
# split_7391.csv is copied to bad_data.
# [ERROR] split_5586.csv: Same source and destination cities.
# split_5586.csv is copied to bad_data.
# split_4840.csv is copied to good_data.
# split_4698.csv is copied to good_data.
# split_3691.csv is copied to good_data.
# [ERROR] split_3849.csv: Same source and destination cities.
# [ERROR] split_3849.csv: Invalid 'days_left' values (Yes/No).
# split_3849.csv is copied to bad_data.
# [ERROR] split_1086.csv: Same source and destination cities.
# split_1086.csv is copied to bad_data.
# split_6931.csv is copied to good_data.
# [ERROR] split_8908.csv: Null values found in 'airline' column.
# split_8908.csv is copied to bad_data.
# split_1092.csv is copied to good_data.
# split_6925.csv is copied to good_data.
# split_3685.csv is copied to good_data.
# [ERROR] split_5592.csv: Negative 'duration' values.
# [ERROR] split_5592.csv: Invalid 'days_left' values (Yes/No).
# [ERROR] split_5592.csv: Air India flights with Vistara flight numbers.
# [ERROR] split_5592.csv: Zero stops with duration > 20 hours.
# split_5592.csv is copied to bad_data.
# [ERROR] split_4854.csv: Negative 'duration' values.
# split_4854.csv is copied to bad_data.
# [ERROR] split_7385.csv: Air India flights with Vistara flight numbers.
# split_7385.csv is copied to bad_data.
# split_1904.csv is copied to good_data.
# split_9380.csv is copied to good_data.
# split_392.csv is copied to good_data.
# [ERROR] split_8920.csv: Air India flights with Vistara flight numbers.
# split_8920.csv is copied to bad_data.
# [ERROR] split_3875.csv: Null values found in 'airline' column.
# split_3875.csv is copied to bad_data.
# [ERROR] split_3861.csv: Invalid 'days_left' values (Yes/No).
# split_3861.csv is copied to bad_data.
# [ERROR] split_386.csv: Invalid 'days_left' values (Yes/No).
# split_386.csv is copied to bad_data.
# split_8934.csv is copied to good_data.
# [ERROR] split_6919.csv: Air India flights with Vistara flight numbers.
# split_6919.csv is copied to bad_data.
# [ERROR] split_1910.csv: Invalid 'days_left' values (Yes/No).
# [ERROR] split_1910.csv: Air India flights with Vistara flight numbers.
# split_1910.csv is copied to bad_data.
# split_9394.csv is copied to good_data.
# [ERROR] split_4868.csv: Premium travel_class found.
# split_4868.csv is copied to bad_data.
# split_3450.csv is copied to good_data.
# split_2996.csv is copied to good_data.
# split_5021.csv is copied to good_data.
# [ERROR] split_1247.csv: Invalid 'days_left' values (Yes/No).
# split_1247.csv is copied to bad_data.
# split_6528.csv is copied to good_data.
# [ERROR] split_7636.csv: Zero stops with duration > 20 hours.
# split_7636.csv is copied to bad_data.
# split_8505.csv is copied to good_data.
# split_7150.csv is copied to good_data.
# [ERROR] split_8263.csv: Null values found in 'airline' column.
# [ERROR] split_8263.csv: Invalid 'days_left' values (Yes/No).
# split_8263.csv is copied to bad_data.
# [ERROR] split_609.csv: Premium travel_class found.
# split_609.csv is copied to bad_data.
# [ERROR] split_1521.csv: Zero stops with duration > 20 hours.
# split_1521.csv is copied to bad_data.
# [ERROR] split_2028.csv: Invalid 'days_left' values (Yes/No).
# split_2028.csv is copied to bad_data.
# [ERROR] split_5747.csv: Invalid 'days_left' values (Yes/No).
# split_5747.csv is copied to bad_data.
# [ERROR] split_4459.csv: Air India flights with Vistara flight numbers.
# split_4459.csv is copied to bad_data.
# split_3336.csv is copied to good_data.
# split_5753.csv is copied to good_data.
# [ERROR] split_3322.csv: Negative 'duration' values.
# [ERROR] split_3322.csv: Zero stops with duration > 20 hours.
# split_3322.csv is copied to bad_data.
# split_7144.csv is copied to good_data.
# [ERROR] split_8277.csv: Negative 'duration' values.
# [ERROR] split_8277.csv: Premium travel_class found.
# split_8277.csv is copied to bad_data.
# split_9169.csv is copied to good_data.
# [ERROR] split_1535.csv: Same source and destination cities.
# split_1535.csv is copied to bad_data.
# split_1253.csv is copied to good_data.
# split_7622.csv is copied to good_data.
# split_8511.csv is copied to good_data.
# split_3444.csv is copied to good_data.
# split_2982.csv is copied to good_data.
# [ERROR] split_5035.csv: Same source and destination cities.
# [ERROR] split_5035.csv: Invalid 'days_left' values (Yes/No).
# [ERROR] split_5035.csv: Air India flights with Vistara flight numbers.
# split_5035.csv is copied to bad_data.
# split_153.csv is copied to good_data.
# split_9627.csv is copied to good_data.
# split_6514.csv is copied to good_data.
# [ERROR] split_8539.csv: Premium travel_class found.
# split_8539.csv is copied to bad_data.
# [ERROR] split_4303.csv: Null values found in 'airline' column.
# [ERROR] split_4303.csv: Invalid 'days_left' values (Yes/No).
# split_4303.csv is copied to bad_data.
# [ERROR] split_2772.csv: Invalid 'days_left' values (Yes/No).
# split_2772.csv is copied to bad_data.
# [ERROR] split_2014.csv: Same source and destination cities.
# [ERROR] split_2014.csv: Invalid 'days_left' values (Yes/No).
# split_2014.csv is copied to bad_data.
# [ERROR] split_4465.csv: Premium travel_class found.
# split_4465.csv is copied to bad_data.
# [ERROR] split_9141.csv: Air India flights with Vistara flight numbers.
# split_9141.csv is copied to bad_data.
# [ERROR] split_6272.csv: Negative 'duration' values.
# [ERROR] split_6272.csv: Same source and destination cities.
# split_6272.csv is copied to bad_data.
# [ERROR] split_635.csv: Negative 'duration' values.
# [ERROR] split_635.csv: Same source and destination cities.
# split_635.csv is copied to bad_data.
# split_7178.csv is copied to good_data.
# [ERROR] split_9155.csv: Negative 'duration' values.
# split_9155.csv is copied to bad_data.
# split_6266.csv is copied to good_data.
# split_1509.csv is copied to good_data.
# ...
# split_2352.csv is copied to bad_data.
# [ERROR] split_4723.csv: Negative 'duration' values.
# split_4723.csv is copied to bad_data.
# split_4045.csv is copied to good_data.
# split_2434.csv is copied to good_data.
# split_6652.csv is copied to good_data.
# [ERROR] split_9561.csv: Same source and destination cities.
# [ERROR] split_9561.csv: Premium travel_class found.
# split_9561.csv is copied to bad_data.
# split_215.csv is copied to good_data.
# split_3702.csv is copied to good_data.
# [ERROR] split_5373.csv: Null values found in 'airline' column.
# split_5373.csv is copied to bad_data.
# split_9549.csv is copied to good_data.
# split_1115.csv is copied to good_data.
# split_8657.csv is copied to good_data.
# split_7564.csv is copied to good_data.
# [ERROR] split_8131.csv: Zero stops with duration > 20 hours.
# split_8131.csv is copied to bad_data.
# split_7202.csv is copied to good_data.
# [ERROR] split_1673.csv: Air India flights with Vistara flight numbers.
# split_1673.csv is copied to bad_data.
# split_5415.csv is copied to good_data.
# split_3064.csv is copied to good_data.
# split_5401.csv is copied to good_data.
# split_3070.csv is copied to good_data.
# split_8125.csv is copied to good_data.
# [ERROR] split_7216.csv: Negative 'duration' values.
# [ERROR] split_7216.csv: Premium travel_class found.
# split_7216.csv is copied to bad_data.
# split_1667.csv is copied to good_data.
# split_6108.csv is copied to good_data.
# split_1101.csv is copied to good_data.
# [ERROR] split_229.csv: Air India flights with Vistara flight numbers.
# [ERROR] split_229.csv: Zero stops with duration > 20 hours.
# split_229.csv is copied to bad_data.
# [ERROR] split_8643.csv: Premium travel_class found.
# split_8643.csv is copied to bad_data.
# [ERROR] split_7570.csv: Negative 'duration' values.
# split_7570.csv is copied to bad_data.
# split_4079.csv is copied to good_data.
# split_3716.csv is copied to good_data.
# [ERROR] split_2408.csv: Premium travel_class found.
# split_2408.csv is copied to bad_data.
# split_5367.csv is copied to good_data.
# split_3925.csv is copied to good_data.
# split_4092.csv is copied to good_data.
# split_6685.csv is copied to good_data.
# split_8870.csv is copied to good_data.
# split_1854.csv is copied to good_data.
# [ERROR] split_2385.csv: Invalid 'days_left' values (Yes/No).
# [ERROR] split_2385.csv: Air India flights with Vistara flight numbers.
# split_2385.csv is copied to bad_data.
# split_2391.csv is copied to good_data.
# [ERROR] split_4938.csv: Null values found in 'airline' column.
# [ERROR] split_4938.csv: Same source and destination cities.
# split_4938.csv is copied to bad_data.
# split_1698.csv is copied to good_data.
# [ERROR] split_1840.csv: Air India flights with Vistara flight numbers.
# split_1840.csv is copied to bad_data.
# split_6849.csv is copied to good_data.
# [ERROR] split_6691.csv: Negative 'duration' values.
# split_6691.csv is copied to bad_data.
# [ERROR] split_8864.csv: Null values found in 'airline' column.
# [ERROR] split_8864.csv: Air India flights with Vistara flight numbers.
# split_8864.csv is copied to bad_data.
# [ERROR] split_3931.csv: Null values found in 'airline' column.
# split_3931.csv is copied to bad_data.
# split_5398.csv is copied to good_data.
# split_4086.csv is copied to good_data.
# [ERROR] split_6861.csv: Premium travel_class found.
# split_6861.csv is copied to bad_data.
# [ERROR] split_8694.csv: Air India flights with Vistara flight numbers.
# split_8694.csv is copied to bad_data.
# [ERROR] split_3919.csv: Null values found in 'airline' column.
# [ERROR] split_3919.csv: Negative 'duration' values.
# [ERROR] split_3919.csv: Same source and destination cities.
# [ERROR] split_3919.csv: Zero stops with duration > 20 hours.
# split_3919.csv is copied to bad_data.
# split_4910.csv is copied to good_data.
# split_598.csv is copied to good_data.
# [ERROR] split_1868.csv: Zero stops with duration > 20 hours.
# split_1868.csv is copied to bad_data.
# split_4904.csv is copied to good_data.
# [ERROR] split_6875.csv: Air India flights with Vistara flight numbers.
# split_6875.csv is copied to bad_data.
# [ERROR] split_8680.csv: Negative 'duration' values.
# [ERROR] split_8680.csv: Air India flights with Vistara flight numbers.
# split_8680.csv is copied to bad_data.
# [ERROR] split_8858.csv: Zero stops with duration > 20 hours.
# split_8858.csv is copied to bad_data.
# split_375.csv is copied to good_data.
# split_6732.csv is copied to good_data.
# [ERROR] split_9401.csv: Null values found in 'airline' column.
# [ERROR] split_9401.csv: Negative 'duration' values.
# split_9401.csv is copied to bad_data.
# split_3892.csv is copied to good_data.
# [ERROR] split_2554.csv: Negative 'duration' values.
# [ERROR] split_2554.csv: Air India flights with Vistara flight numbers.
# split_2554.csv is copied to bad_data.
# split_4125.csv is copied to good_data.
# [ERROR] split_4643.csv: Invalid 'days_left' values (Yes/No).
# split_4643.csv is copied to bad_data.
# [ERROR] split_2232.csv: Invalid 'days_left' values (Yes/No).
# [ERROR] split_2232.csv: Premium travel_class found.
# split_2232.csv is copied to bad_data.
# [ERROR] split_6054.csv: Zero stops with duration > 20 hours.
# split_6054.csv is copied to bad_data.
# [ERROR] split_9367.csv: Same source and destination cities.
# split_9367.csv is copied to bad_data.
# split_413.csv is copied to good_data.
# split_8079.csv is copied to good_data.
# [ERROR] split_6040.csv: Zero stops with duration > 20 hours.
# split_6040.csv is copied to bad_data.
# split_9373.csv is copied to good_data.
# [ERROR] split_407.csv: Same source and destination cities.
# split_407.csv is copied to bad_data.
# split_4657.csv is copied to good_data.
# [ERROR] split_3138.csv: Air India flights with Vistara flight numbers.
# [ERROR] split_3138.csv: Zero stops with duration > 20 hours.
# split_3138.csv is copied to bad_data.
# [ERROR] split_2226.csv: Same source and destination cities.
# split_2226.csv is copied to bad_data.
# split_5549.csv is copied to good_data.
# split_3886.csv is copied to good_data.
# split_2540.csv is copied to good_data.
# split_4131.csv is copied to good_data.
# split_7438.csv is copied to good_data.
# split_361.csv is copied to good_data.
# split_1049.csv is copied to good_data.
# [ERROR] split_6726.csv: Same source and destination cities.
# split_6726.csv is copied to bad_data.
# [ERROR] split_9415.csv: Premium travel_class found.
# split_9415.csv is copied to bad_data.
# [ERROR] split_5207.csv: Same source and destination cities.
# [ERROR] split_5207.csv: Air India flights with Vistara flight numbers.
# split_5207.csv is copied to bad_data.
# [ERROR] split_2568.csv: Premium travel_class found.
# split_2568.csv is copied to bad_data.
# split_3676.csv is copied to good_data.
# [ERROR] split_4119.csv: Same source and destination cities.
# split_4119.csv is copied to bad_data.
# [ERROR] split_8723.csv: Premium travel_class found.
# split_8723.csv is copied to bad_data.
# split_7410.csv is copied to good_data.
# split_1061.csv is copied to good_data.
# split_349.csv is copied to good_data.
# split_6068.csv is copied to good_data.
# split_1707.csv is copied to good_data.
# split_8045.csv is copied to good_data.
# [ERROR] split_7376.csv: Premium travel_class found.
# split_7376.csv is copied to bad_data.
# split_3110.csv is copied to good_data.
# [ERROR] split_5561.csv: Negative 'duration' values.
# split_5561.csv is copied to bad_data.
# [ERROR] split_3104.csv: Null values found in 'airline' column.
# split_3104.csv is copied to bad_data.
# [ERROR] split_5575.csv: Negative 'duration' values.
# split_5575.csv is copied to bad_data.
# [ERROR] split_1713.csv: Same source and destination cities.
# [ERROR] split_1713.csv: Zero stops with duration > 20 hours.
# split_1713.csv is copied to bad_data.
# [ERROR] split_8051.csv: Air India flights with Vistara flight numbers.
# split_8051.csv is copied to bad_data.
# split_7362.csv is copied to good_data.
# [ERROR] split_8737.csv: Premium travel_class found.
# split_8737.csv is copied to bad_data.
# split_7404.csv is copied to good_data.
# split_1075.csv is copied to good_data.
# split_9429.csv is copied to good_data.
# split_5213.csv is copied to good_data.
# split_3662.csv is copied to good_data.
# [ERROR] split_3689.csv: Zero stops with duration > 20 hours.
# split_3689.csv is copied to bad_data.
# [ERROR] split_3851.csv: Same source and destination cities.
# split_3851.csv is copied to bad_data.
# [ERROR] split_2597.csv: Negative 'duration' values.
# [ERROR] split_2597.csv: Invalid 'days_left' values (Yes/No).
# split_2597.csv is copied to bad_data.
# split_8904.csv is copied to good_data.
# [ERROR] split_6929.csv: Null values found in 'airline' column.
# split_6929.csv is copied to bad_data.
# [ERROR] split_7389.csv: Same source and destination cities.
# split_7389.csv is copied to bad_data.
# split_1920.csv is copied to good_data.
# split_6097.csv is copied to good_data.
# split_4858.csv is copied to good_data.
# split_4680.csv is copied to good_data.
# split_4694.csv is copied to good_data.
# [ERROR] split_1934.csv: Negative 'duration' values.
# split_1934.csv is copied to bad_data.
# split_6083.csv is copied to good_data.
# split_8910.csv is copied to good_data.
# split_3845.csv is copied to good_data.
# [ERROR] split_2583.csv: Premium travel_class found.
# split_2583.csv is copied to bad_data.
# split_8938.csv is copied to good_data.
# split_6915.csv is copied to good_data.
# split_4864.csv is copied to good_data.
# [ERROR] split_8086.csv: Air India flights with Vistara flight numbers.
# split_8086.csv is copied to bad_data.
# [ERROR] split_9398.csv: Null values found in 'airline' column.
# [ERROR] split_9398.csv: Premium travel_class found.
# split_9398.csv is copied to bad_data.
# split_8092.csv is copied to good_data.
# [ERROR] split_1908.csv: Invalid 'days_left' values (Yes/No).
# split_1908.csv is copied to bad_data.
# [ERROR] split_4870.csv: Null values found in 'airline' column.
# split_4870.csv is copied to bad_data.
# split_3879.csv is copied to good_data.
# [ERROR] split_6901.csv: Same source and destination cities.
# split_6901.csv is copied to bad_data.
# split_7148.csv is copied to good_data.
# [ERROR] split_1539.csv: Same source and destination cities.
# split_1539.csv is copied to bad_data.
# [ERROR] split_611.csv: Negative 'duration' values.
# split_611.csv is copied to bad_data.
# [ERROR] split_9165.csv: Negative 'duration' values.
# [ERROR] split_9165.csv: Same source and destination cities.
# [ERROR] split_9165.csv: Invalid 'days_left' values (Yes/No).
# [ERROR] split_9165.csv: Air India flights with Vistara flight numbers.
# split_9165.csv is copied to bad_data.
# [ERROR] split_6256.csv: Zero stops with duration > 20 hours.
# split_6256.csv is copied to bad_data.
# split_2030.csv is copied to good_data.
# [ERROR] split_5987.csv: Invalid 'days_left' values (Yes/No).
# split_5987.csv is copied to bad_data.
# [ERROR] split_4441.csv: Premium travel_class found.
# split_4441.csv is copied to bad_data.
# [ERROR] split_4327.csv: Zero stops with duration > 20 hours.
# split_4327.csv is copied to bad_data.
# split_3448.csv is copied to good_data.
# split_2756.csv is copied to good_data.
# [ERROR] split_5039.csv: Air India flights with Vistara flight numbers.
# split_5039.csv is copied to bad_data.
# split_9603.csv is copied to good_data.
# [ERROR] split_6530.csv: Same source and destination cities.
# [ERROR] split_6530.csv: Zero stops with duration > 20 hours.
# split_6530.csv is copied to bad_data.
# split_177.csv is copied to good_data.
# split_9617.csv is copied to good_data.
# [ERROR] split_6524.csv: Negative 'duration' values.
# [ERROR] split_6524.csv: Premium travel_class found.
# split_6524.csv is copied to bad_data.
# split_163.csv is copied to good_data.
# [ERROR] split_8509.csv: Same source and destination cities.
# split_8509.csv is copied to bad_data.
# [ERROR] split_4333.csv: Invalid 'days_left' values (Yes/No).
# split_4333.csv is copied to bad_data.
# split_2742.csv is copied to good_data.
# [ERROR] split_2024.csv: Premium travel_class found.
# [ERROR] split_2024.csv: Air India flights with Vistara flight numbers.
# split_2024.csv is copied to bad_data.
# [ERROR] split_5993.csv: Air India flights with Vistara flight numbers.
# split_5993.csv is copied to bad_data.
# split_4455.csv is copied to good_data.
# [ERROR] split_605.csv: Null values found in 'airline' column.
# split_605.csv is copied to bad_data.
# [ERROR] split_9171.csv: Air India flights with Vistara flight numbers.
# split_9171.csv is copied to bad_data.
# [ERROR] split_6242.csv: Same source and destination cities.
# split_6242.csv is copied to bad_data.
# split_5763.csv is copied to good_data.
# [ERROR] split_3312.csv: Air India flights with Vistara flight numbers.
# split_3312.csv is copied to bad_data.
# split_7174.csv is copied to good_data.
# [ERROR] split_8247.csv: Negative 'duration' values.
# split_8247.csv is copied to bad_data.
# split_1505.csv is copied to good_data.
# split_9159.csv is copied to good_data.
# split_1263.csv is copied to good_data.
# [ERROR] split_7612.csv: Air India flights with Vistara flight numbers.
# split_7612.csv is copied to bad_data.
# [ERROR] split_8521.csv: Premium travel_class found.
# split_8521.csv is copied to bad_data.
# split_3474.csv is copied to good_data.
# split_5005.csv is copied to good_data.
# [ERROR] split_3460.csv: Null values found in 'airline' column.
# [ERROR] split_3460.csv: Negative 'duration' values.
# split_3460.csv is copied to bad_data.
# split_5011.csv is copied to good_data.
# split_6518.csv is copied to good_data.
# [ERROR] split_1277.csv: Null values found in 'airline' column.
# [ERROR] split_1277.csv: Negative 'duration' values.
# split_1277.csv is copied to bad_data.
# split_7606.csv is copied to good_data.
# split_8535.csv is copied to good_data.
# split_7160.csv is copied to good_data.
# split_8253.csv is copied to good_data.
# [ERROR] split_639.csv: Invalid 'days_left' values (Yes/No).
# split_639.csv is copied to bad_data.
# split_1511.csv is copied to good_data.
# split_5777.csv is copied to good_data.
# split_2018.csv is copied to good_data.
# split_3306.csv is copied to good_data.
# split_4469.csv is copied to good_data.
# split_5944.csv is copied to good_data.
# split_4482.csv is copied to good_data.
# [ERROR] split_6295.csv: Negative 'duration' values.
# split_6295.csv is copied to bad_data.
# [ERROR] split_9818.csv: Invalid 'days_left' values (Yes/No).
# split_9818.csv is copied to bad_data.
# [ERROR] split_7835.csv: Invalid 'days_left' values (Yes/No).
# split_7835.csv is copied to bad_data.
# split_2795.csv is copied to good_data.
# [ERROR] split_2781.csv: Invalid 'days_left' values (Yes/No).
# split_2781.csv is copied to bad_data.
# [ERROR] split_2959.csv: Premium travel_class found.
# split_2959.csv is copied to bad_data.
# [ERROR] split_1288.csv: Air India flights with Vistara flight numbers.
# split_1288.csv is copied to bad_data.
# split_7821.csv is copied to good_data.
# [ERROR] split_6281.csv: Air India flights with Vistara flight numbers.
# split_6281.csv is copied to bad_data.
# split_5950.csv is copied to good_data.
# [ERROR] split_4496.csv: Invalid 'days_left' values (Yes/No).
# split_4496.csv is copied to bad_data.
# split_5788.csv is copied to good_data.
# [ERROR] split_836.csv: Null values found in 'airline' column.
# split_836.csv is copied to bad_data.
# [ERROR] split_8284.csv: Negative 'duration' values.
# split_8284.csv is copied to bad_data.
# [ERROR] split_5978.csv: Invalid 'days_left' values (Yes/No).
# split_5978.csv is copied to bad_data.
# split_2971.csv is copied to good_data.
# [ERROR] split_9824.csv: Negative 'duration' values.
# [ERROR] split_9824.csv: Invalid 'days_left' values (Yes/No).
# split_9824.csv is copied to bad_data.
# [ERROR] split_188.csv: Same source and destination cities.
# [ERROR] split_188.csv: Air India flights with Vistara flight numbers.
# split_188.csv is copied to bad_data.
# [ERROR] split_7809.csv: Null values found in 'airline' column.
# split_7809.csv is copied to bad_data.
# [ERROR] split_9830.csv: Same source and destination cities.
# split_9830.csv is copied to bad_data.
# split_2965.csv is copied to good_data.
# [ERROR] split_822.csv: Zero stops with duration > 20 hours.
# split_822.csv is copied to bad_data.
# [ERROR] split_8290.csv: Negative 'duration' values.
# [ERROR] split_8290.csv: Same source and destination cities.
# split_8290.csv is copied to bad_data.
#
# Total files processed: 9999
# Files copied to bad_data: 4991
# Files copied to good_data: 5007
# Files skipped due to errors: 1
