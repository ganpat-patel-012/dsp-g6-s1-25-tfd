# %%
import pandas as pd
import numpy as np
import random

# %%
file_path = '/Users/jatinkumarparmar/Documents/GitHub/dsp_project/dsp-g6-s1-25-tfd/data/Clean_Dataset.csv'

df = pd.read_csv(file_path)

# %%
def introduce_specific_errors(df):
    
    df_error = df.copy()

    # 1. Remove airline from 500 rows
    random_airline_indices = np.random.choice(df_error.index, size=min(500, len(df_error)), replace=False)
    df_error.loc[random_airline_indices, 'airline'] = None

    # 2. Negative value in duration column
    random_days_indices = np.random.choice(df_error.index, size=min(500, len(df_error)), replace=False)
    df_error.loc[random_days_indices, 'duration'] *= -1

    # 3. Same source and destination cities
    random_city_indices = np.random.choice(df_error.index, size=min(500, len(df_error)), replace=False)
    df_error.loc[random_city_indices, 'destination_city'] = df_error.loc[random_city_indices, 'source_city']

    # 4. Yes and No values in days_left column
    df_error['days_left'] = df_error['days_left'].astype('object')
    random_days_left_indices = np.random.choice(df_error.index, size=min(500, len(df_error)), replace=False)
    df_error.loc[random_days_left_indices, 'days_left'] = np.random.choice(['Yes', 'No'], size=len(random_days_left_indices))

    # 5. Invalid class types (add "Premium" besides Economy/Business)
    random_class_indices = np.random.choice(df_error.index, size=min(500, len(df_error)), replace=False)
    df_error.loc[random_class_indices, 'travel_class'] = 'Premium'

    # 6. Air India airline has flights with Vistara flight numbers
    air_india_indices = df_error[df_error['airline'] == 'Air_India'].index
    if len(air_india_indices) > 0:
        random_air_india = np.random.choice(air_india_indices, size=min(500, len(air_india_indices)), replace=False)
        vistara_flight_numbers = ['UK-' + str(random.randint(100, 999)) for _ in range(len(random_air_india))]
        df_error.loc[random_air_india, 'flight'] = vistara_flight_numbers

    # 7. Assign random durations > 20 hours to some "zero stops" flights
    zero_stop_indices = df_error[df_error['stops'] == 'zero'].index
    if len(zero_stop_indices) > 0:
        random_zero_stops = np.random.choice(zero_stop_indices, size=min(500, len(zero_stop_indices)), replace=False)
        df_error.loc[random_zero_stops, 'duration'] = np.random.uniform(20.1, 25.0, size=len(random_zero_stops))

    return df_error

def verify_errors(original_df, error_df):
    
    print("1. Flights without Airline name:")
    print(error_df[(error_df['airline'].isna())].head())

    print("\n2. Negative duration values:")
    print(error_df[error_df['duration'] < 0].head())

    print("\n3. Same source and destination cities:")
    print(error_df[error_df['source_city'] == error_df['destination_city']].head())

    print("\n4. Yes/No values in days_left:")
    print(error_df[error_df['days_left'].astype(str).isin(['Yes', 'No'])].head())

    print("\n5. Premium class entries:")
    print(error_df[error_df['travel_class'] == 'Premium'].head())

    print("\n6. Air India with Vistara flight numbers:")
    print(error_df[(error_df['airline'] == 'Air_India') & (error_df['flight'].str.startswith('UK-'))].head())

    print("\n7. Zero stops with duration > 20 hours:")
    temp_duration = pd.to_numeric(error_df['duration'], errors='coerce') 
    print(error_df[(error_df['stops'] == 'zero') & (temp_duration > 20)].head())


# Introduce errors
df_with_errors = introduce_specific_errors(df)

# Verify the introduced errors
verify_errors(df, df_with_errors)

# Save the dataset with errors
df_with_errors.to_csv('/Users/jatinkumarparmar/Documents/GitHub/dsp_project/dsp-g6-s1-25-tfd/data/flight_dataset_with_errors.csv', index=False)
# Out:
# 1. Flights without Airline name:
#       Unnamed: 0 airline   flight source_city departure_time stops  \
# 566          566    None  SG-8803       Delhi  Early_Morning  zero
# 2101        2101    None  G8-7535       Delhi        Evening  zero
# 2549        2549    None  SG-1089       Delhi  Early_Morning  zero
# 2563        2563    None   UK-977       Delhi        Evening  zero
# 2861        2861    None   UK-819       Delhi      Afternoon   one
#
#      arrival_time destination_city travel_class  duration days_left  price
# 566       Morning           Mumbai      Economy      2.25         5   5953
# 2101      Evening           Mumbai      Economy      2.08        13   5954
# 2549      Morning           Mumbai      Economy      2.25        15   2621
# 2563        Night           Mumbai      Economy      2.25        15   3310
# 2861        Night           Mumbai      Economy      9.17        16   6296
#
# 2. Negative duration values:
#      Unnamed: 0    airline   flight source_city departure_time stops  \
# 13           13     Indigo  6E-6202       Delhi        Morning  zero
# 22           22   GO_FIRST   G8-103       Delhi        Evening   one
# 145         145  Air_India   AI-805       Delhi        Evening  zero
# 732         732  Air_India   AI-429       Delhi        Morning   one
# 758         758    Vistara   UK-945       Delhi        Morning  zero
#
#     arrival_time destination_city travel_class  duration days_left  price
# 13     Afternoon           Mumbai      Economy     -2.17         1   5955
# 22       Morning           Mumbai      Economy    -15.67         1   5954
# 145        Night           Mumbai      Economy     -2.17         2   5955
# 732      Evening           Mumbai      Economy     -8.42         5  21180
# 758    Afternoon           Mumbai      Economy     -2.33         6   5955
#
# 3. Same source and destination cities:
#       Unnamed: 0    airline  flight source_city departure_time stops  \
# 649          649    Vistara  UK-871       Delhi          Night   one
# 2031        2031   GO_FIRST  G8-286       Delhi        Morning   one
# 2091        2091    Vistara  UK-943       Delhi  Early_Morning  zero
# 4160        4160  Air_India  AI-439       Delhi  Early_Morning   one
# 4709        4709  Air_India  AI-887       Delhi  Early_Morning  zero
#
#      arrival_time destination_city travel_class  duration days_left  price
# 649       Morning            Delhi      Economy     13.42         5   9840
# 2031        Night            Delhi      Economy     11.00        12  12045
# 2091      Morning            Delhi      Economy      2.25        13   5955
# 4160      Evening            Delhi      Economy     11.00        22   5693
# 4709      Morning            Delhi      Economy      2.08        25   2476
#
# 4. Yes/No values in days_left:
#       Unnamed: 0   airline   flight source_city departure_time stops  \
# 112          112  GO_FIRST   G8-213       Delhi        Morning   one
# 420          420    Indigo  6E-6202       Delhi        Morning  zero
# 1661        1661   Vistara   UK-963       Delhi        Morning  zero
# 1870        1870   Vistara   UK-993       Delhi      Afternoon  zero
# 2107        2107  GO_FIRST   G8-346       Delhi        Evening  zero
#
#      arrival_time destination_city travel_class  duration days_left  price
# 112       Evening           Mumbai      Economy      6.33       Yes  21111
# 420     Afternoon           Mumbai      Economy      2.17        No   5955
# 1661      Morning           Mumbai      Economy      2.33        No   5955
# 1870    Afternoon           Mumbai      Economy      2.17        No   5955
# 2107        Night           Mumbai      Economy      2.25        No   5954
#
# 5. Premium class entries:
#       Unnamed: 0    airline  flight source_city departure_time stops  \
# 110          110  Air_India  AI-473       Delhi        Evening   one
# 583          583    Vistara  UK-945       Delhi        Morning  zero
# 1055        1055  Air_India  AI-479       Delhi          Night   one
# 2070        2070  Air_India  AI-764       Delhi        Evening   one
# 2616        2616    AirAsia  I5-784       Delhi        Evening   one
#
#        arrival_time destination_city travel_class  duration days_left  price
# 110         Evening           Mumbai      Premium     22.75         1  19815
# 583       Afternoon           Mumbai      Premium      2.33         5   5955
# 1055      Afternoon           Mumbai      Premium     16.50         7  12215
# 2070          Night           Mumbai      Premium     27.17        12  14355
# 2616  Early_Morning           Mumbai      Premium     15.17        15   5230
#
# 6. Air India with Vistara flight numbers:
#       Unnamed: 0    airline  flight source_city departure_time stops  \
# 737          737  Air_India  UK-865       Delhi        Morning   one
# 777          777  Air_India  UK-459       Delhi  Early_Morning  zero
# 2641        2641  Air_India  UK-124       Delhi        Morning   one
# 4975        4975  Air_India  UK-873       Delhi        Evening   one
# 5422        5422  Air_India  UK-412       Delhi  Early_Morning   one
#
#      arrival_time destination_city travel_class  duration days_left  price
# 737         Night           Mumbai      Economy     10.92         5  24908
# 777       Morning           Mumbai      Economy      2.08         6   5955
# 2641        Night           Mumbai      Economy     14.17        15   5931
# 4975        Night           Mumbai      Economy     24.75        26   3897
# 5422        Night           Mumbai      Economy     17.83        28   4233
#
# 7. Zero stops with duration > 20 hours:
#       Unnamed: 0   airline  flight source_city departure_time stops  \
# 127          127  GO_FIRST  G8-336       Delhi      Afternoon  zero
# 575          575   Vistara  UK-951       Delhi      Afternoon  zero
# 1298        1298   Vistara  UK-985       Delhi        Evening  zero
# 1668        1668  GO_FIRST  G8-530       Delhi  Early_Morning  zero
# 1866        1866   AirAsia  I5-764       Delhi  Early_Morning  zero
#
#        arrival_time destination_city travel_class   duration days_left  price
# 127         Evening           Mumbai      Economy  20.177708         2   5954
# 575         Evening           Mumbai      Economy  24.410042         5   5955
# 1298          Night           Mumbai      Economy  21.369619         9   5955
# 1668        Morning           Mumbai      Economy  21.307214        11   5954
# 1866  Early_Morning           Mumbai      Economy  22.061282        12   5956
